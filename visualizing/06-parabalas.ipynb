# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
a = 1
h = -10
k = -2
n = 100

# x-axis
x = np.linspace(h-5, h+5, n)

y = a * (x-h)**2 + k

plt.plot(y, x)
plt.grid()
plt.axis('square')
plt.show()
