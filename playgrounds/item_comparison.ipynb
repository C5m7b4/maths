# %% [markdown]
# ## Import Libraries

# %%
import sys
import os

import numpy as np
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import fpgrowth, association_rules

sys.path.append(os.path.abspath('..'))
from utils.db import get_db

# %%
engine = get_db()

# %% [markdown]
# ## Gather Data

# %% [markdown]
# select sale_date, sale_id, product_code, product_description, qty, total_sales, sub_department_description,
# sale_type, item_ring_type
# from sales
# where store_number='440'
# and sale_date='5/15/2025'
# and sale_type in ('Refunded', 'Sale')
# and item_ring_type in ('ITEM')

# %%
query = """select sale_date, sale_id, product_code, product_description, qty, total_sales, sub_department_description,
sale_type, item_ring_type
from sales
where store_number='440'
and sale_date between '5/10/2025' and '5/15/2025'
and sale_type in ('Refunded', 'Sale')
and item_ring_type in ('ITEM')"""

# %%
#ds = pd.read_csv('../data/local_daily_basket_analysis_for_items_purchased_together.csv')

# %%
ds = pd.read_sql(query,engine)
# Out:
# 2025-06-12 14:08:59,186 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2025-06-12 14:08:59,186 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-06-12 14:08:59,241 INFO sqlalchemy.engine.Engine select current_schema()
# 2025-06-12 14:08:59,243 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-06-12 14:08:59,296 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2025-06-12 14:08:59,296 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-06-12 14:08:59,353 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-06-12 14:08:59,353 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-06-12 14:08:59,353 INFO sqlalchemy.engine.Engine [generated in 0.00071s] {'table_name': "select sale_date, sale_id, product_code, product_description, qty, total_sales, sub_department_description,\nsale_type, item_ring_type\nfrom sales\nwhere store_number='440'\nand sale_date between '5/10/2025' and '5/15/2025'\nand sale_type in ('Refunded', 'Sale')\nand item_ring_type in ('ITEM')", 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-06-12 14:08:59,409 INFO sqlalchemy.engine.Engine select sale_date, sale_id, product_code, product_description, qty, total_sales, sub_department_description,
# sale_type, item_ring_type
# from sales
# where store_number='440'
# and sale_date between '5/10/2025' and '5/15/2025'
# and sale_type in ('Refunded', 'Sale')
# and item_ring_type in ('ITEM')
# 2025-06-12 14:08:59,410 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-06-12 14:09:02,452 INFO sqlalchemy.engine.Engine ROLLBACK

# %%
ds.head()
# Out:
#    sale_date  sale_id   product_code                      product_description  \
# 0 2025-05-11   478636   8259219415.0                  NAKED WB STWBAN 15.2 OZ
# 1 2025-05-11   478776         4062.0                              CUCUMBER EA
# 2 2025-05-11   478683  85002770272.0             OLOPOP RIDGE RUSH SODA 12 OZ
# 3 2025-05-11   374139   2718256264.0  JALAPENO JACK INFUSED GROUND BEEF PATTY
# 4 2025-05-11   123807   3100012610.0            BANQ MEGA BOWL BUF CHKN 14 OZ
#
#    qty  total_sales sub_department_description sale_type item_ring_type
# 0  1.0         3.99                    Produce      Sale           ITEM
# 1  2.0         2.38                Wic Produce      Sale           ITEM
# 2  1.0         2.49                    Produce      Sale           ITEM
# 3  1.0        10.99                       Meat      Sale           ITEM
# 4  1.0         3.99                Frozen Food      Sale           ITEM

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41030 entries, 0 to 41029
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   sale_date                   41030 non-null  datetime64[ns]
#  1   sale_id                     41030 non-null  int64
#  2   product_code                41030 non-null  object
#  3   product_description         41030 non-null  object
#  4   qty                         41030 non-null  float64
#  5   total_sales                 41030 non-null  float64
#  6   sub_department_description  41030 non-null  object
#  7   sale_type                   41030 non-null  object
#  8   item_ring_type              41030 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(5)
# memory usage: 2.8+ MB

# %%
ds['item'] = ds['product_code'].astype(str).str.replace('.0', '', regex=False) + "::" + ds['product_description']

# %%
ds.head()
# Out:
#    sale_date sale_id   product_code                      product_description  \
# 0 2025-05-11  478636   8259219415.0                  NAKED WB STWBAN 15.2 OZ
# 1 2025-05-11  478776         4062.0                              CUCUMBER EA
# 2 2025-05-11  478683  85002770272.0             OLOPOP RIDGE RUSH SODA 12 OZ
# 3 2025-05-11  374139   2718256264.0  JALAPENO JACK INFUSED GROUND BEEF PATTY
# 4 2025-05-11  123807   3100012610.0            BANQ MEGA BOWL BUF CHKN 14 OZ
#
#    qty  total_sales sub_department_description sale_type item_ring_type  \
# 0  1.0         3.99                    Produce      Sale           ITEM
# 1  2.0         2.38                Wic Produce      Sale           ITEM
# 2  1.0         2.49                    Produce      Sale           ITEM
# 3  1.0        10.99                       Meat      Sale           ITEM
# 4  1.0         3.99                Frozen Food      Sale           ITEM
#
#                                                 item
# 0                8259219415::NAKED WB STWBAN 15.2 OZ
# 1                                  4062::CUCUMBER EA
# 2          85002770272::OLOPOP RIDGE RUSH SODA 12 OZ
# 3  2718256264::JALAPENO JACK INFUSED GROUND BEEF ...
# 4          3100012610::BANQ MEGA BOWL BUF CHKN 14 OZ

# %% [markdown]
# ## Clean Data

# %%
# lets filter this down to just items
ds = ds[ds['item_ring_type'] == 'ITEM']

# %%
#now lets get rid of any empty products
ds.dropna(subset=['product_description', 'sale_id', 'product_code'], inplace=True)

# %%
# convert sale_id to string
ds['sale_id'] = ds['sale_id'].astype(str)

# %%
transactions = ds.groupby('sale_id')['item'].apply(list)

# %%
transactions.head()
# Out:
# sale_id
# 102481     [4::PREMIUM]
# 102482    [2::UNLEADED]
# 102483    [2::UNLEADED]
# 102484    [2::UNLEADED]
# 102486    [2::UNLEADED]
# Name: item, dtype: object

# %%
# filter out single item transactions as these wont apply
transactions_filtered = transactions[transactions.apply(lambda x: len(x) > 1)]
transaction_list = transactions_filtered.tolist()

# %%
len(transaction_list)
# Out:
# 4808

# %%
transaction_list[:-20]
# Out:
# [['2412601435::BUNNY HONEY WHEAT 20 OZ',
#   '7342053121::DAISY 4% CTGE CHS/PINAPL 6 OZ',
#   '7342053124::DAISY PEACH COTT CHS 6 OZ',
#   '7003837286::BST CH GRD A LRG 18P EGG 1.5 DZ',
#   '7342053124::DAISY PEACH COTT CHS 6 OZ',
#   '7342053121::DAISY 4% CTGE CHS/PINAPL 6 OZ',
#   '2100004489::VEL SHRP CHDR SNGLS 12 OZ',
#   '28029400000::LEAN GROUND BEEF LB',
#   '5210007086::MC PURE VANILLA EXTRACT 1 OZ',
#   '2840020059::LAYS LIGHTLY SALTED 7.75 OZ',
#   '28029400000::LEAN GROUND BEEF LB',
#   '9908746090::SUMMER SAUSAGE W/JALAPENO AND CHEESE',
#   '4011::BANANA LB',
#   '3283::APPLE WA HONEYCRISP LB',
#   '3010000133::KEB ZESTA SALTINES 16 OZ',
#   '79590254088::CARD MDAY ANYONE',
#   '7273022110::PRAIRIE FARM 2% MILK GL 128 OZ'],
#  ['84186689452::YOU ARE MY SUNSHINE BQT BQT',
#   '84186601109::COUNTRY GIRL CHARM FLOWER BQT'],
#  ['81547301900::BORDEN HEAVY WHIPNG CREAM 16 OZ',
#   '81547301900::BORDEN HEAVY WHIPNG CREAM 16 OZ',
#   '7273021110::PRAIRIE FARM WHOLE MILK 128 OZ',
#   '2100030088::BRKSTN RICOTTA CHEESE 15 OZ',
#   '2100030088::BRKSTN RICOTTA CHEESE 15 OZ',
#   '3700095664::SCOPE MW OUTLAST FRESH MINT 16.9 OZ',
#   '9772968004::MICK CHOC TRUFFLE MINT EACH',
#   '9772968001::DARK CHOC TRUFFLE EACH'],
#  ['700::MISC FLORAL GIFTWARE',
#   '700::MISC FLORAL GIFTWARE',
#   '598::VARIETY DOZEN DONUT',
#   '28519600000::CHOCOLATE CHIP COOKIE',
#   '497::MISC BALLOON ORDER'],
#  ['64786518572::AIRBORNE GUMMIES 21 CT', '599::SINGLE DONUT'],
#  ['702::FLORAL SEASONAL', '702::FLORAL SEASONAL'],
#  ['4920005175::DOMINO 10X POWDER SUGAR 32 OZ',
#   '4920005175::DOMINO 10X POWDER SUGAR 32 OZ'],
#  ['5190001602::LOF PRM DELI TKY BRS 16 OZ',
#   '82927450225::MEOW MIX ORIGINAL 16 LB',
#   '1200000088::MOUNTAIN DEW 24 PK',
#   '4252::BLUEBERRIES PINT',
#   '5200004333::GAT ZERO GLACIER FREEZE 20OZ 8P 8 PK',
#   '4246::STRAWBERRIES   1 LB',
#   '7343500230::KINGS HAWAIIAN ROLLS 20 OZ',
#   '2100001714::KR STRING UMS CHEESE 12 OZ',
#   '5190001603::LOF PREM DELI HNY HA 16 OZ'],
#  ['28043200000::FP CENTER CUT RIB CHOPS LB',
#   '1200000088::MOUNTAIN DEW 24 PK',
#   '3560007301::KL DICED HAM 8 OZ',
#   '28043200000::FP CENTER CUT RIB CHOPS LB',
#   '3560007301::KL DICED HAM 8 OZ',
#   '28003200000::ANGUS CUBE STEAK LB',
#   '3560081302::KY LEG HICKRY SMK SLICED BACON 1 LB',
#   '3560081323::KL B BACON 16 OZ',
#   '3560081302::KY LEG HICKRY SMK SLICED BACON 1 LB',
#   '28003200000::ANGUS CUBE STEAK LB',
#   '28136200000::SF 7 TRAY CF DRUMS LB',
#   '28136200000::SF 7 TRAY CF DRUMS LB',
#   '28047800000::FP WHOLE PNLS PORK LOIN LB',
#   '28048500000::BNLS PORK STEAK LB',
#   '28018900000::PORK STEAK LB',
#   '28021100000:: SMOKED PORK HOCKS LB'],
#  ['4280011400::TOTINO PEPPERONI PIZZA 10.2 OZ',
#   '4502::ONIONS SWEET 3 LB',
#   '4069::CABBAGE GREEN LB',
#   '4280011400::TOTINO PEPPERONI PIZZA 10.2 OZ',
#   '4065::PEPPER GREEN EA',
#   '4666::ONIONS GREEN 5.5 OZ',
#   '7539102212::SEA BEST 30/40 E-Z PEEL SHRIMP 1 LB',
#   '7539102212::SEA BEST 30/40 E-Z PEEL SHRIMP 1 LB',
#   '4280011400::TOTINO PEPPERONI PIZZA 10.2 OZ',
#   '28309500000::BEANS GREEN LB',
#   '84023020001::AM CH MILK WHOLE GAL 128 OZ',
#   '4440011250::GORTONS THR FISH FILLETS 24.5 Z',
#   '28030500000::FP GROUND CHUCK LEAN LB',
#   '28030500000::FP GROUND CHUCK LEAN LB',
#   '3415::POTATO RUSSET 5 LB',
#   '2412600899::BUNNY 4 PLAIN HAMBURGER 12 PK 12 PK',
#   '2412600899::BUNNY 4 PLAIN HAMBURGER 12 PK 12 PK',
#   '7003866676::BST CHCE ROUND TOP 20 OZ',
#   '7003831146::BC HONEYWHEAT 20 OZ',
#   '3450015136::LOL BUTTER QUARTERS 16 OZ',
#   '7507660001::TRYME TIGER SAUCE THE ORIGINAL 10 OZ',
#   '7248600220::JIFFY CORN MUFFIN MIX 8.5 OZ',
#   '7248600220::JIFFY CORN MUFFIN MIX 8.5 OZ',
#   '2840007098::JAR DIP TOSTITOS QUESO 15 OZ',
#   '2998824310::CNTRY BOB AP SAUCE 13 OZ',
#   '2998824310::CNTRY BOB AP SAUCE 13 OZ',
#   '2998824310::CNTRY BOB AP SAUCE 13 OZ',
#   '2998824310::CNTRY BOB AP SAUCE 13 OZ',
#   '5150005711::SMUCKER SQUEEZE GRAPE JELLY 20 OZ',
#   '2100002649::KR MIRACLE WHIP 30 OZ',
#   '960000003546::CPN: $1 off (3) Totinos Pizzas or Rolls 5/7-5',
#   '4280010800::TOTINO 3 MEAT PIZZA 10.5 OZ',
#   '4280010800::TOTINO 3 MEAT PIZZA 10.5 OZ',
#   '4280010800::TOTINO 3 MEAT PIZZA 10.5 OZ'],
#  ['2840070576::FRITO LAY SANTITAS WHITE 11 OZ',
#   '61126900276::RED BULL SUGAR FREE SUMMER EDITION WHITE',
#   '28556400000::BROWNIE FACTORY EACH',
#   '2100005536::KR FINE SHRD MEX TACO 8 OZ',
#   '7003861336::BST CH TORTILLA BURRITO 8 CT'],
#  ['28886100000::ASE HAWAIIAN HAM EACH',
#   '4799::TOMATOES HOT HOUSE LARGE LB',
#   '4011::BANANA LB',
#   '599::SINGLE DONUT',
#   '1200010735::DIET MOUNTAIN DEW .5L 6 PK',
#   '1410007187::PF SOFT WHITE HAMBURGER BUNS 14.5 OZ',
#   '2412601861::LBS BUTTERMILK BREAD HALF LOAF 12 OZ'],
#  ['84186607480::ROSE MIX BQT', '7800012240::SUNKIST ZERO ORANGE SODA 20 OZ'],
#  ['89661200002::VEGETABLE BEDDING 4 CELL EA',
#   '7003837286::BST CH GRD A LRG 18P EGG 1.5 DZ',
#   '89661200002::VEGETABLE BEDDING 4 CELL EA',
#   '89661200002::VEGETABLE BEDDING 4 CELL EA'],
#  ['7273026203::PRAIRIE FARMS WHOLE CHOC 64 OZ',
#   '1128400357::JJ LEMON CREAM PIE 4 OZ',
#   '7273021202::PRAIRIE FARMS WHOLE MILK 64 OZ',
#   '598::VARIETY DOZEN DONUT',
#   '598::VARIETY DOZEN DONUT'],
#  ['28140400000::PR NY STRP STK EA',
#   '1404532418::COLEMAN PROPANE CYLINDER 16 OZ',
#   '4072::POTATO IDAHO LOOSE BAKER LB',
#   '2100005500::KR FINE SHRD SHP CHD 8 OZ',
#   '7003860932::BST CH BACON PIECES REAL 2.8 OZ',
#   '28140400000::PR NY STRP STK EA'],
#  ['88810901001::HOSTESS CHOCOLATE CUPCAKES 2 CT 3.17 OZ',
#   '75436240031::THRD SL TAPE1/2X260',
#   '2889312225::PLUG I/M TYPE QC 1/4MPT',
#   '2889317351::AIR CHUCK FEMALE 1/4NPT',
#   '2889312225::PLUG I/M TYPE QC 1/4MPT',
#   '4900000045::DIET COKE 20 OZ',
#   '5200032481::GATORADE COOL BLUE 20 OZ'],
#  ['84186607486::DOZEN ROSE BOUQUET BQT', '700::MISC FLORAL GIFTWARE'],
#  ['6055690001::ROMAINE HEARTS 3 PK',
#   '3283::APPLE WA HONEYCRISP LB',
#   '79590251864::CARD MDAY GRANDMOTHER',
#   '79590256866::CARD MDAY ANYONE',
#   '4900001063::DIET COKE 24 PK 12 OZ 288 OZ',
#   '28584900000::KRETSCHMAR OVN RSTD TRKY BRST EACH'],
#  ['7778200011::JOHNS ORIG RECIPE SAUSGE 12 O',
#   '2100005233::KR BBQ SCE SWT&SPICY 18 OZ',
#   '9147504189::MILO SWEET TEA GAL',
#   '2840051646::DORITOS NACHO CHEESE 9.25 OZ',
#   '28056200000::SPRINGER MNTN BONE IN THIGHS',
#   '28028700000::GROUND BEEF LB',
#   '28518900000::HOMEMADE CHICKEN N NOODL LB',
#   '7367526125::CAROLINA PRIDE BOLOGNA 6 OZ',
#   '2700044205::MANWICH THICK CHUNKY SLOPPY JOE SCE 15.5',
#   '2100005228::KR BBQ SCE ORIGINAL 18 OZ',
#   '7367526120::CP CHOPPED HAM PEG 5 OZ',
#   '7367504235::CAR PRD BLK FRST HAM 4 OZ',
#   '2840000024::CAN DIP JALAPENO  CHEDDAR 9 OZ',
#   '7184692243::S GATE CHILI W/BNS 15 OZ',
#   '7184692243::S GATE CHILI W/BNS 15 OZ'],
#  ['82692000135::MINI TRI COLOR PEPPERS RS 1 LB',
#   '75166677155::TOMATOES NATURE  SWEET CHERUB 10 OZ',
#   '82692000065::CUCUMBER MINI EA',
#   '4388::MANDARINS 3  LB',
#   '2412601716::LEWIS 1/2 LOAF 100% WHOLE WHEAT 12 OZ',
#   '7273072016::PF LEMON RASPBERRY CHEESCAKE 48 OZ',
#   '4061::LETTUCE  EA'],
#  ['80398428002::PDQ GLOW NECKLACE PDQ',
#   '2840052846::TOSTITOS CANTINA THIN AN CRISPY 10 OZ',
#   '7049112009::REAL VANILLA SYRP 16.9 OZ',
#   '599::SINGLE DONUT',
#   '2500004490::SIMPLY LEMONADE RASP 52 OZ',
#   '28301700000::STRWBRY/PINEPLE/BLUBRY MIX LB',
#   '7273021110::PRAIRIE FARM WHOLE MILK 128 OZ',
#   '3890003039::DOLE TROP FRUIT BOWL 4 PK',
#   '81547301235::BORDN HALF AND HALF 32 OZ',
#   '7273026406::PRAIRIE FARMS CHOCOLATE MILK 16 OZ',
#   '4388::MANDARINS 3  LB',
#   '88491200672::POST MARSHMALLOW FRUITY PEBBLES 11 OZ',
#   '3800022261::KEL PTART FROST BRWN SGR CIN 8 CT',
#   '7003859719::BST CH SHRED FANCY  COLBY JACK 8 OZ',
#   '7790053608::JD APPLEWD SMKD BCN 12 OZ',
#   '4900002892::SPRITE 12 PK 144 OZ',
#   '8304600402::ICE MOUNTAIN 16.9 OZ 24 PK PET 405.6 OZ',
#   '3077216014::BNTY 8TR SAS WHITE',
#   '3560005586::FIELD OL FASH FRNK 14 OZ',
#   '9477607774::GUMMI NEON WORMS 15 OZ'],
#  ['7084702090::MONSTER ULTRA SUNRISE 16 OZ', '599::SINGLE DONUT'],
#  ['28558100000::SHEET CAKE FLORAL EACH',
#   '7003860299::AS ICE CREAM NEAPOLITAN 128 OZ'],
#  ['2840051691::RUFFLES CHEDDAR SOUR CREAM 8 OZ',
#   '2781500430::ECKRICH BOLOGNA 12 OZ',
#   '2781500430::ECKRICH BOLOGNA 12 OZ',
#   '4011::BANANA LB'],
#  ['2430004320::LIL DEBBIE NUTTY BARS 25.2 OZ',
#   '2430004320::LIL DEBBIE NUTTY BARS 25.2 OZ',
#   '599::SINGLE DONUT'],
#  ['4470002773::OM REAL BACON RECIPE PIECES 2.8 OZ',
#   '7003862830::BST CH SHRED FANCY CHDR MLD RF 2% 8 OZ',
#   '84023020002::AM CH MILK 2% GALN 128 OZ',
#   '7003862830::BST CH SHRED FANCY CHDR MLD RF 2% 8 OZ',
#   '4119210714::KEL FF GLZ DNT HL 10 OZ',
#   '4119210025::CORN POPS CEREAL 16.4 OZ',
#   '2100005718::KR DLX MAC DINNER 3PK 42 OZ 42 OZ',
#   '4470002773::OM REAL BACON RECIPE PIECES 2.8 OZ'],
#  ['7520110249::C WILLIE BTR EXPLOSION POPCORN 6 PK',
#   '7520110249::CPN: C WILLIE BTR EXPLOSION POPCORN 6 PK',
#   '3620043170::RAGU OWS TRAD RETRO SAUCE LE 24 OZ',
#   '3620043170::RAGU OWS TRAD RETRO SAUCE LE 24 OZ'],
#  ['599::SINGLE DONUT',
#   '28616900000::GENERAL TSO MEAL 19 OZ',
#   '4900000764::SPRITE 20 OZ'],
#  ['730::FRESH ARRANGEMENT OR STEMS',
#   '79590251516::CARD MDAY ANYONE',
#   '920091676::CARD MDAY ANYONE'],
#  ['1394100692::CF A/N GROUND CHICKEN 16 OZ',
#   '1394100692::CPN: CF A/N GROUND CHICKEN 16 OZ'],
#  ['28517000000::MISC HOT FOODS EACH',
#   '1200000017::PEPSI 24 PK',
#   '28041300000::SUKARNE BF RIBEYE STK LB',
#   '28041300000::SUKARNE BF RIBEYE STK LB',
#   '28041300000::SUKARNE BF RIBEYE STK LB'],
#  ['81410902134::COOKIE POP OREO PPCR 5.25 OZ',
#   '7003831033::BST CH FUDGE STRIPE COOKIE 13 OZ',
#   '2840014739::SUNCHIPS HARVEST CHEDDAR 7 OZ',
#   '7800000386::DR PEPPER .5L 6 PK',
#   '3010047241::KBLR CRKR CLUB CHEDDAR 8 CT',
#   '7800000388::DT DR PEPPER 6 PK 101.4 OZ',
#   '3010047357::KBLR CRKR TOAST N PB 10.9 OZ',
#   '7800000386::DR PEPPER .5L 6 PK',
#   '7800000388::DT DR PEPPER 6 PK 101.4 OZ',
#   '2840014740::SUNCHIPS GARDEN SALSA 7 OZ',
#   '3485610818::WLCH FRT SNK MXD FRT 10 CT',
#   '81410902134::COOKIE POP OREO PPCR 5.25 OZ'],
#  ['7064001261::BB NEAPOLITAN PREMIUM ICE CREAM 48 OZ',
#   '7064001241::B BUNNY PEANUT BUTTER PARTY 46 OZ',
#   '28016800000::  BUTTERFLY  PORK CHOPS LB',
#   '84023020002::AM CH MILK 2% GALN 128 OZ',
#   '2412601022::BUNNY HAMBURGER BUNS 8 CT',
#   '2412600908::BUNNY HOT DOG BUNS 12 OZ 8 CT'],
#  ['9990090836::NESTLE CRUNCH BARS 1.55 OZ',
#   '2781500111::ECKRICH ORIG SKNLS SAUSAGE 14 OZ.',
#   '2781500111::ECKRICH ORIG SKNLS SAUSAGE 14 OZ.',
#   '84023020002::AM CH MILK 2% GALN 128 OZ'],
#  ['7003861277::AS DRESSING ITALAIN 16 OZ',
#   '7003861277::AS DRESSING ITALAIN 16 OZ'],
#  ['28504500000::DELI BEVERAGE EACH',
#   '4223831223::HARIBO SOUR GOLDBEAR 7 OZ',
#   '7940034218::DOVE DRY SP CL ESSNS 3.8 OZ',
#   '3283::APPLE WA HONEYCRISP LB'],
#  ['61126900164::RB SUMMER EDITION JUNEBERRY 12 OZ',
#   '28556300000::BROWNIES EACH',
#   '77098102023::PECAN TARTS 9.2 OZ'],
#  ['28842400000::SELECT ANGUS NY STRIP EA',
#   '65955471110::POTATO IDAHO MINUTE BAKER EA',
#   '65955471110::POTATO IDAHO MINUTE BAKER EA',
#   '28842400000::SELECT ANGUS NY STRIP EA',
#   '28517000000::MISC HOT FOODS EACH',
#   '28890000000::FRSH DILL CHKN SALAD',
#   '3560081300::KY LEG APPLWOD SMK SLCED BACON 1 LB',
#   '65955471110::POTATO IDAHO MINUTE BAKER EA',
#   '2840075904::DORITOS TANGY GLDN SRIR 9.25 OZ',
#   '2840051631::DORITOS COOL RANCH 9.25 OZ',
#   '2840051631::DORITOS COOL RANCH 9.25 OZ'],
#  ['81000344023::COMET REGULAR POWDER 21 OZ',
#   '7003832640::AS PAPER PLATES 100 CT',
#   '7003861361::BST CH PLASTIC CUTLERY 144 CT',
#   '8290111689::SPRAYR HOUSEHOLD16OZ ACE',
#   '84653800891::KITCHEN SCRUBBER EA',
#   '5037500024::WRENCH SERVICE DISPOSER',
#   '7003866893::AS LS REG BLEACH 128 OZ',
#   '1980000117::DRANO MAX CLOG REMOVR 32 OZ',
#   '81000344023::COMET REGULAR POWDER 21 OZ'],
#  ['7003836554::AS CULTURED SOUR CREAM 16 OZ',
#   '2100077436::KR BLUE BX MAC & CHS 5 CT 36.25 OZ',
#   '7003858591::BST CH PRUNE JUICE 64 OZ',
#   '7003858591::BST CH PRUNE JUICE 64 OZ',
#   '7273023117::PRAIRIE FARMS SKIM MILK 128 OZ',
#   '7003867439::BST CH BLK PEP CHIP 7.75 OZ',
#   '7003836554::AS CULTURED SOUR CREAM 16 OZ'],
#  ['3010010068::KEB CLUB MULTI GRAIN 12.7 OZ',
#   '3010010057::KEB CLUB ORIGINAL 13.7 OZ'],
#  ['7003867128::BST CH CHED SC CHIPS 7.75 OZ',
#   '7184030012::DEAN FRNCH ONION DIP',
#   '7480601500::LIL HUG ASST. FLAVOR 20PK 20 CT',
#   '4156500024::PACE PICANTE SCE MEDIUM 24 OZ',
#   '7480601503::LIL HUG BERRY BLEND 8 OZ',
#   '1128400303::JJ BERRY FRT SNK PIE 4 OZ',
#   '1128400303::JJ BERRY FRT SNK PIE 4 OZ',
#   '2840006740::JAR DIP TOSTITOS SLSA QUESO MED 23 OZ',
#   '7184030008::DEAN RANCH DIP 16 OZ',
#   '7003867102::AL SAVE WAVY POT CHP 13 OZ',
#   '7003867128::BST CH CHED SC CHIPS 7.75 OZ',
#   '7003867100::AL SAVE BBQ POT CHPS 12.5Z'],
#  ['4300000953::COOL WHIP ORIGINAL TOPPING 8 OZ',
#   '7273073552::PF SHERBET ORANGE 64 OZ',
#   '7273071934::PF PREMIUM MOOSE TRACKS 48 OZ'],
#  ['7003835485::BST CH STHRN STYLE HASH BROWN 32 OZ',
#   '2100000198::KR CHNK NY SHARP CHDR 8 OZ',
#   '2100000198::KR CHNK NY SHARP CHDR 8 OZ',
#   '2100000198::KR CHNK NY SHARP CHDR 8 OZ',
#   '2100061223::KR PHIL CREAM CHSE BAR 8 OZ',
#   '2100061223::KR PHIL CREAM CHSE BAR 8 OZ',
#   '2100061223::KR PHIL CREAM CHSE BAR 8 OZ',
#   '2100061223::KR PHIL CREAM CHSE BAR 8 OZ',
#   '66559100021::BL HOG BBQ SQZE CHAMP 24 OZ',
#   '2100000198::KR CHNK NY SHARP CHDR 8 OZ',
#   '7342000011::DAISY SOUR CREAM 16 OZ',
#   '9504500007::LOLLIPOP DSP REFIL 1.1OZ 1.1 OZ',
#   '85352200031::ENJOY LIFE CHOC CHUNK SEMI 10 OZ'],
#  ['3077212078::TIDE SMP HEC REFRESH BRZ 117 OZ',
#   '7778200839::JNSNVL SWT ITALIAN JVILLEBRT',
#   '84023020006::AM CH MILK 2% HGAL 64 OZ',
#   '7273029287::PRAIRIE FARMS ICED COFFE 64 OZ',
#   '7080021635::SM APWD BCN PK LN FL 27.2 OZ',
#   '5963500195::FURLANI PARMESAN GARLIC TOAST 6 CT',
#   '2781530061::ECKRICH BEEF SMOKED LINKS ERCH',
#   '1510000163::CRMT THIN SPAGHETTI 16 OZ',
#   '1510000007::CRMT SM ELBOW MAC 16 OZ',
#   '88810915002::HOST FROSTED DONETTES MINI DONUTS 10.75',
#   '3560081300::KY LEG APPLWOD SMK SLCED BACON 1 LB',
#   '7003858242::BST CH SHRED FANCY ITALIAN CHEESE 8 OZ',
#   '5300007636::BDN SLC NAT SMK PROV 6 OZ',
#   '7003837281::BST CH GR A JMBO EGG 1 DZ',
#   '2412601027::BUNNY SOFT TWIST 16 OZ',
#   '2412601022::BUNNY HAMBURGER BUNS 8 CT',
#   '28525900000::LIVERS EACH',
#   '28525900000::LIVERS EACH',
#   '3415::POTATO RUSSET 5 LB',
#   '1200017195::DIET PEPSI 16.9 OZ 6 PK'],
#  ['89661200040::STAND ANNUAL PLANTS 4 IN',
#   '3338396941::KIMBERLY FERN BIN 10 IN',
#   '920051970::GRADUATION CARD',
#   '89661201204::FLOWER BEDDING 4 CELL EA'],
#  ['89661200002::VEGETABLE BEDDING 4 CELL EA',
#   '28562200000::HEART SHAPED CAKE EACH',
#   '4388::MANDARINS 3  LB',
#   '710::FLORAL HANGING BASKET',
#   '497::MISC BALLOON ORDER'],
#  ['9451400012::XTRA LQ MT RAIN 116L 139.2 OZ',
#   '84023020001::AM CH MILK WHOLE GAL 128 OZ',
#   '7800011316::SUNKIST  ORANGE 12 PK'],
#  ['7084701247::MONSTER ZERO ULTRA 16 OZ',
#   '7084701247::MONSTER ZERO ULTRA 16 OZ',
#   '1600030590::BC TRIPLE BERRY MUFFIN MIX 6.5 OZ',
#   '4032::WATERMELON  SEEDLESS',
#   '6827490021::NPL PURIFIED WATER 6 PK 101.4 OZ',
#   '78616200355::VITA WATER DRAGONFRUIT 6 PK 101.4 OZ'],
#  ['79042923270::VN SALT WATER TAFFY 11 OZ',
#   '2430004313::NUTTY BUDDY CREM PIES 6 CT 16.91 OZ',
#   '700::MISC FLORAL GIFTWARE',
#   '4017::APPLE WA GRANNY SMITH LB',
#   '28525900000::LIVERS EACH',
#   '28903200000::WEDGES BY COUNT EA',
#   '28525900000::LIVERS EACH',
#   '3760084296::HRML F/C BACON 10.5 OZ',
#   '2222821040::BUBBLE BLASTER RED EACH',
#   '2430004313::NUTTY BUDDY CREM PIES 6 CT 16.91 OZ',
#   '28903100000::STANDARD SIDE LB',
#   '2840067901::FUNYUNS 10CT 7.5 OZ',
#   '61126942672::RED BULL REGULAR 12 PK 100.8 OZ',
#   '28903100000::STANDARD SIDE LB',
#   '2840070572::FRITO LAY CHESTERS CHEES 4.25 OZ',
#   '7480600160::BIG HUG PUNCH 16 OZ',
#   '7480600160::BIG HUG PUNCH 16 OZ',
#   '88331509028::TUM E YUMMIE APPLE 10.1 OZ'],
#  ['7273026203::PRAIRIE FARMS WHOLE CHOC 64 OZ',
#   '4900004284::COKE ZERO SUGAR 24 PK 12 OZ 288 OZ',
#   '28564800000::YEAST DONUTS 6 CT',
#   '1200050408::MOUNTAIN DEW .5L 6 PK',
#   '1200081331::FRAPPUCCINO VANIILA 13.7 OZ 13.7 OZ 13.7',
#   '9147504189::MILO SWEET TEA GAL'],
#  ['28540900000::GOURMET COOKIE TRAY EA', '28662700000::BUTTER PECAN FUDGE LB'],
#  ['65853339394::RST STEAK SIRLOIN GAR N HERB 12 OZ',
#   '65853339394::RST STEAK SIRLOIN GAR N HERB 12 OZ',
#   '8259272715::NAKED BLUE MACHINE  SMOOTHIE 15.2 OZ',
#   '8259272615::NAKED  RED MACHINE 15.2 OZ',
#   '3560007301::KL DICED HAM 8 OZ',
#   '28845200000::PICK 5 MISC 24.99 EA',
#   '7146401624::BH PEACH PARFAIT 15.2 OZ',
#   '4246::STRAWBERRIES   1 LB',
#   '4246::STRAWBERRIES   1 LB',
#   '18473900106::HINT WATER PEACH 16 OZ',
#   '7146432750::BH PROTEIN PLUS STRAWBRY 450 ML',
#   '1657195210::SI BLACK CHERRY 17 OZ',
#   '1340951598::SWT RAY BBQ HAWAIIAN 18 OZ',
#   '18473900127::HINT WATER PINEAPPLE 16 OZ',
#   '18473900104::HINT WATER CRISP APPLE 16 OZ',
#   '18473900004::HINT WATER RASPBERRY 16 OZ',
#   '1340951598::SWT RAY BBQ HAWAIIAN 18 OZ',
#   '7003861683::BST CH SODA PEACH 67.6 OZ',
#   '7524320111::MAYFIELD BUTTER PECAN 48 OZ',
#   '7524320655::MAYFIELD EX MOOSE TRACKS 48 OZ'],
#  ['29999500000::MG POTTING MIX S',
#   '8290172434::ACE TOP SOIL 40# EA',
#   '3224756523::MG POTTING MIX SOIL 2 CF EA',
#   '29999500000::MG POTTING MIX S'],
#  ['85658400322::PARADISE RTC POPCORN CHICKEN 4#',
#   '85658400324::PK READY TO COOK FAST FOOD NUGGET 4#',
#   '2529300099::SILK PURE ALMOND VAN 64 OZ',
#   '81829001281::CHOB STRW 4PK 4 PK',
#   '7003837286::BST CH GRD A LRG 18P EGG 1.5 DZ'],
#  ['29999500000::FLWR VEG GARD SO',
#   '29999500000::FLWR VEG GARD SO',
#   '29999500000::FLWR VEG GARD SO',
#   '29999900000::FLWR VEG GARD SO',
#   '29999900000::FLWR VEG GARD SO',
#   '29999500000::FLWR VEG GARD SO',
#   '29999900000::FLWR VEG GARD SO',
#   '29999900000::FLWR VEG GARD SO',
#   '29999900000::FLWR VEG GARD SO',
#   '29999900000::FLWR VEG GARD SO',
#   '29999500000::FLWR VEG GARD SO',
#   '3224734513::FLWR VEG GARD SOIL 1 CF',
#   '29999500000::FLWR VEG GARD SO'],
#  ['4330161204::SONIC FRIES 28 OZ',
#   '7045900558::NY TEX GARL TOAST 8 CT',
#   '4280011836::TOTINO COMBO PZ RLS 48.85 OZ',
#   '4300002825::KA JAMMERS TROPICAL 10PK 60 OZ',
#   '7045900558::NY TEX GARL TOAST 8 CT',
#   '4400006377::RITZ FRESH STACKS PARTY SIZE 23.7 OZ',
#   '4178900232::MAR RAMEN 12 PK BEEF 36 OZ',
#   '5150004817::SMKR UNCRUSTABLES GRAPE 10 CT',
#   '5150004817::SMKR UNCRUSTABLES GRAPE 10 CT',
#   '7615023252::ACT II BUTTER LOVERS POPCORN 6 CT 16.5 O',
#   '7615023252::ACT II BUTTER LOVERS POPCORN 6 CT 16.5 O',
#   '4280011836::TOTINO COMBO PZ RLS 48.85 OZ',
#   '2740069402::CNTRY CROCK ORIG SPRD 67.5 OZ',
#   '2412601027::BUNNY SOFT TWIST 16 OZ',
#   '4400006025::NAB OREO DS FAM SZ 18.71 OZ',
#   '4400006025::NAB OREO DS FAM SZ 18.71 OZ',
#   '2412601027::BUNNY SOFT TWIST 16 OZ',
#   '2430004146::LD ZEBRA CAKE 13 OZ',
#   '2430004146::LD ZEBRA CAKE 13 OZ',
#   '2430004302::BIG PK HONEY BUNS 21 OZ',
#   '2430004302::BIG PK HONEY BUNS 21 OZ',
#   '1510000042::CRMT THIN SPAG 32 OZ',
#   '5100001588::PREGO PASTA SC TRADITIONAL 67 OZ',
#   '5100001588::PREGO PASTA SC TRADITIONAL 67 OZ',
#   '28030500000::FP GROUND CHUCK LEAN LB',
#   '28030500000::FP GROUND CHUCK LEAN LB',
#   '28030500000::FP GROUND CHUCK LEAN LB',
#   '2781530042::ECKRICH SMKD SAUSAGE 14 OZ.',
#   '2781530042::ECKRICH SMKD SAUSAGE 14 OZ.',
#   '4660003386::LMKR PEP PIZZA 3.3 OZ.',
#   '4660003386::LMKR PEP PIZZA 3.3 OZ.',
#   '4660003386::LMKR PEP PIZZA 3.3 OZ.',
#   '4660003386::LMKR PEP PIZZA 3.3 OZ.',
#   '2430004350::FUDGE ROUNDS 30 OZ',
#   '2430004350::FUDGE ROUNDS 30 OZ',
#   '2430004331::COSMIC BROWNIES 30 OZ',
#   '2430004310::BP PNB CREME PIES 18.39 OZ',
#   '2430004313::NUTTY BUDDY CREM PIES 6 CT 16.91 OZ',
#   '2430004309::LDS BP ZEBRA CAKES 6 CT 18.4 OZ',
#   '2430004330::LD BIG SWISS ROLLS 20 OZ',
#   '2430004330::LD BIG SWISS ROLLS 20 OZ',
#   '4079::CAULIFLOWER EA',
#   '4079::CAULIFLOWER EA',
#   '28333600000::BROCCOLI  CROWNS LB',
#   '3415::POTATO RUSSET 5 LB',
#   '3415::POTATO RUSSET 5 LB',
#   '7003866358::BST CH WHITE COOKIE 13 OZ',
#   '7003866357::BST CH BLUE FRST COOKIE 13 OZ',
#   '4330161204::SONIC FRIES 28 OZ',
#   '4330161204::SONIC FRIES 28 OZ'],
#  ['7273010001::PRAIRIE FARMS BUTTER QTR 16 OZ',
#   '7069002365::FSHR CHOPPED WALNUTS\xa0 10 OZ',
#   '7003837280::BST CH GR A LARGE EGG 1 DZ',
#   '7003834440::AL SAVE GRAN SUGAR 4 LB',
#   '7273025204::PF BUTTERMILK HGL 64 OZ',
#   '1330020441::PILLSBURY FLOUR ALL PURPOSE 5 LB',
#   '74938492002::JF UTILITY PANS 2 CT',
#   '3320001110::A&H BAKING SODA 16 OZ',
#   '7069002364::FSHR WALNUT HALVES \xa0 10 OZ',
#   '21399900000::GOT Markdown - Cold Deli',
#   '7003866855::BST CH RSN WLNT OATS 8 CT',
#   '2900000803::FLEIS MOVE OVER BTR SPREAD 10.05 OZ'],
#  ['1200014208::PURE LEAF UNSWEET BLACK BREWED TEA 64 OZ',
#   '2460001003::MORT IODIZED SALT 26 OZ',
#   '4480000103::SWT N LOW COOKING & BAKING 8 OZ',
#   '1200014208::PURE LEAF UNSWEET BLACK BREWED TEA 64 OZ'],
#  ['2000010745::GG MSHRM PIECES STEMS 4 OZ',
#   '2100005921::KR SHRD MOZZARELLA 24 OZ',
#   '7590000205::BE ITAL ROLL FZ 1LB'],
#  ['89661201204::FLOWER BEDDING 4 CELL EA',
#   '89661201204::FLOWER BEDDING 4 CELL EA',
#   '89661201204::FLOWER BEDDING 4 CELL EA',
#   '89661201204::FLOWER BEDDING 4 CELL EA'],
#  ['5200001122::V CAMP PORK N BEANS 15 OZ',
#   '5200001122::V CAMP PORK N BEANS 15 OZ',
#   '5200001122::V CAMP PORK N BEANS 15 OZ',
#   '4065::PEPPER GREEN EA',
#   '28028700000::GROUND BEEF LB',
#   '3760029538::CHI CHI SALSA MILD 16 OZ',
#   '5200001122::V CAMP PORK N BEANS 15 OZ'],
#  ['79233876146::KF PLLD PORK W/BBQSC 16 OZ',
#   '65955471110::POTATO IDAHO MINUTE BAKER EA',
#   '65955471110::POTATO IDAHO MINUTE BAKER EA',
#   '1800000182::PIL GRANDS BISCUITS HOMESTYLE BTTRMK 16.',
#   '4062::CUCUMBER EA',
#   '1800000182::PIL GRANDS BISCUITS HOMESTYLE BTTRMK 16.',
#   '7273026406::PRAIRIE FARMS CHOCOLATE MILK 16 OZ',
#   '4900005537::COKE 1.25 LTR',
#   '2998837118::CNTRY BOB MARINADE BBQ GRILL 18 OZ',
#   '65955471110::POTATO IDAHO MINUTE BAKER EA',
#   '84023020002::AM CH MILK 2% GALN 128 OZ',
#   '7143000965::DOLE GREENER SELECT 11 OZ',
#   '28511600000::KR VIRGINIA HAM EACH',
#   '28502400000::HAM SALAD EACH'],
#  ['1200050405::PEPSI .5 LTR 6 PK',
#   '1200050405::PEPSI .5 LTR 6 PK',
#   '1200050405::PEPSI .5 LTR 6 PK',
#   '28561200000::JUMBO CINNAMON EACH',
#   '2430004168::L D CHOC CK Z 12 OZ',
#   '1200050405::PEPSI .5 LTR 6 PK'],
#  ['7003834790::BST CH CUT GREEN BEANS 14.5 OZ',
#   '7539106001::ARGENTINE RAW 16 20 2 LB.',
#   '7539106001::ARGENTINE RAW 16 20 2 LB.',
#   '7539106001::ARGENTINE RAW 16 20 2 LB.',
#   '84186689452::YOU ARE MY SUNSHINE BQT BQT',
#   '7003834790::BST CH CUT GREEN BEANS 14.5 OZ',
#   '7003834790::BST CH CUT GREEN BEANS 14.5 OZ'],
#  ['3010010055::KEB TOWNHOUSE ORIG 13.8 OZ',
#   '3010010055::KEB TOWNHOUSE ORIG 13.8 OZ',
#   '1800081773::PIL DELUXE CHOC CHIP CKY 16 OZ',
#   '1800081775::PIL COOKIE DOUGH REESES PIECES 16 OZ',
#   '7199800190::TONY CH MORE SPICE CREOLE SSNG 7 OZ',
#   '5210003004::MC CRSE GRND PEPR 1.5 OZ',
#   '5190001609::LOF PREM BRN SGR HAM 16 OZ',
#   '88742200000::HAPPY EGG FREE RANGE 12 CT',
#   '7003837280::BST CH GR A LARGE EGG 1 DZ',
#   '2412601435::BUNNY HONEY WHEAT 20 OZ',
#   '2412601435::BUNNY HONEY WHEAT 20 OZ',
#   '7790011633::JD SAGE ROLL SAUSAGE 1L',
#   '960000003545::CPN: $1 OFF (2) Pillsbury Participating  Item',
#   '4410019093::PLANET OAT UNSWT XTRA CREAMY 52 OZ',
#   '7273021110::PRAIRIE FARM WHOLE MILK 128 OZ'],
#  ['1200010205::MOUNTAIN DEW CODE RED 16.9 OZ 6 PK',
#   '28562200000::HEART SHAPED CAKE EACH',
#   '1200081119::PEPSI WILD CHERRY 16.9 OZ 6 PK',
#   '1200050408::MOUNTAIN DEW .5L 6 PK',
#   '1200050405::PEPSI .5 LTR 6 PK'],
#  ['1420024355::S FLF STF WTRMLN PEG 2.1 OZ',
#   '7172087775::S DOTS LEMONADE TBX 6.5 OZ',
#   '7800008240::DR PEPPER 20 OZ'],
#  ['2100000014::KR PHIL CREAM CHEESE ORIG 8 OZ',
#   '2840019914::LAYS CLASSIC 8 OZ',
#   '28607300000::MTLF MSHD POTATO EACH',
#   '1330076150::PIL FRSTNG CREAM CHEESE 16 OZ',
#   '4900004584::COCA COLA SODA ZERO SUGAR 6 PK 101.4 OZ',
#   '4900004584::COCA COLA SODA ZERO SUGAR 6 PK 101.4 OZ',
#   '4900004584::COCA COLA SODA ZERO SUGAR 6 PK 101.4 OZ',
#   '1330076150::PIL FRSTNG CREAM CHEESE 16 OZ',
#   '2700037243::ORV RED CLSC BTR 3 CT',
#   '64420941065::DH MIX SIG SPICE CAKE 15.25 OZ',
#   '9990083720::NSTL BABY RUTH FUNSZ LDB 10.2 OZ',
#   '7255400153::NESTLE DRUMSTICK VARIETY 8 CT 36.8 OZ'],
#  ['7003830346::AS MARSHMALLOWS 16 OZ',
#   '28000600000::FRESH GROUND CHUCK 80/20 LB',
#   '7003831131::BC HOT DOG BUNS 8 CT 11 OZ',
#   '2412600899::BUNNY 4 PLAIN HAMBURGER 12 PK 12 PK',
#   '2100004490::VEL JALAPENO SINGLES 12 OZ',
#   '4166::ONIONS SWEET LB',
#   '7003831131::BC HOT DOG BUNS 8 CT 11 OZ',
#   '7003830960::AS HONEY GRAHAM 14.4 OZ',
#   '3400017038::HRSH MILK CHOC XL BAR 4.4 OZ'],
#  ['4178027187::UTZ SOUR CREAM & ONION RILE CHIP 7.75 OZ',
#   '28532200000::HOT DOG BUNS 8 PK',
#   '4900004086::COKE ZERO 20 OZ',
#   '28030500000::FP GROUND CHUCK LEAN LB',
#   '2100001863::KR NAT SLC SHRP CHDR 8 OZ',
#   '28030500000::FP GROUND CHUCK LEAN LB',
#   '7778200787::JNSNVL  ORIG BRATS 16 OZ',
#   '7778200787::JNSNVL  ORIG BRATS 16 OZ',
#   '2412600899::BUNNY 4 PLAIN HAMBURGER 12 PK 12 PK',
#   '4178027176::UTZ HONEY BAR BQ CHIP 7.75 OZ'],
#  ['7003866963::BST CH PIE SHELL 2PK 10 OZ',
#   '3560081323::KL B BACON 16 OZ',
#   '4246::STRAWBERRIES   1 LB',
#   '4140901731::CONCORD STRWBRY GLZ/PCH 16 OZ',
#   '3560081300::KY LEG APPLWOD SMK SLCED BACON 1 LB',
#   '3560081300::KY LEG APPLWOD SMK SLCED BACON 1 LB',
#   '3000065070::PMC COMPLETE PANCAKE MIX 32 OZ',
#   '7027223202::REDI WIP REAL CREAM TOP 6.5 OZ',
#   '7020052344::MARZ CHOC FRUIT DIP 13.5 OZ',
#   '2100061223::KR PHIL CREAM CHSE BAR 8 OZ',
#   '64420979129::MB ORIGINAL SYRUP 24 OZ',
#   '7680000696::LEND CINN RAISIN SWIRL BAGELS 17.1 OZ',
#   '4246::STRAWBERRIES   1 LB',
#   '4246::STRAWBERRIES   1 LB'],
#  ['28842600000::CHOICE ANGUS BNLS SIRLOIN LB',
#   '28086500000::SELECT NY STRIP STEAKS LB',
#   '28140000000::PREMIUM RESERVE RIBEYE STEAK LB',
#   '28310700000::ASPARAGUS BNCH EA',
#   '4460032071::KNGFRD BRIQUETS ORIGINAL 8 LB',
#   '28066400000::PICK 5 BNLS COUNTRY RIBS LB',
#   '7080021635::SM APWD BCN PK LN FL 27.2 OZ'],
#  ['7192170282::TOMBSTONE 5 CHEESE 19.3 OZ',
#   '2100006062::TB DIABLO SAUCE 7.5 OZ',
#   '4011::BANANA LB',
#   '28136100000::SF 7 TRAY CF TNDR LB',
#   '7003837284::BST CH GR A MED EGGS 1 DZ',
#   '28016800000::  BUTTERFLY  PORK CHOPS LB',
#   '28016800000::  BUTTERFLY  PORK CHOPS LB',
#   '7192170282::TOMBSTONE 5 CHEESE 19.3 OZ',
#   '7192170282::TOMBSTONE 5 CHEESE 19.3 OZ',
#   '7192170282::TOMBSTONE 5 CHEESE 19.3 OZ'],
#  ['2430004333::LD BIG PACKS FROSTED DONUTS 16.91 OZ',
#   '5440000005::A1 SAUCE ORIGINAL 10 OZ',
#   '7110000021::HVR DRESSING SQZ ORIG 20 OZ',
#   '2430004313::NUTTY BUDDY CREM PIES 6 CT 16.91 OZ',
#   '5210003639::MC GRILL MATE BRAZIL STEAKHOUSE 2.12 OZ',
#   '4660055005::ECK SMKD LINK SAUSAGE 14 OZ',
#   '4660055003::ECK CHEDDAR SMK LINKS 14 OZ',
#   '1590006337::BAR S BUNLENGTH  FRANKS 12 OZ.',
#   '2430004301::OATMEAL CREME PIES 36 OZ',
#   '2430004316::LD MUFFINS CHOCOLATE CHIP 5 CT 12.67 OZ',
#   '28842400000::SELECT ANGUS NY STRIP EA',
#   '1590006337::BAR S BUNLENGTH  FRANKS 12 OZ.',
#   '28842400000::SELECT ANGUS NY STRIP EA',
#   '28842400000::SELECT ANGUS NY STRIP EA',
#   '7143000965::DOLE GREENER SELECT 11 OZ',
#   '22599900000::GOT Markdown - Wic Produce',
#   '3415::POTATO RUSSET 5 LB',
#   '7800001181::Dt 7up 12pk 12oz  Can  Cs 12 PK',
#   '7181703330::DIET BIG  RED 12 PK',
#   '85402500845::ICEE BLUE RASPBERRY 6 OZ'],
#  ['28536100000::MISC HOT CHICKEN EACH',
#   '2781500123::ECKRICH CHEESE FRANKS 12 OZ',
#   '2781500123::ECKRICH CHEESE FRANKS 12 OZ',
#   '7003834785::AS CUT GREEN BEANS 14.5 OZ',
#   '7920071783::SWTRTS MINI CHEWY 12 OZ',
#   '7003834785::AS CUT GREEN BEANS 14.5 OZ',
#   '28903100000::STANDARD SIDE LB'],
#  ['2100005441::KR SHRD 2% MEX 4 CHS 7 OZ',
#   '5380010961::LINDSAY OLIVE RIPE SLICED 2.25 OZ'],
#  ['2100005509::KR SHRD MILD CHEDDAR 8 OZ',
#   '7740012723::BUDDIG SLICED HAM 2.0 OZ',
#   '7740012723::BUDDIG SLICED HAM 2.0 OZ',
#   '2100005509::KR SHRD MILD CHEDDAR 8 OZ',
#   '7740012853::BUDDIG HONEY HAM 2.0 OZ',
#   '28030500000::FP GROUND CHUCK LEAN LB',
#   '7740012853::BUDDIG HONEY HAM 2.0 OZ',
#   '7740012853::BUDDIG HONEY HAM 2.0 OZ',
#   '7740012853::BUDDIG HONEY HAM 2.0 OZ',
#   '7740012723::BUDDIG SLICED HAM 2.0 OZ',
#   '4660000090::ECK ORIG FRANKS 12 OZ',
#   '2781500123::ECKRICH CHEESE FRANKS 12 OZ',
#   '2781500123::ECKRICH CHEESE FRANKS 12 OZ',
#   '4660000090::ECK ORIG FRANKS 12 OZ',
#   '7273029145::PRAIRIE FARMS ORANGE JUICE 128 OZ',
#   '2100005495::KR SHRD MOZZARELLA 8 OZ',
#   '2100005495::KR SHRD MOZZARELLA 8 OZ'],
#  ['7684714435::GRIPPOS SWEET MAUI ONION 2.75 OZ',
#   '28563200000::8 CT ICED SUGAR COOKIES 8 CT',
#   '28563200000::8 CT ICED SUGAR COOKIES 8 CT',
#   '9504500007::LOLLIPOP DSP REFIL 1.1OZ 1.1 OZ',
#   '3560081300::KY LEG APPLWOD SMK SLCED BACON 1 LB',
#   '88810915003::HOST MINI DONUT DBL CHOC 11.25 OZ',
#   '3560081300::KY LEG APPLWOD SMK SLCED BACON 1 LB',
#   '3560081300::KY LEG APPLWOD SMK SLCED BACON 1 LB',
#   '28619000000::ROSE CAKE 8 IN',
#   '88810925465::HOST DONETTES OLD FASH 10.5 OZ',
#   '28562200000::HEART SHAPED CAKE EACH',
#   '28551400000::CHERRY STRUDEL BITES EACH',
#   '28888500000::CREAM CHEESE CINN ROLL 4CT',
#   '7080004103::JAMESTOWN BRND SLCD BCN 1 LB',
#   '7080004103::JAMESTOWN BRND SLCD BCN 1 LB',
#   '7684715185::GRIPPOS SWEET MAUI ONION 8 OZ'],
#  ['4608::GARLIC LB',
#   '7003860976::BST CH MOZZARELLA CHEESE STICKS 8 OZ',
#   '81565200215::PETE GERRY PAST RAISED LG EGGS 1 DZ',
#   '28583700000::ITALIAN CHS SUB ROLL 4 CT',
#   '28323000000::CORN BI COLOR 4 PK',
#   '28309500000::BEANS GREEN LB'],
#  ['28562200000::HEART SHAPED CAKE EACH',
#   '9147504189::MILO SWEET TEA GAL',
#   '4900000044::COKE CLASSIC 20 OZ',
#   '1200017174::DIET PEPSI 20 OZ',
#   '9147540799::MILO UNSWEET TEA GAL',
#   '4000000405::M&M TWIX CARAMEL KING 3.02 OZ',
#   '4246::STRAWBERRIES   1 LB',
#   '28661500000::CUPCAKE W PICK 6 CT'],
#  ['2840006408::TOSTITOS SCOOPS 10 OZ',
#   '3400000239::HRSH COOKIE&CRM BAR 1.55 OZ',
#   '4600081566::OEP ORIGINAL TACO SSNG MIX 6.25 OZ',
#   '1590013401::BAR/S MEAT FRANKS 12 OZ',
#   '28000600000::FRESH GROUND CHUCK 80/20 LB',
#   '7003866676::BST CHCE ROUND TOP 20 OZ'],
#  ['64220556006::99% LN GR TKYBRST 1LB',
#   '64220556006::99% LN GR TKYBRST 1LB',
#   '64220556006::99% LN GR TKYBRST 1LB',
#   '28048700000::THIN CUT PORK STEAK LB',
#   '28310700000::ASPARAGUS BNCH EA',
#   '64220556006::99% LN GR TKYBRST 1LB',
#   '64220556006::99% LN GR TKYBRST 1LB'],
#  ['3224756523::MG POTTING MIX SOIL 2 CF EA',
#   '29999500000::MG POTTING MIX S',
#   '3224756523::MG POTTING MIX SOIL 2 CF EA',
#   '29999500000::MG POTTING MIX S'],
#  ['21399900000::GOT Markdown - Cold Deli',
#   '21399900000::GOT Markdown - Cold Deli',
#   '78113870901::OTB CHUNKY MILD 16 OZ',
#   '78113870901::OTB CHUNKY MILD 16 OZ',
#   '28547700000::ROTIS CHICKEN SALAD EACH'],
#  ['1200018119::BUBLY BLACKBERRY 12 OZ 8 PK 96 OZ',
#   '7192192580::DIG STUFFED PEPPERONI 22.2 OZ',
#   '3800039103::KEL HONEY SMACKS 15.3 OZ',
#   '84023020006::AM CH MILK 2% HGAL 64 OZ'],
#  ['3121::PEPPER ORANGE EA',
#   '4065::PEPPER GREEN EA',
#   '75166677155::TOMATOES NATURE  SWEET CHERUB 10 OZ',
#   '2100004489::VEL SHRP CHDR SNGLS 12 OZ',
#   '4166::ONIONS SWEET LB',
#   '5300000054::BDN CHNK XSHP CHDR 8 OZ',
#   '4061::LETTUCE  EA',
#   '5300000063::BDN CHNK COJACK 8 OZ',
#   '84037090010::VEL SHREDS MEXICAN 8 OZ',
#   '7152416985::LA PREF FAJITA SEAS 1.25 OZ',
#   '7152416985::LA PREF FAJITA SEAS 1.25 OZ',
#   '75166677155::TOMATOES NATURE  SWEET CHERUB 10 OZ',
#   '5410097766::OPEN PIT BBQ SC HICKORY 18 OZ',
#   '5410097766::OPEN PIT BBQ SC HICKORY 18 OZ',
#   '7152416985::LA PREF FAJITA SEAS 1.25 OZ',
#   '2150004800::LAWRY MARINADE MESQUITE 12 OZ',
#   '5410097766::OPEN PIT BBQ SC HICKORY 18 OZ',
#   '4132100635::WISHBONE DRSNG RUSSIAN 15 OZ',
#   '89660600206::BACKYARD ORIG SEASON 7 OZ',
#   '2150004800::LAWRY MARINADE MESQUITE 12 OZ',
#   '7110000668::HVR DRESSING ORIG RANCH 36 OZ',
#   '7273031515::PRAIRIE FARM COTTAGE CH 24 OZ',
#   '7184030012::DEAN FRNCH ONION DIP',
#   '3450015181::LOL BUTTER HALF STICKS 16 OZ',
#   '28512600000::KR ROTISS CHKN BRST EACH',
#   '28546300000::KRETSCHMAR SUN DRIED TOM TKY EACH',
#   '7003861336::BST CH TORTILLA BURRITO 8 CT',
#   '1800000013::PIL CRSNT SWT HAWAII 8 OZ',
#   '1800000501::PIL CINNAMON ROLLS ORIGINAL 12.4 OZ',
#   '1800000501::PIL CINNAMON ROLLS ORIGINAL 12.4 OZ',
#   '1800000013::PIL CRSNT SWT HAWAII 8 OZ',
#   '2412601435::BUNNY HONEY WHEAT 20 OZ',
#   '2412601027::BUNNY SOFT TWIST 16 OZ',
#   '2840031041::LAYS CLASSIC PRTY SZ 13 OZ',
#   '7003831532::BST CH FRUIT COCKTAIL 15.25 OZ',
#   '7003831532::BST CH FRUIT COCKTAIL 15.25 OZ',
#   '9047821621::JARRITOS BTL MANDARIN 1.5 LTR',
#   '9047821625::JARRITO LIME SODA 1.5 LT',
#   '84023020001::AM CH MILK WHOLE GAL 128 OZ',
#   '7003836386::BST CH CANOLA OIL 48 OZ',
#   '7003836386::BST CH CANOLA OIL 48 OZ',
#   '3415::POTATO RUSSET 5 LB',
#   '3415::POTATO RUSSET 5 LB',
#   '7003858503::POTATO BST CH GOLD 5 LB',
#   '960000003545::CPN: $1 OFF (2) Pillsbury Participating  Item',
#   '4689::PEPPER YELLOW EA',
#   '4088::PEPPER  RED EA'],
#  ['4280011400::TOTINO PEPPERONI PIZZA 10.2 OZ',
#   '4280011520::TOTINO 3 CHEESE PIZZA 9.8 OZ',
#   '4280011520::TOTINO 3 CHEESE PIZZA 9.8 OZ',
#   '4280011400::TOTINO PEPPERONI PIZZA 10.2 OZ',
#   '4280011600::TOTINO COMBINATION PIZZA 10.7 OZ',
#   '4280011600::TOTINO COMBINATION PIZZA 10.7 OZ',
#   '4280011600::TOTINO COMBINATION PIZZA 10.7 OZ',
#   '4280010700::TOTINO SUPREME PIZZA 10.9 OZ',
#   '4280011400::TOTINO PEPPERONI PIZZA 10.2 OZ',
#   '4280011520::TOTINO 3 CHEESE PIZZA 9.8 OZ',
#   '28136200000::SF 7 TRAY CF DRUMS LB',
#   '4280010700::TOTINO SUPREME PIZZA 10.9 OZ',
#   '4280010700::TOTINO SUPREME PIZZA 10.9 OZ',
#   '28136200000::SF 7 TRAY CF DRUMS LB',
#   '28136200000::SF 7 TRAY CF DRUMS LB',
#   '28136000000::SF 7 TRAY CF THIGH LB',
#   '28136000000::SF 7 TRAY CF THIGH LB',
#   '28136000000::SF 7 TRAY CF THIGH LB',
#   '4660000090::ECK ORIG FRANKS 12 OZ',
#   '4660000090::ECK ORIG FRANKS 12 OZ',
#   '4660000090::ECK ORIG FRANKS 12 OZ',
#   '4660000090::ECK ORIG FRANKS 12 OZ',
#   '2781500430::ECKRICH BOLOGNA 12 OZ',
#   '2781500430::ECKRICH BOLOGNA 12 OZ',
#   '2781500430::ECKRICH BOLOGNA 12 OZ',
#   '2781500430::ECKRICH BOLOGNA 12 OZ',
#   '1111522427::IMPERIAL SPREAD 45 OZ',
#   '7003862195::BC SANDWICH 20 OZ',
#   '7003862195::BC SANDWICH 20 OZ',
#   '960000003546::CPN: $1 off (3) Totinos Pizzas or Rolls 5/7-5',
#   '4280011200::TOTINO HAMBURGER PIZZA 10.9 OZ',
#   '4280011200::TOTINO HAMBURGER PIZZA 10.9 OZ',
#   '4280011200::TOTINO HAMBURGER PIZZA 10.9 OZ'],
#  ['28541300000::TENDERS 1 LB', '7343500026::KH DELI ROLLS 4 OZ'],
#  ['28541300000::TENDERS 1 LB',
#   '28903100000::STANDARD SIDE LB',
#   '4900002468::COKE  CLASSIC  .5LT 6 PK'],
#  ['2430004120::LD NUTTY BAR 12 OZ', '9729814438::AIR PURIFIER AIR POLICE'],
#  ['81008581689::GHOST LTO BLACK CHERRY WARHEADS 16OZ SIN',
#   '1510000007::CRMT SM ELBOW MAC 16 OZ',
#   '1510000073::CRMT MEDIUM SHELLS 16 OZ',
#   '81547301900::BORDEN HEAVY WHIPNG CREAM 16 OZ',
#   '2412601022::BUNNY HAMBURGER BUNS 8 CT',
#   '2412600908::BUNNY HOT DOG BUNS 12 OZ 8 CT',
#   '2100060464::KR SLICED AMER DELI CHSE 12 OZ',
#   '7003865707::BST CH STEAM SWT W CRN 12 OZ',
#   '7003836086::BST CH CHUNK MED CHEDDAR 8 OZ',
#   '5300006708::BDN CHNK GOUDA 8 OZ',
#   '1300000466::HZ KETCHUP SQUEEZE 38 OZ'],
#  ['2100003131::KR CO/JACK BIG SLICE 8 OZ',
#   '1200017174::DIET PEPSI 20 OZ',
#   '2370016222::TYSN BNLS TENDERLOIN 2.5 LB',
#   '4470003053::OM SHAVED SMO  TURKEY 9 OZ',
#   '7460905439::KC MSTRPC MARINADE CRBN JERK 16 OZ'],
#  ['7273010002::PRAIRIE FARMS BUTTER QTR 16 OZ',
#   '4300020433::JELLO PUDDING PIE FILLING VANILLA 3.4 OZ',
#   '74938493942::JF 13X9 CAKE WITH BLUE LID EACH',
#   '4400006064::NAB OREO PARTY SZ 24.16 OZ',
#   '7003864375::AL SAVE POWDER SUGAR 2 LB',
#   '4300020433::JELLO PUDDING PIE FILLING VANILLA 3.4 OZ',
#   '84023020006::AM CH MILK 2% HGAL 64 OZ',
#   '4300000953::COOL WHIP ORIGINAL TOPPING 8 OZ',
#   '7003864703::BST CH CREAM CHEESE 2PK 16 OZ'],
#  ['4061::LETTUCE  EA',
#   '4061::LETTUCE  EA',
#   '3121::PEPPER ORANGE EA',
#   '4062::CUCUMBER EA',
#   '75166677155::TOMATOES NATURE  SWEET CHERUB 10 OZ',
#   '7116973002::BC DECO ICING BLUE 4.25 OZ',
#   '4088::PEPPER  RED EA',
#   '7116973006::BC DECO ICING YELLOW 4.25 OZ',
#   '7116920895::BC HAPPY BDAY CANDLE 13 CT',
#   '7116920306::BC CANDLE #6 1 CT',
#   '1070080422::HRSH ZERO BAR 1.85 OZ',
#   '4689::PEPPER YELLOW EA',
#   '28531300000::ASSORTED TWIRLS',
#   '74938490315::JF COOKIE SHEETS 2 CT',
#   '1070080422::HRSH ZERO BAR 1.85 OZ',
#   '61029043126::CARD BRTHDAY HALLMARK',
#   '1200000134::DIET MOUNTAIN DEW 20 OZ',
#   '2840051777::DORITOS COOL RANCH PRTY SZ 15 OZ',
#   '2840031040::LAYS BBQ PRTY SZ 12.5 OZ'],
#  ['70897111806::LH OATMEAL RSN CKIE 15 OZ',
#   '4069768001::7UP  CAKE 26 OZ',
#   '7229000000::TENN PRIDE MILD SAUSAGE 1 LB',
#   '84023020002::AM CH MILK 2% GALN 128 OZ'],
#  ['3010012937::KLG GRIPZ VRTY PCK 12CT 11 OZ',
#   '3010012937::KLG GRIPZ VRTY PCK 12CT 11 OZ',
#   '4330161164::IDAHO HAND CUT FRIES 16.1 OZ'],
#  ['7800004416::CHERRY  RC COLA 12 PK',
#   '28609000000::SMK PORK CHOP CLD LB',
#   '28536100000::MISC HOT CHICKEN EACH'],
#  ['4300020051::JELLO STRAWBERRY GELATIN 6 OZ',
#   '7003866963::BST CH PIE SHELL 2PK 10 OZ',
#   '2100064361::KR DRSNG CLASSIC RANCH 16 OZ',
#   '7003831381::AL SAVE FLOUR ALL PURPOSE 5 LB',
#   '5300006336::BDN SLC NAT CO/JACK 6 OZ',
#   '4246::STRAWBERRIES   1 LB'],
#  ['7273071916::PF VANILLA HOMEMADE 48 OZ',
#   '84023020001::AM CH MILK WHOLE GAL 128 OZ',
#   '5000000926::NSTL TOLLHOUSE CHOC CHIP LOVERS 16 OZ'],
#  ['7003866676::BST CHCE ROUND TOP 20 OZ',
#   '1420002465::FLAG BLOW POPS 9.1  OZ',
#   '2100065492::VLVTA SHELLS N CHEESE LIGHT 12 OZ',
#   '2100065897::KR MAC N CHEESE SPIRALS 5.5 OZ',
#   '7203001570::ENTENMANNS BAG PWD DNT 12 CT',
#   '2100065371::KR MAC N CHEESE THINK N CREAMY 7.25 OZ',
#   '1121000832::TABASCO SAUCE SRIRACHA 20 OZ',
#   '7050580000::OL FOLKS ITALIAN SGE 1 LB',
#   '9147504189::MILO SWEET TEA GAL',
#   '9147504189::MILO SWEET TEA GAL'],
#  ['28003800000::ANGUS BEEF STEW MEAT',
#   '5210004360::MC BEEF STEW SEASONING 1.5 OZ',
#   '4072::POTATO IDAHO LOOSE BAKER LB',
#   '4070::CELERY EA',
#   '28003800000::ANGUS BEEF STEW MEAT',
#   '3338366602::CARROTS BABY PEEL 1 LB',
#   '2412601022::BUNNY HAMBURGER BUNS 8 CT',
#   '497::MISC BALLOON ORDER',
#   '84186689452::YOU ARE MY SUNSHINE BQT BQT',
#   '960000003545::CPN: $1 OFF (2) Pillsbury Participating  Item',
#   '4135855413::SWEET SUE BROTH BEEF 14.5 OZ',
#   '1800000013::PIL CRSNT SWT HAWAII 8 OZ',
#   '1800000013::PIL CRSNT SWT HAWAII 8 OZ'],
#  ['4330161163::IDAHO CRISPY POTATO PUFFS 13.8 OZ',
#   '7003838659::BST CH LARGE GRADE EGGS 2.5 DZ',
#   '9772968001::DARK CHOC TRUFFLE EACH',
#   '4330161163::IDAHO CRISPY POTATO PUFFS 13.8 OZ'],
#  ['7673790038::EVERFRESH APPLE JCE FUJI 12 OZ',
#   '81143203010::LUMP CHARCL SPRPRM 17.6#',
#   '28310700000::ASPARAGUS BNCH EA',
#   '28310700000::ASPARAGUS BNCH EA',
#   '63486894080::BBQ SAUCE SW HNY 20.25OZ'],
#  ['3283::APPLE WA HONEYCRISP LB',
#   '4011::BANANA LB',
#   '7003859674::BST CH SUNFLOWER KERNEL 5.85 OZ',
#   '7265500107::HC CHICKEN PESTO 9.9 OZ',
#   '7265545444::HC STMR SPAG MEATBALL 9.5 OZ',
#   '7342052420::DAISY 2% COTTAGE CHS 24 OZ'],
#  ['85407400635::SKYR STRAWBERRIES CREAM EXTRA CRMY 4.4 O',
#   '85407400635::SKYR STRAWBERRIES CREAM EXTRA CRMY 4.4 O',
#   '85407400635::SKYR STRAWBERRIES CREAM EXTRA CRMY 4.4 O',
#   '7707900400::SO REC SLT PPR RINDS 4 OZ',
#   '84023020001::AM CH MILK WHOLE GAL 128 OZ',
#   '85407400619::SKYR VANILLA EXTRA CREAMY 4.4 OZ'],
#  ['84186607481::SINGLE ROSE EA', '84186607480::ROSE MIX BQT'],
#  ['1394100692::CF A/N GROUND CHICKEN 16 OZ',
#   '7402610008::LORETTA STEAK SEASONING 1.4 OZ',
#   '7402610021::LOR CHKN SP GRINDER 1.5 OZ',
#   '7590000526::BOB EVANS MASHED POT 24 OZ.'],
#  ['710::FLORAL HANGING BASKET', '710::FLORAL HANGING BASKET'],
#  ['4470010295::OM UPLOADED DEEPDISH PEP PIZZ 14.7',
#   '28334000000::WATERMELON CHUNKS LB',
#   '84023020002::AM CH MILK 2% GALN 128 OZ',
#   '3100019677::KID CUISINE POPCORN CHKN 7 OZ',
#   '7003861761::BST CH SOUP CREAM CHICKEN 26 OZ',
#   '3100010976::BANQ CHKN FRIED CHICKEN MEAL 10.1 OZ',
#   '7003861761::BST CH SOUP CREAM CHICKEN 26 OZ',
#   '4400003111::NAB RITZ CRACKERS 13.7 OZ',
#   '1600014154::GM CINN TOAST CRUNCH 2 OZ',
#   '28334900000::PINEAPPLE CHUNKS LB',
#   '2100061223::KR PHIL CREAM CHSE BAR 8 OZ',
#   '3000031596::CAP N CRUNCH BERRIES    SNGL SRV 1.3 OZ',
#   '2100002522::KR CLBY M/JACK CUBES 6.4 OZ',
#   '2100061223::KR PHIL CREAM CHSE BAR 8 OZ',
#   '28047800000::FP WHOLE PNLS PORK LOIN LB',
#   '28047800000::FP WHOLE PNLS PORK LOIN LB',
#   '3100010976::BANQ CHKN FRIED CHICKEN MEAL 10.1 OZ',
#   '3100010976::BANQ CHKN FRIED CHICKEN MEAL 10.1 OZ',
#   '4470009558::OM FP PIZZA TREATZA 10.5'],
#  ['1600044030::BC ANGEL FOOD CAKE 16 OZ',
#   '7027223202::REDI WIP REAL CREAM TOP 6.5 OZ',
#   '3993899709::BBQ GINGHAM SMALL PLATE EACH',
#   '4246::STRAWBERRIES   1 LB'],
#  ['4400005869::NAB OREO MEGA STUFF FS 17.6 OZ',
#   '7064001315::BB CHERRIFIC CHEESECAKE 46 OZ',
#   '29999500000::ACE RSTP SPRY GL',
#   '29999500000::ACE RSTP SPRY SA',
#   '7064002370::B BUNNY SOFT CHOCOLATE 46 OZ',
#   '8290117072::ACE RSTP SPRY GL BLK 15OZ',
#   '7003860877::BST CH ROUND TOOTHPICK 250 CT',
#   '28519200000::8 PC COLD CHICKEN 8 PC',
#   '7018357080::RUP EXT CNTRL RFLL',
#   '8290117073::ACE RSTP SPRY SATBLK15OZ',
#   '1200001879::PEPSI ZERO SUGAR 12 PK',
#   '4400006063::NAB OREO CHOC FAM SZ 18.71 OZ'],
#  ['7003837280::BST CH GR A LARGE EGG 1 DZ',
#   '7003837280::BST CH GR A LARGE EGG 1 DZ',
#   '3663200835::DAN OIKOS ZERO BRY 5.3 OZ',
#   '3663200837::OIKOS TRIPLE ZERO PEACH 5.3 OZ',
#   '3560007173::KY LEGEND PILLOW PACK BLACK FOREST SLICE',
#   '3560007176::KY LEGEND PILLOW PACK SMOKED SLICED TURK',
#   '3663200835::DAN OIKOS ZERO BRY 5.3 OZ',
#   '3663200837::OIKOS TRIPLE ZERO PEACH 5.3 OZ',
#   '3663200835::DAN OIKOS ZERO BRY 5.3 OZ',
#   '3663200837::OIKOS TRIPLE ZERO PEACH 5.3 OZ',
#   '3663200837::OIKOS TRIPLE ZERO PEACH 5.3 OZ',
#   '3560007176::KY LEGEND PILLOW PACK SMOKED SLICED TURK',
#   '3663200835::DAN OIKOS ZERO BRY 5.3 OZ',
#   '3663200835::DAN OIKOS ZERO BRY 5.3 OZ',
#   '3663200835::DAN OIKOS ZERO BRY 5.3 OZ',
#   '3663200835::DAN OIKOS ZERO BRY 5.3 OZ',
#   '3663200835::DAN OIKOS ZERO BRY 5.3 OZ',
#   '3663200837::OIKOS TRIPLE ZERO PEACH 5.3 OZ',
#   '3663200835::DAN OIKOS ZERO BRY 5.3 OZ',
#   '3663200836::DAN OIKOS ZERO STRAW 5.3 OZ',
#   '3663200836::DAN OIKOS ZERO STRAW 5.3 OZ',
#   '3663200835::DAN OIKOS ZERO BRY 5.3 OZ',
#   '3663200835::DAN OIKOS ZERO BRY 5.3 OZ',
#   '3663200835::DAN OIKOS ZERO BRY 5.3 OZ',
#   '3663200836::DAN OIKOS ZERO STRAW 5.3 OZ',
#   '5410001270::VLASIC SWT MIDGET PICKLE 16 OZ',
#   '960000003403::CPN: Save $1.50 on  1 Kentucky Legend Lunchme',
#   '7003860299::AS ICE CREAM NEAPOLITAN 128 OZ',
#   '7003837280::BST CH GR A LARGE EGG 1 DZ'],
#  ['2412600822::BUNNY 100% WHEAT 16 OZ',
#   '3700096260::FEBREZE AIR HAWAIIAN ALOHA 8.8 OZ',
#   '7027530181::WHINK COFFEEMAK 10 OZ',
#   '4650081666::RD FLYING INSECT 20% MORE 18 OZ',
#   '2570001356::ZIPL SNDWCH BAG 50 CT',
#   '28609000000::SMK PORK CHOP CLD LB',
#   '7040400278::POMP OLIVE OIL XV SMOOTH 16 OZ',
#   '7590000563::BE BROCCOLI & CHSE 20 OZ'],
#  ['7273062042::PF ENG TOFFEE 16.5 OZ',
#   '88552330813::JL COCO MERINGUE PIE 27 OZ',
#   '61278110108::MARIE C COCONUT CREAM PIE 30.3 OZ'],
#  ['84186607481::SINGLE ROSE EA', '84186607481::SINGLE ROSE EA'],
#  ['4470006647::OM READY/TO/SRV BACN 2.52 OZ',
#   '2781530059::ECK MAPLE LINK 8.30OZ',
#   '2412600908::BUNNY HOT DOG BUNS 12 OZ 8 CT',
#   '2840059668::CHEETOS PUFFS JUMBO 8 OZ',
#   '2781500123::ECKRICH CHEESE FRANKS 12 OZ',
#   '7050550260::PURNELLS OLD FOLK GRAVY BG 8 OZ',
#   '7050550260::PURNELLS OLD FOLK GRAVY BG 8 OZ',
#   '1800000185::PIL GRANDS BISCUITS STHRN STYLE 16.3 OZ',
#   '4400002991::NAB CHIPS AHOY W REESES 9.5 OZ'],
#  ['5000022522::FRSK PRM FILET TRKY 5.5 OZ',
#   '5000057201::FRSK SHRDDED SALMON 5.5 OZ',
#   '5000017018::FRSK CHKN/GRAVY 5.5 OZ',
#   '5000022522::FRSK PRM FILET TRKY 5.5 OZ',
#   '5000017018::FRSK CHKN/GRAVY 5.5 OZ',
#   '5000022522::FRSK PRM FILET TRKY 5.5 OZ',
#   '5000057796::FRSK TSTY CHKN CHS 5.5 OZ',
#   '5000057796::FRSK TSTY CHKN CHS 5.5 OZ',
#   '5000022522::FRSK PRM FILET TRKY 5.5 OZ',
#   '5000057201::FRSK SHRDDED SALMON 5.5 OZ',
#   '7003860398::BST CH HEAVY DUTY FORKS 48 CT'],
#  ['84023020006::AM CH MILK 2% HGAL 64 OZ',
#   '7050500001::OL FOLKS SAUS.MILD 1/LB',
#   '3560081302::KY LEG HICKRY SMK SLICED BACON 1 LB',
#   '1800000188::PIL GR BTR TST BISC 10.2 OZ',
#   '84186650711::MUCH LOVE MOM MIXED BOUQUET BQT'],
#  ['79590251516::CARD MDAY ANYONE',
#   '84186650711::MUCH LOVE MOM MIXED BOUQUET BQT',
#   '84186650711::MUCH LOVE MOM MIXED BOUQUET BQT'],
#  ['79590251562::CARD MDAY MOTHER',
#   '2100002649::KR MIRACLE WHIP 30 OZ',
#   '2998812008::COUNTRY BOB SEA SALT 8 OZ'],
#  ['7047016487::RATIO YOG BLUEBERRY 5.3 OZ',
#   '7047016487::RATIO YOG BLUEBERRY 5.3 OZ',
#   '7047016485::RATIO YOG STRAWBERRY 5.3 OZ',
#   '7047016486::RATIO YOG VANILLA 5.3 OZ',
#   '7047016485::RATIO YOG STRAWBERRY 5.3 OZ',
#   '7047016486::RATIO YOG VANILLA 5.3 OZ',
#   '7047016486::RATIO YOG VANILLA 5.3 OZ',
#   '85631200279::FAIRLIFE 2% CHOC MILK 52 OZ',
#   '7003837280::BST CH GR A LARGE EGG 1 DZ',
#   '28016600000::BONELESS PORK CHOPS LB',
#   '28000600000::FRESH GROUND CHUCK 80/20 LB',
#   '7080004146::SF BACON 12 OZ',
#   '7080004146::SF BACON 12 OZ',
#   '84186607486::DOZEN ROSE BOUQUET BQT'],
#  ['28610000000::SHREDDED PULLED PORK LB',
#   '1340951520::SWT RAY BBQ VIDALIA 18 OZ',
#   '1340935231::SWT RAY BBQ ORIG 28 OZ',
#   '4850020548::TROP STRWBRY LMADE 46 OZ',
#   '2500004488::SIMPLY ORNGE LOW ACD 52 OZ',
#   '9175204100::OS WILD BLUEBERRY MUFFIN 3 PK',
#   '599::SINGLE DONUT'],
#  ['7003837286::BST CH GRD A LRG 18P EGG 1.5 DZ',
#   '7203001985::ENTENMANNS BAGED CINN DONUTS 12 PK 12 PK',
#   '4146039887::PIONEER GRAVY PEPPER 2.75 OZ',
#   '4146039888::PIONEER GRAVY COUNTRY 2.75 OZ',
#   '599::SINGLE DONUT',
#   '4178900214::MAR RAMEN NDL SOY SCE 3 OZ',
#   '4178900214::MAR RAMEN NDL SOY SCE 3 OZ',
#   '84023020001::AM CH MILK WHOLE GAL 128 OZ',
#   '2100005535::KR SHRD SHARP CHDR 8 OZ',
#   '1800000123::PIL GRANDS BISCUITS BTR 32.6 OZ',
#   '7050500008::OL FOLKS SMKD SAUSAG 1 LB'],
#  ['61126933282::RED BULL RED EDITION WATERMELON 12 OZ',
#   '79590255930::CARD MDAY MOTHER',
#   '84186600704::9 STEM BOUQUET BQT',
#   '79590251557::CARD MDAY ANYONE',
#   '84186689452::YOU ARE MY SUNSHINE BQT BQT',
#   '84186607486::DOZEN ROSE BOUQUET BQT'],
#  ['89661201204::FLOWER BEDDING 4 CELL EA',
#   '89661200040::STAND ANNUAL PLANTS 4 IN'],
#  ['4088::PEPPER  RED EA',
#   '710::FLORAL HANGING BASKET',
#   '4065::PEPPER GREEN EA'],
#  ['28538400000::FROZEN CAKE EA',
#   '7684713138::GRIPPOS BBQ CHIPS 24 OZ',
#   '4178027160::UTZ KET CLASSIC RUSSET CHIPS 7.5 OZ'],
#  ['4900001278::COKE CLASSIC 24 PK 12 OZ 288 OZ',
#   '1200000746::DIET MOUNTAIN DEW 2 LTR',
#   '1200000935::MUG ROOT BEER 2 LTR'],
#  ['30149003966::PEPTO BSML KIDS CHEWABLE BUBBLE GUM 24 C',
#   '30065008515::ALCON EYE DROPS 0.5 OZ'],
#  ['2412600899::BUNNY 4 PLAIN HAMBURGER 12 PK 12 PK',
#   '2412600899::BUNNY 4 PLAIN HAMBURGER 12 PK 12 PK',
#   '2412600899::BUNNY 4 PLAIN HAMBURGER 12 PK 12 PK'],
#  ['7343500027::KING HAWAIIAN REG ROLLS 4 OZ',
#   '8290125239::ACE BAG 39GAL 32CT DRAW',
#   '7218063245::RED BARON FRENCH 5 CHEESE N GARLIC 21.1',
#   '7218063244::RED BARON FRENCH PEPPERONI 10.8 OZ',
#   '3560005576::CHILI ROLL 16 OZ.',
#   '3560005576::CHILI ROLL 16 OZ.',
#   '7465365243::JACKS THIN SUPREME 15.8 OZ',
#   '7465339393::JACKS THIN SAUSAGE N PEPPERONI 16.1 OZ',
#   '7465392068::JACK`S CANADIAN BACON  PIZZA 15.7 OZ',
#   '84023020001::AM CH MILK WHOLE GAL 128 OZ',
#   '710::FLORAL HANGING BASKET'],
#  ['28502100000::PISTACHIO SALAD EACH',
#   '28529400000::CRANBERRY SALAD EACH',
#   '7003865401::BST CH SHRED MOZZARLA 8 OZ',
#   '2100000728::KR PHIL CREAM CHSE CHIVE N ONION 7.5 OZ'],
#  ['7003837280::BST CH GR A LARGE EGG 1 DZ',
#   '3560007301::KL DICED HAM 8 OZ',
#   '2100061146::KR VELV SPRD SNGL 16 OZ'],
#  ['1200000017::PEPSI 24 PK',
#   '7273026307::PF DUTCH CHOCOLATE MILK 32 OZ',
#   '2840070572::FRITO LAY CHESTERS CHEES 4.25 OZ',
#   '4240018906::MOM BAG FROSTED FLAKES 30 OZ'],
#  ['29999500000::MG POTTING MIX S',
#   '29999500000::MG POTTING MIX S',
#   '3224756523::MG POTTING MIX SOIL 2 CF EA',
#   '29999500000::MG POTTING MIX S',
#   '29999500000::MG POTTING MIX S',
#   '29999500000::MG POTTING MIX S'],
#  ['2840051631::DORITOS COOL RANCH 9.25 OZ',
#   '2840051646::DORITOS NACHO CHEESE 9.25 OZ',
#   '2412601027::BUNNY SOFT TWIST 16 OZ',
#   '2840051646::DORITOS NACHO CHEESE 9.25 OZ',
#   '4072::POTATO IDAHO LOOSE BAKER LB',
#   '28842400000::SELECT ANGUS NY STRIP EA',
#   '28136300000::SF THIN BNLS BRST LB',
#   '7143000933::DOLE AMERICAN BLEND 12 OZ',
#   '76531700207::ROXANE SPRING WTR 24 PK'],
#  ['2412601027::BUNNY SOFT TWIST 16 OZ',
#   '7273068046::NOR STR LOTTA CREME 35 OZ',
#   '3010010057::KEB CLUB ORIGINAL 13.7 OZ',
#   '2100001856::KR DELI MLD CHD SLIC 8 OZ',
# ...
#   '28333600000::BROCCOLI  CROWNS LB',
#   '89661201204::FLOWER BEDDING 4 CELL EA',
#   '89661201204::FLOWER BEDDING 4 CELL EA',
#   '89661201204::FLOWER BEDDING 4 CELL EA'],
#  ['7684715154::GRIPPOS BBQ CHIPS 8 OZ',
#   '7003867128::BST CH CHED SC CHIPS 7.75 OZ'],
#  ['28569100000::ICED OATMEAL COOKIES EACH',
#   '28563200000::8 CT ICED SUGAR COOKIES 8 CT',
#   '28507100000::SMOKED CHICKEN HOT EACH',
#   '7003835086::AS FROZEN WHIP TOPPING 8 OZ',
#   '4246::STRAWBERRIES   1 LB',
#   '7003859156::BST CH SS CHEESE RAVOLI 20 OZ',
#   '1290000700::DESSERT SHELLS 6 CT',
#   '74616782001::TASTY CHOICE SESAME CHIC 24 OZ',
#   '89661201204::FLOWER BEDDING 4 CELL EA',
#   '7539102457::SEABEST 50/60 CT CKD SHRMP 10 OZ'],
#  ['4900001801::CHERRY COKE 20 OZ', '3000057272::QKR CPN CRN BRRY BAR 8 CT'],
#  ['1200010735::DIET MOUNTAIN DEW .5L 6 PK',
#   '1200010735::DIET MOUNTAIN DEW .5L 6 PK',
#   '710::FLORAL HANGING BASKET',
#   '710::FLORAL HANGING BASKET',
#   '89661200040::STAND ANNUAL PLANTS 4 IN',
#   '702::FLORAL SEASONAL'],
#  ['7064001086::B BUNNY MINI SWIRL VANILLA 8 CT 18 OZ',
#   '28500900000::PIMENTO SPREAD EACH',
#   '28502400000::HAM SALAD EACH',
#   '28529400000::CRANBERRY SALAD EACH'],
#  ['7273065013::PF ORNG DRM BAR 30 OZ',
#   '2100030088::BRKSTN RICOTTA CHEESE 15 OZ',
#   '7273071918::PF PREMIUM STRAWBERRY SHORTCAKE 16 OZ',
#   '7273071920::PF PREMIUM BUTTER PECAN IC 16 OZ',
#   '7003866356::BST CH PINK FRIST COOKIE 13 OZ',
#   '7003866356::BST CH PINK FRIST COOKIE 13 OZ'],
#  ['7273025313::PRAIRIE FARMS BUTTER MIL 32 OZ',
#   '1600037400::BC FRSTNG DLX WHP STRW 12 OZ',
#   '63155202236::YUMMY LOLLI REFILLS 1 OZ',
#   '88399010127::G2G PARADISE PUNCH BIGGE 10 OZ'],
#  ['899::HILLMAN FASTENERS',
#   '3920821073::BOLT EYE W/NUT 1/4X2',
#   '7018351006::ROUND UP W&G CONC 36.8OZ'],
#  ['4900003165::DASANI PET 16.9 OZ 24 PK',
#   '4011::BANANA LB',
#   '3600054316::KLNX US FLAT 4 PK 480 CT'],
#  ['76531700207::ROXANE SPRING WTR 24 PK',
#   '76531700207::ROXANE SPRING WTR 24 PK'],
#  ['2410078925::CHEEZ IT PEPPER JACK 12.42 OZ',
#   '2410078925::CHEEZ IT PEPPER JACK 12.42 OZ',
#   '1410008599::PF WHOLE GRAIN 100% WHOLE WHEAT BRD 24 O',
#   '7003837280::BST CH GR A LARGE EGG 1 DZ',
#   '3415::POTATO RUSSET 5 LB',
#   '28000600000::FRESH GROUND CHUCK 80/20 LB',
#   '28000600000::FRESH GROUND CHUCK 80/20 LB',
#   '28570200000::DILL DIP EACH',
#   '19600570834::CRISCO CANOLA OIL 40 OZ'],
#  ['2412601027::BUNNY SOFT TWIST 16 OZ',
#   '2412601770::LEWIS TEXAS TOAST 24 OZ',
#   '5100005977::CAMP SOUP CREAM CHICKEN HR 10.5 OZ',
#   '5000092787::COFMAT IC COF CARML 50 OZ',
#   '5100012114::SWANSON BROTH CHICKEN BOX 32 OZ',
#   '3620043170::RAGU OWS TRAD RETRO SAUCE LE 24 OZ',
#   '3620043170::RAGU OWS TRAD RETRO SAUCE LE 24 OZ',
#   '88810925465::HOST DONETTES OLD FASH 10.5 OZ',
#   '7273073752::PF SHERBET ORANGE 32 OZ',
#   '7684715180::GRIPPOS BBQ CHIPS 12 OZ',
#   '2700000900::BLUE BON SPREAD BOWL 15 OZ',
#   '3100000737::BANQ TURKEY MEAL 10 OZ',
#   '3100000715::BANQ SWEDISH MEATBALLS 10.25 OZ',
#   '1510000043::CRMT SPAGHETTI 16 OZ',
#   '1200010205::MOUNTAIN DEW CODE RED 16.9 OZ 6 PK',
#   '1200010205::MOUNTAIN DEW CODE RED 16.9 OZ 6 PK',
#   '7800000676::SUNKIST ORANGE ZERO SUAGR 6 PK'],
#  ['28554600000::DESSERT FOR 2 EACH',
#   '28552200000::PARFAIT EACH',
#   '7003860401::BST CH HEAVY DUTY  SPOONS 24 CT',
#   '7003862066::BST CH NAT BONE 5IN EA',
#   '2310001527::PDGR CHOICE CUT BEEF 13.2 OZ',
#   '2000012682::GG SF BROC CAR CAUL CHS 22 OZ',
#   '9147593097::MILOS SWEET TEA 20 OZ',
#   '2100007715::VLVTA BOWL SHELLS N CHEESE 5 OZ',
#   '9147563004::MILO TEA SWEET W/SPLENDA GAL',
#   '28507100000::SMOKED CHICKEN HOT EACH'],
#  ['4300001098::CNTRY TIME OTG LMD 10CT 10 CT',
#   '1600045960::BC FRSTNG RC CREAM CHSE 16 OZ',
#   '2754100123::NIAGARA DRNKG  WTR 24 PK',
#   '7010001935::JOHN M BRAUNSCHWEIGER 16 OZ',
#   '7878350610::CARROTS GR MATCHSTIX 10 OZ',
#   '5100000803::V8 ORIG 100% VEG JCE 46 OZ',
#   '5100012156::V8 SPICY HOT VEG JCE 46 OZ',
#   '28561400000::DANISH ROLLS 3 CT',
#   '2754100123::NIAGARA DRNKG  WTR 24 PK',
#   '28556400000::BROWNIE FACTORY EACH'],
#  ['7003837280::BST CH GR A LARGE EGG 1 DZ',
#   '4300005953::CRST LT SWT TEA 12 QT',
#   '7003834855::AS SAUERKRAUT 15 OZ',
#   '7003834855::AS SAUERKRAUT 15 OZ',
#   '4070::CELERY EA',
#   '1300000466::HZ KETCHUP SQUEEZE 38 OZ',
#   '1300000466::HZ KETCHUP SQUEEZE 38 OZ',
#   '4069::CABBAGE GREEN LB',
#   '74938490355::JF MUFFIN PANS 2 CT',
#   '3760011806::CHI CHI SALSA MED 16 OZ',
#   '4061::LETTUCE  EA',
#   '4166::ONIONS SWEET LB',
#   '1200001276::LPT GREEN TEA 12 PK 202.8 OZ'],
#  ['4900002933::COKE CAFFEINE FREE 12 PK 144 OZ',
#   '3415::POTATO RUSSET 5 LB',
#   '4900002933::COKE CAFFEINE FREE 12 PK 144 OZ',
#   '4900000977::DASANI WATER 20 OZ',
#   '28568700000::ROTISSERIE CHICKEN HOT EACH',
#   '4016::APPLE WA RED DELICIOUS LB',
#   '3400000240::HRSH MILK CHOC BAR 1.55 OZ',
#   '84521802497::SMALL DIE CAST CARS EACH',
#   '2840051646::DORITOS NACHO CHEESE 9.25 OZ'],
#  ['2840076865::FL LAYS DUAF FLAVOR 7.75 OZ',
#   '4400007352::OREO MEGA STUFF PARTY SIZE 25.35 OZ',
#   '28538800000::GOURMET DBL CHOC CHIP EACH',
#   '7273603300::ROBIN BBQ SC WHISKEY RIVER 14 OZ'],
#  ['61126900130::RED BULL SUMMER EDITION STRA 12 OZ',
#   '3400000440::HRSH REESE PBTR CUPS 1.5 OZ',
#   '1200000131::MOUNTAIN DEW 20 OZ'],
#  ['7273072018::PF PREMIUM ROCKY ROAD 48 OZ',
#   '2100001342::KR MAC CH SPONGEBOB 5.5 OZ',
#   '2100001342::KR MAC CH SPONGEBOB 5.5 OZ',
#   '2100001342::KR MAC CH SPONGEBOB 5.5 OZ',
#   '2100001342::KR MAC CH SPONGEBOB 5.5 OZ',
#   '960000003513::CPN: SAVE $2.00 off (4) Kraft Mac Cheese 5/7-'],
#  ['4000045984::DOVE MILK CHOC BAR 1.44 OZ',
#   '79367483025::FROSTIE CREAM SODA 32 OZ',
#   '7003867124::BST-CH BBQ PRK SKINS 5 OZ',
#   '599::SINGLE DONUT'],
#  ['7003861893::BST CH SODA CHERRY COLA 12PK 144 OZ',
#   '7003858528::BST CH SODA DR CHOICE 12PK 144 OZ',
#   '2840051631::DORITOS COOL RANCH 9.25 OZ',
#   '2840051646::DORITOS NACHO CHEESE 9.25 OZ',
#   '5210004576::MC STREET TACO CHICKEN .87 OZ',
#   '7003834140::AS ORANGE 67.6 OZ',
#   '7003836220::BST CH SHRED TACO 8 OZ',
#   '7003858243::BST CH SHRED PEPPER JACK 8 OZ',
#   '5210004576::MC STREET TACO CHICKEN .87 OZ',
#   '5210004576::MC STREET TACO CHICKEN .87 OZ',
#   '7143001065::DOLE SHREDDED LETTUCE 8 OZ',
#   '4799::TOMATOES HOT HOUSE LARGE LB',
#   '4156500017::PACE PICANTE SAUCE MILD 16 OZ',
#   '4166::ONIONS SWEET LB',
#   '28028700000::GROUND BEEF LB',
#   '28029000000::GROUND CHUCK LB',
#   '7625910401::WAMP A/N MLD TACO MT 16 OZ',
#   '7003836554::AS CULTURED SOUR CREAM 16 OZ',
#   '28661400000::CUPCAKE W PICK 10 CT',
#   '1200000131::MOUNTAIN DEW 20 OZ',
#   '7800008240::DR PEPPER 20 OZ',
#   '7084702290::MONSTER ENERGY PUNCH 16 OZ'],
#  ['1450001809::BE LOADD BAKED PTO BAKE 25 OZ',
#   '28045200000::FP BONLES CNTRY RIBS',
#   '5190080103::LOF DELI/SHAVED HAM 9 OZ',
#   '28046100000::TENDERIZED THIN BONLES PORK CHOPS LB',
#   '28045700000::TENDERIZED PORK CHOPS LB',
#   '28045200000::FP BONLES CNTRY RIBS',
#   '7003837280::BST CH GR A LARGE EGG 1 DZ',
#   '1340945133::SWT RAY BBQ HONEY 40 OZ',
#   '2412601027::BUNNY SOFT TWIST 16 OZ',
#   '28588400000::MINI CHOC CUPCK WP 3 OZ',
#   '3560081302::KY LEG HICKRY SMK SLICED BACON 1 LB',
#   '3560081302::KY LEG HICKRY SMK SLICED BACON 1 LB',
#   '4900001278::COKE CLASSIC 24 PK 12 OZ 288 OZ',
#   '4900001278::COKE CLASSIC 24 PK 12 OZ 288 OZ',
#   '960000003555::CPN: $1 OFF (2) Coke Participating Items 24 p'],
#  ['3120020007::OCN SPR CRANBERRY JUICE COCKTAIL 64 OZ',
#   '3120021007::OCN SPR CRAN APPLE JUICE 64 OZ',
#   '7116971040::BC RAINBOW MIX SPRINKLES 1.75 OZ'],
#  ['84037090312::KR GRTED PARM PP4.99 8 OZ',
#   '7294011415::RED GOLD TOMATO PUREE 15 OZ',
#   '7294011415::RED GOLD TOMATO PUREE 15 OZ',
#   '1510000163::CRMT THIN SPAGHETTI 16 OZ',
#   '1510000163::CRMT THIN SPAGHETTI 16 OZ',
#   '28030500000::FP GROUND CHUCK LEAN LB'],
#  ['7045900910::NY GARLIC BREADSTICK 6 CT',
#   '4370015016::RONCO SPAGHETTI 16 OZ',
#   '2412601022::BUNNY HAMBURGER BUNS 8 CT',
#   '8304600402::ICE MOUNTAIN 16.9 OZ 24 PK PET 405.6 OZ'],
#  ['7829131082::CLR LIME RUST REMOVER 28 OZ',
#   '7829131082::CLR LIME RUST REMOVER 28 OZ',
#   '1980040109::DRANO MX GEL CLOG RMVR 80 OZ'],
#  ['28511800000::KR BLK ANGUS RST BEEF EACH',
#   '2840051631::DORITOS COOL RANCH 9.25 OZ'],
#  ['3663207916::I DLT CRML MACCH CLD FOAM CREAMER 14 OZ',
#   '4246::STRAWBERRIES   1 LB',
#   '7027223202::REDI WIP REAL CREAM TOP 6.5 OZ',
#   '4246::STRAWBERRIES   1 LB',
#   '5000011234::COFMAT VAN CARM CRM 32 OZ',
#   '2840076867::FL LAYS DUAF FLAVOR 3 7.5 OZ',
#   '2840020128::LAYS DILL PICKLE 7.75 OZ',
#   '28532100000::ANGEL FOOD CAKE',
#   '28532100000::ANGEL FOOD CAKE'],
#  ['5473281638::MECH TIMER INDR 24HR', '5473281638::MECH TIMER INDR 24HR'],
#  ['7116910502::BC PENCIL CANDLES 24 CT',
#   '28561700000::1/2 SLAB RIB COLD EACH'],
#  ['2840051646::DORITOS NACHO CHEESE 9.25 OZ',
#   '2840051646::DORITOS NACHO CHEESE 9.25 OZ',
#   '2840051631::DORITOS COOL RANCH 9.25 OZ',
#   '3560081300::KY LEG APPLWOD SMK SLCED BACON 1 LB',
#   '2781500440::ECKRICH THICK BOLOGNA 12 OZ',
#   '7910052000::K9 CARRYOUTS BEEF 4.5 OZ',
#   '5200001122::V CAMP PORK N BEANS 15 OZ'],
#  ['3400000244::HRSH ROLO BARS 1.7 OZ',
#   '7064001245::BB BUTTER PECAN PREMIUM ICE CREAM 48 OZ'],
#  ['2840004770::ROLD GOLD STICKS 16 OZ',
#   '2100064482::KR DRSNG CUCUMBER RANCH 16 OZ',
#   '2970000146::IDHN BTR HERB MSH POTATO 4 OZ',
#   '2970000146::IDHN BTR HERB MSH POTATO 4 OZ',
#   '2970000146::IDHN BTR HERB MSH POTATO 4 OZ',
#   '2970000146::IDHN BTR HERB MSH POTATO 4 OZ'],
#  ['4239::BLACKBERRIES 6 OZ',
#   '4054::RASPBERRIES 6 OZ',
#   '4252::BLUEBERRIES PINT',
#   '88810911065::HOST MINI DONUT GLAZED 10.5 OZ',
#   '28532300000::HAMBURGER BUNS EACH',
#   '4127102773::STOK COLD BREW UNSWE 48 OZ',
#   '84023020002::AM CH MILK 2% GALN 128 OZ'],
#  ['7680850294::BARILLA RIGATONI 16 OZ',
#   '7680850294::BARILLA RIGATONI 16 OZ',
#   '28333600000::BROCCOLI  CROWNS LB',
#   '2700037801::HNT FIRE RSTD TOM 14.5 OZ',
#   '2700037801::HNT FIRE RSTD TOM 14.5 OZ',
#   '2700039023::HNT TOMATO SAUCE 29 OZ',
#   '2700039023::HNT TOMATO SAUCE 29 OZ'],
#  ['2412601807::LBS HAWAIIAN DINNER ROLL 12 CT',
#   '1200000134::DIET MOUNTAIN DEW 20 OZ'],
#  ['4070::CELERY EA', '28333600000::BROCCOLI  CROWNS LB'],
#  ['5100001641::CAMP SOUP CREAM POTATO 10.5 OZ',
#   '1800028794::PIL PIE CRUSTS 14.1 OZ'],
#  ['7192100779::CALI PK UNCURED PEPPERONI THIN 13.6 OZ',
#   '7218056625::RED BARON CL SAUS PEPP 21.95 OZ',
#   '7218063471::RED BARON CLASSIC SUPREME 23.45 OZ',
#   '2100000198::KR CHNK NY SHARP CHDR 8 OZ',
#   '7675322211::GC PIZZA CUTTER 1 CT',
#   '85245500504::BASKIN ROBBINS JAMOCA ALMOND FUDGE 14 OZ',
#   '4741::RADISHES 1 LB',
#   '7027710520::ATHENOS FETA CRM EACH'],
#  ['2412601743::LEWIS TEXAS TOAST 12 OZ',
#   '2412601741::LEWIS SOURDOUGH 12 OZ',
#   '2840019963::LAYS SOUR CREAM AND ONION 7.75 OZ',
#   '3663207916::I DLT CRML MACCH CLD FOAM CREAMER 14 OZ'],
#  ['7064002005::BL RIBBON C HOMEMADE VANILLA R FAT 48 OZ',
#   '7003834454::BST CH PIE CRUST REFRIGRTD 15 OZ',
#   '7092300300::TERRO LIQUID ANT KILLER BAITS 6 CT'],
#  ['702::FLORAL SEASONAL',
#   '4128989570::AZTECA SSZ FLOUR TORTILLA 10 CT',
#   '5000000926::NSTL TOLLHOUSE CHOC CHIP LOVERS 16 OZ',
#   '89661200040::STAND ANNUAL PLANTS 4 IN',
#   '7294576605::SL ART HAW BN 8P 19Z',
#   '2840051780::DORITOS SPICY NACHO PRTY SZ 15 OZ',
#   '89661200040::STAND ANNUAL PLANTS 4 IN',
#   '2840007098::JAR DIP TOSTITOS QUESO 15 OZ',
#   '2840072468::FRITO LAY TOSTITOS SPICY QUESO DIP 15 OZ',
#   '73359047276::RED CACTUS SALSA SWT HOT 16 OZ',
#   '89661200040::STAND ANNUAL PLANTS 4 IN',
#   '89661201204::FLOWER BEDDING 4 CELL EA',
#   '89661201204::FLOWER BEDDING 4 CELL EA',
#   '89661201204::FLOWER BEDDING 4 CELL EA',
#   '28030500000::FP GROUND CHUCK LEAN LB'],
#  ['84023020002::AM CH MILK 2% GALN 128 OZ',
#   '88810911010::HOST TWINKIES 10 CT 13.58 OZ',
#   '4246::STRAWBERRIES   1 LB',
#   '4246::STRAWBERRIES   1 LB'],
#  ['4300001084::COOL WHIP SF TOPPING 8 OZ',
#   '4300000953::COOL WHIP ORIGINAL TOPPING 8 OZ'],
#  ['7064001257::B BUNNY HOMEMADE VANILA 48 OZ',
#   '7003859124::BST CH SP CREAM MSHRM FF 10.75 OZ',
#   '7003859124::BST CH SP CREAM MSHRM FF 10.75 OZ',
#   '28029000000::GROUND CHUCK LB'],
#  ['7524320314::MAYFIELD PT MOOSE TRACKS 1 EACH',
#   '4369507118::HOT PKT SMKY GRN CHILI CHS STEAK 9 OZ',
#   '2970000141::IDHN BTR HMSTYLE MSH POTATO 4 OZ',
#   '7003862463::BST CH BLACK BEANS 15 OZ',
#   '28029000000::GROUND CHUCK LB',
#   '28030500000::FP GROUND CHUCK LEAN LB'],
#  ['4011::BANANA LB', '28018900000::PORK STEAK LB'],
#  ['7539101230::SB CK SALAD SHRIMP 16 OZ',
#   '81547301900::BORDEN HEAVY WHIPNG CREAM 16 OZ',
#   '9147504189::MILO SWEET TEA GAL',
#   '2500010061::SIMPLY LT LEMONADE 52 OZ',
#   '2412601741::LEWIS SOURDOUGH 12 OZ'],
#  ['2754100123::NIAGARA DRNKG  WTR 24 PK',
#   '2754100123::NIAGARA DRNKG  WTR 24 PK',
#   '2754100123::NIAGARA DRNKG  WTR 24 PK',
#   '2754100123::NIAGARA DRNKG  WTR 24 PK'],
#  ['5210003493::MC SEASONING TACO MILD 1 OZ',
#   '4134400006::MULLENS DRSNG IMITATION FRENCH 16 OZ',
#   '5210003493::MC SEASONING TACO MILD 1 OZ',
#   '4246::STRAWBERRIES   1 LB',
#   '89470001013::CHOB 0% PLAIN YOG 32 OZ',
#   '4157005621::ALMOND BRZ VAN MILK 64 OZ',
#   '4252::BLUEBERRIES PINT',
#   '4300000953::COOL WHIP ORIGINAL TOPPING 8 OZ',
#   '4011::BANANA LB',
#   '3620043170::RAGU OWS TRAD RETRO SAUCE LE 24 OZ',
#   '3620043170::RAGU OWS TRAD RETRO SAUCE LE 24 OZ'],
#  ['7800000034::7 UP 2 LTR', '7092300300::TERRO LIQUID ANT KILLER BAITS 6 CT'],
#  ['21399900000::GOT Markdown - Cold Deli',
#   '28536100000::MISC HOT CHICKEN EACH',
#   '28536100000::MISC HOT CHICKEN EACH'],
#  ['3320001110::A&H BAKING SODA 16 OZ',
#   '2840007098::JAR DIP TOSTITOS QUESO 15 OZ',
#   '4161700250::HEARTH CLUB BAKING POWDER 8.1 OZ',
#   '4300001084::COOL WHIP SF TOPPING 8 OZ',
#   '4300001084::COOL WHIP SF TOPPING 8 OZ'],
#  ['28585900000::FRESH TORTILLA CHIPS LB',
#   '2100002449::TB SALSA CON QUESO MILD 15 OZ',
#   '2100002449::TB SALSA CON QUESO MILD 15 OZ',
#   '85817600296::BODY ARMOR LYTE SPORTS DK TROP COCNT 16',
#   '85817600296::BODY ARMOR LYTE SPORTS DK TROP COCNT 16',
#   '4900007932::POWERADE ZERO MIXED BERRY 28 OZ',
#   '4900055417::PADE ZERO STRAWBERRY 28 OZ'],
#  ['2100005496::KR FINE SHRD 4 CHS MEX 8 OZ',
#   '2100005496::KR FINE SHRD 4 CHS MEX 8 OZ',
#   '4335400725::CHI CHI BURRITO TORTILLA 8 CT 17 OZ',
#   '28028700000::GROUND BEEF LB',
#   '4430012330::LACHOY BEAN SPROUT 14 OZ',
#   '4600086035::OEP ENCHILADA SCE RED MILD 19 OZ',
#   '4600086035::OEP ENCHILADA SCE RED MILD 19 OZ'],
#  ['2113100032::MARIE C SHEP PIE BEEF 11.5 OZ',
#   '2113100032::MARIE C SHEP PIE BEEF 11.5 OZ',
#   '1200010735::DIET MOUNTAIN DEW .5L 6 PK',
#   '1200010735::DIET MOUNTAIN DEW .5L 6 PK',
#   '1200010735::DIET MOUNTAIN DEW .5L 6 PK',
#   '1200010735::DIET MOUNTAIN DEW .5L 6 PK'],
#  ['3620034430::RAGU PASTA SC 4 CHEESE 16 OZ',
#   '3620034430::RAGU PASTA SC 4 CHEESE 16 OZ'],
#  ['19067900828::H/ESS B/ENVY AERO SPRY   003 8 OZ',
#   '87863900021::EMJ DEO CEDARWOOD 3 OZ',
#   '86000914670::COAQUA SUPER PREM COCONUT WATER 8.4 OZ'],
#  ['28536100000::MISC HOT CHICKEN EACH',
#   '28541300000::TENDERS 1 LB',
#   '4450097650::HILLSHIRE FARM UT O/R TRK 9 OZ',
#   '1600019333::GARDETTO GARLIC RYE CHIPS 8 OZ',
#   '4900000044::COKE CLASSIC 20 OZ'],
#  ['7003834340::AS WATER DISTILLED 128 OZ',
#   '6414428266::ROTEL HOT TOM HAB 10 OZ',
#   '4166::ONIONS SWEET LB',
#   '4061::LETTUCE  EA'],
#  ['88491211762::POST GOLDEN CRISP 14.75 OZ',
#   '88491211171::POST HONEYCOMB 12.5 OZ',
#   '4660003387::ARM CHEESE PIZZA PEG 2.45 OZ',
#   '2529300099::SILK PURE ALMOND VAN 64 OZ',
#   '9147504189::MILO SWEET TEA GAL',
#   '4246::STRAWBERRIES   1 LB',
#   '4246::STRAWBERRIES   1 LB',
#   '7294560136::SL CL HNY WHE 20 OZ',
#   '4660003387::ARM CHEESE PIZZA PEG 2.45 OZ',
#   '4470036114::OM LC CHEESE PIZZA FP 10.6 OZ',
#   '4470036114::OM LC CHEESE PIZZA FP 10.6 OZ',
#   '1800081781::PILLS R/B CHOC CHK/CHIP 16 OZ',
#   '28335000000::STRAWBERRY CHUNKS LB',
#   '3338366602::CARROTS BABY PEEL 1 LB',
#   '3338366602::CARROTS BABY PEEL 1 LB',
#   '4388::MANDARINS 3  LB',
#   '7020085727::MARZETTI RANCH VEGGIE DIP 12 OZ',
#   '7020085727::MARZETTI RANCH VEGGIE DIP 12 OZ',
#   '700::MISC FLORAL GIFTWARE',
#   '7294560136::SL CL HNY WHE 20 OZ'],
#  ['4134400006::MULLENS DRSNG IMITATION FRENCH 16 OZ',
#   '4134400006::MULLENS DRSNG IMITATION FRENCH 16 OZ'],
#  ['7934068666::ADHS CONST PL PREM 10 OZ',
#   '3890206593::1LB-TAN STR DECK PLUS 10X3'],
#  ...]

# %% [markdown]
# ## Preprocessing

# %%
# one-hot encode the transactions
te = TransactionEncoder()
te_array = te.fit(transaction_list).transform(transaction_list)
ds_encoded = pd.DataFrame(te_array, columns=te.columns_)

# %%
ds_encoded.head()
# Out:
#    1022810403::CH LINEN SPRAY DISINFECTANT 6 OZ  \
# 0                                         False
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
#
#    1037416201::TFT STRWBRY CHEESECAKE 16 OZ  \
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                     False
# 4                                     False
#
#    1037416205::CHEESECAKE VARIETY SAMPLER 16 OZ  \
# 0                                         False
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
#
#    1037416270::HERSHEY SMORE CHSCK 16OZ  \
# 0                                 False
# 1                                 False
# 2                                 False
# 3                                 False
# 4                                 False
#
#    1037442060::FT NY PLAIN CHSECAKE 40 OZ  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
#
#    1037442063::FATHERS TABLE FUDGE B CHEESECAKE 40 OZ  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    1037442065::4 VARIETY CHEESCAKE 40 OZ  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
#
#    1063144400474::FLDNG CHAIR CNNMN 34.8H  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
#
#    1066807502::CAMS COFFEE BAG STHRN PCN 12 OZ  \
# 0                                        False
# 1                                        False
# 2                                        False
# 3                                        False
# 4                                        False
#
#    1066807519::CAMS COFFEE BAG JAMAICA 10 OZ  ...  \
# 0                                      False  ...
# 1                                      False  ...
# 2                                      False  ...
# 3                                      False  ...
# 4                                      False  ...
#
#    9908746640::BRAUNSCHWEIGER 1 LB  9908746840::OLD WORLD SUMMER SAUSAGE  \
# 0                            False                                 False
# 1                            False                                 False
# 2                            False                                 False
# 3                            False                                 False
# 4                            False                                 False
#
#    9955508003::GM KCUP COLOMBIAN 12 COUNT  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
#
#    9990010025::NSTL BUTTERFINGER FUN SIZE 6 PK  \
# 0                                        False
# 1                                        False
# 2                                        False
# 3                                        False
# 4                                        False
#
#    9990010087::NSTL BUTRFINGER BAR 1.9 OZ  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
#
#    9990050589::NSTL CRUNCH FS BAG 10 OZ  9990062546::BABYRUTH SNGL 1.9 OZ  \
# 0                                 False                             False
# 1                                 False                             False
# 2                                 False                             False
# 3                                 False                             False
# 4                                 False                             False
#
#    9990069423::100 GRAND BAR 1.5 OZ  \
# 0                             False
# 1                             False
# 2                             False
# 3                             False
# 4                             False
#
#    9990083720::NSTL BABY RUTH FUNSZ LDB 10.2 OZ  \
# 0                                         False
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
#
#    9990090836::NESTLE CRUNCH BARS 1.55 OZ
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
#
# [5 rows x 8227 columns]

# %% [markdown]
# ## Create Itemsets

# %%
frequent_itemsets = fpgrowth(ds_encoded, min_support=0.002, use_colnames=True)

# %%
frequent_itemsets.tail()
# Out:
#       support                                           itemsets
# 665  0.003328    (4635::GRAPES RED SEEDLESS LB, 4011::BANANA LB)
# 666  0.002080  (1290000700::DESSERT SHELLS 6 CT, 4246::STRAWB...
# 667  0.002496  (28309600000::SQUASH ZUCCHINI LB, 28328000000:...
# 668  0.002288  (1128400311::JJ PEACH SNACK PIE 4 OZ, 11284003...
# 669  0.002080  (2412601700::LEWIS 1/2 LOAF NUTTY OAT 12 OZ, 4...

# %%
fi = frequent_itemsets.sort_values(by='support', ascending=False)
fi.tail(20)
# Out:
#      support                                           itemsets
# 583  0.00208  (4246::STRAWBERRIES   1 LB, 4799::TOMATOES HOT...
# 306  0.00208          (7003865399::BST CH SHRD XSHRP CHDR 8 OZ)
# 600  0.00208  (4246::STRAWBERRIES   1 LB, 3560081300::KY LEG...
# 602  0.00208  (4011::BANANA LB, 7342000011::DAISY SOUR CREAM...
# 260  0.00208    (65272971079::BC HMB HLP CHSY HASHBROWN 5.5 OZ)
# 219  0.00208                (7273062042::PF ENG TOFFEE 16.5 OZ)
# 215  0.00208          (2100002522::KR CLBY M/JACK CUBES 6.4 OZ)
# 607  0.00208  (89661200040::STAND ANNUAL PLANTS 4 IN, 702::F...
# 229  0.00208              (2100061146::KR VELV SPRD SNGL 16 OZ)
# 227  0.00208                    (79590251557::CARD MDAY ANYONE)
# 237  0.00208        (1200024075::MT DEW BAJA BLAST CABO CITRUS)
# 226  0.00208                    (79590255930::CARD MDAY MOTHER)
# 625  0.00208  (7003837280::BST CH GR A LARGE EGG 1 DZ, 28000...
# 662  0.00208  (1600012479::GM HONEY NUT CHEERIOS 10.8 OZ, 96...
# 664  0.00208          (4196::GALA APPLES 3 LB, 4011::BANANA LB)
# 663  0.00208        (3338366400::CARROTS 1 LB, 4011::BANANA LB)
# 640  0.00208  (28517000000::MISC HOT FOODS EACH, 28541300000...
# 666  0.00208  (1290000700::DESSERT SHELLS 6 CT, 4246::STRAWB...
# 6    0.00208                    (79590254088::CARD MDAY ANYONE)
# 669  0.00208  (2412601700::LEWIS 1/2 LOAF NUTTY OAT 12 OZ, 4...

# %% [markdown]
# ## Create rules

# %%
rules = association_rules(frequent_itemsets,metric="lift", min_threshold=0.5)
print(rules.sort_values(by='lift', ascending=False).head(10))
# Out:
#                                            antecedents  \
# 123          (3224756523::MG POTTING MIX SOIL 2 CF EA)
# 122                    (29999500000::MG POTTING MIX S)
# 222        (1600012479::GM HONEY NUT CHEERIOS 10.8 OZ)
# 223  (960000003553::CPN: Buy 2 Save $2 on GM Cereal...
# 235            (1128400303::JJ BERRY FRT SNK PIE 4 OZ)
# 234              (1128400311::JJ PEACH SNACK PIE 4 OZ)
# 232                  (28309600000::SQUASH ZUCCHINI LB)
# 233                    (28328000000::SQUASH YELLOW LB)
# 173                           (4689::PEPPER YELLOW EA)
# 172                           (3121::PEPPER ORANGE EA)
#
#                                            consequents  antecedent support  \
# 123                    (29999500000::MG POTTING MIX S)            0.002288
# 122          (3224756523::MG POTTING MIX SOIL 2 CF EA)            0.002288
# 222  (960000003553::CPN: Buy 2 Save $2 on GM Cereal...            0.004576
# 223        (1600012479::GM HONEY NUT CHEERIOS 10.8 OZ)            0.002496
# 235              (1128400311::JJ PEACH SNACK PIE 4 OZ)            0.005408
# 234            (1128400303::JJ BERRY FRT SNK PIE 4 OZ)            0.003120
# 232                    (28328000000::SQUASH YELLOW LB)            0.006656
# 233                  (28309600000::SQUASH ZUCCHINI LB)            0.004992
# 173                           (3121::PEPPER ORANGE EA)            0.005616
# 172                           (4689::PEPPER YELLOW EA)            0.007072
#
#      consequent support   support  confidence        lift  representativity  \
# 123            0.002288  0.002288    1.000000  437.090909               1.0
# 122            0.002288  0.002288    1.000000  437.090909               1.0
# 222            0.002496  0.002080    0.454545  182.121212               1.0
# 223            0.004576  0.002080    0.833333  182.121212               1.0
# 235            0.003120  0.002288    0.423077  135.610256               1.0
# 234            0.005408  0.002288    0.733333  135.610256               1.0
# 232            0.004992  0.002496    0.375000   75.125000               1.0
# 233            0.006656  0.002496    0.500000   75.125000               1.0
# 173            0.007072  0.002288    0.407407   57.612200               1.0
# 172            0.005616  0.002288    0.323529   57.612200               1.0
#
#      leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 123  0.002283         inf       1.000000  1.000000   1.000000    1.000000
# 122  0.002283         inf       1.000000  1.000000   1.000000    1.000000
# 222  0.002068    1.828758       0.999081  0.416667   0.453181    0.643939
# 223  0.002068    5.972546       0.996997  0.416667   0.832567    0.643939
# 235  0.002271    1.727926       0.998023  0.366667   0.421271    0.578205
# 234  0.002271    3.729721       0.995732  0.366667   0.731883    0.578205
# 232  0.002463    1.592013       0.993300  0.272727   0.371865    0.437500
# 233  0.002463    1.986689       0.991639  0.272727   0.496650    0.437500
# 173  0.002248    1.675567       0.988192  0.220000   0.403187    0.365468
# 172  0.002248    1.469959       0.989641  0.220000   0.319709    0.365468

# %%
def format_rule(row):
    antecedent = ' + '.join(sorted(row['antecedents']))
    consequent = ', '.join(sorted(row['consequents']))
    return f"If a customer buys {antecedent}, they also buy {consequent} (Lift: {row['lift']:.2f}, Confidence: {row['confidence']:.0%})"

# %%
rules['rule_summary'] = rules.apply(format_rule, axis=1)

# %%
rules.head()
# Out:
#                              antecedents  \
# 0  (2412601435::BUNNY HONEY WHEAT 20 OZ)
# 1                      (4011::BANANA LB)
# 2         (3283::APPLE WA HONEYCRISP LB)
# 3                      (4011::BANANA LB)
# 4         (3283::APPLE WA HONEYCRISP LB)
#
#                              consequents  antecedent support  \
# 0                      (4011::BANANA LB)            0.015391
# 1  (2412601435::BUNNY HONEY WHEAT 20 OZ)            0.085067
# 2                      (4011::BANANA LB)            0.006864
# 3         (3283::APPLE WA HONEYCRISP LB)            0.085067
# 4            (4246::STRAWBERRIES   1 LB)            0.006864
#
#    consequent support   support  confidence      lift  representativity  \
# 0            0.085067  0.002496    0.162162  1.906297               1.0
# 1            0.015391  0.002496    0.029340  1.906297               1.0
# 2            0.085067  0.002288    0.333333  3.918500               1.0
# 3            0.006864  0.002288    0.026895  3.918500               1.0
# 4            0.048669  0.002496    0.363636  7.471639               1.0
#
#    leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski  \
# 0  0.001187    1.092017       0.482855  0.025478   0.084264    0.095751
# 1  0.001187    1.014370       0.519626  0.025478   0.014167    0.095751
# 2  0.001704    1.372400       0.749948  0.025522   0.271350    0.180114
# 3  0.001704    1.020585       0.814049  0.025522   0.020170    0.180114
# 4  0.002162    1.494949       0.872147  0.047059   0.331081    0.207459
#
#                                         rule_summary
# 0  If a customer buys 2412601435::BUNNY HONEY WHE...
# 1  If a customer buys 4011::BANANA LB, they also ...
# 2  If a customer buys 3283::APPLE WA HONEYCRISP L...
# 3  If a customer buys 4011::BANANA LB, they also ...
# 4  If a customer buys 3283::APPLE WA HONEYCRISP L...

# %%
rules.to_csv('../data/association_rules.csv', index=False)

# %%
print(rules[['rule_summary', 'lift']].sort_values(by='lift', ascending=False).head(20))
# Out:
#                                           rule_summary        lift
# 123  If a customer buys 3224756523::MG POTTING MIX ...  437.090909
# 122  If a customer buys 29999500000::MG POTTING MIX...  437.090909
# 222  If a customer buys 1600012479::GM HONEY NUT CH...  182.121212
# 223  If a customer buys 960000003553::CPN: Buy 2 Sa...  182.121212
# 235  If a customer buys 1128400303::JJ BERRY FRT SN...  135.610256
# 234  If a customer buys 1128400311::JJ PEACH SNACK ...  135.610256
# 232  If a customer buys 28309600000::SQUASH ZUCCHIN...   75.125000
# 233  If a customer buys 28328000000::SQUASH YELLOW ...   75.125000
# 173  If a customer buys 4689::PEPPER YELLOW EA, the...   57.612200
# 172  If a customer buys 3121::PEPPER ORANGE EA, the...   57.612200
# 101  If a customer buys 2840051646::DORITOS NACHO C...   45.695868
# 100  If a customer buys 2840051631::DORITOS COOL RA...   45.695868
# 170  If a customer buys 4088::PEPPER  RED EA, they ...   42.737778
# 171  If a customer buys 4689::PEPPER YELLOW EA, the...   42.737778
# 167  If a customer buys 3121::PEPPER ORANGE EA, the...   42.423529
# 166  If a customer buys 4088::PEPPER  RED EA, they ...   42.423529
# 111  If a customer buys 89661201204::FLOWER BEDDING...   30.526984
# 110  If a customer buys 89661200040::STAND ANNUAL P...   30.526984
# 219  If a customer buys 4252::BLUEBERRIES PINT, the...   30.125313
# 218  If a customer buys 4054::RASPBERRIES 6 OZ, the...   30.125313

# %%
sorted_rules = rules[['rule_summary', 'lift', 'confidence']].sort_values(by='lift', ascending=False)

# %%
sorted_rules
# Out:
#                                           rule_summary        lift  confidence
# 123  If a customer buys 3224756523::MG POTTING MIX ...  437.090909    1.000000
# 122  If a customer buys 29999500000::MG POTTING MIX...  437.090909    1.000000
# 222  If a customer buys 1600012479::GM HONEY NUT CH...  182.121212    0.454545
# 223  If a customer buys 960000003553::CPN: Buy 2 Sa...  182.121212    0.833333
# 235  If a customer buys 1128400303::JJ BERRY FRT SN...  135.610256    0.423077
# ..                                                 ...         ...         ...
# 18   If a customer buys 599::SINGLE DONUT, they als...    1.035984    0.050420
# 89   If a customer buys 4011::BANANA LB, they also ...    0.984754    0.039120
# 88   If a customer buys 28517000000::MISC HOT FOODS...    0.984754    0.083770
# 153  If a customer buys 4011::BANANA LB, they also ...    0.979625    0.029340
# 152  If a customer buys 28536100000::MISC HOT CHICK...    0.979625    0.083333
#
# [238 rows x 3 columns]

# %%
sorted_rules.to_csv('../data/sorted_association_rules.csv', index=False)
