# %% [markdown]
# ## Import Libraries

# %%
import sys
import os

import numpy as np
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import fpgrowth, association_rules

sys.path.append(os.path.abspath('..'))
from utils.db import get_db

# %%
engine = get_db()

# %% [markdown]
# ## Gather Data

# %% [markdown]
# select sale_date, sale_id, product_code, product_description, qty, total_sales, sub_department_description,
# sale_type, item_ring_type
# from sales
# where store_number='440'
# and sale_date='5/15/2025'
# and sale_type in ('Refunded', 'Sale')
# and item_ring_type in ('ITEM')

# %%
query = """select sale_date, sale_id, product_code, product_description, qty, total_sales, sub_department_description,
sale_type, item_ring_type
from sales
where store_number='440'
and sale_date between '5/10/2025' and '5/15/2025'
and sale_type in ('Refunded', 'Sale')
and item_ring_type in ('ITEM')"""

# %%
#ds = pd.read_csv('../data/local_daily_basket_analysis_for_items_purchased_together.csv')

# %%
ds = pd.read_sql(query,engine)
# Out:
# 2025-06-11 16:03:08,205 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-06-11 16:03:08,205 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-06-11 16:03:08,205 INFO sqlalchemy.engine.Engine [cached since 1.143e+04s ago] {'table_name': "select sale_date, sale_id, product_code, product_description, qty, total_sales, sub_department_description,\nsale_type, item_ring_type\nfrom sales\nwhere store_number='440'\nand sale_date between '5/10/2025' and '5/15/2025'\nand sale_type in ('Refunded', 'Sale')\nand item_ring_type in ('ITEM')", 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-06-11 16:03:08,260 INFO sqlalchemy.engine.Engine select sale_date, sale_id, product_code, product_description, qty, total_sales, sub_department_description,
# sale_type, item_ring_type
# from sales
# where store_number='440'
# and sale_date between '5/10/2025' and '5/15/2025'
# and sale_type in ('Refunded', 'Sale')
# and item_ring_type in ('ITEM')
# 2025-06-11 16:03:08,260 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-06-11 16:03:11,100 INFO sqlalchemy.engine.Engine ROLLBACK

# %%
ds.head()
# Out:
#    sale_date  sale_id product_code product_description  qty  total_sales  \
# 0 2025-05-15   374576        467.0        ACE HARDWARE  3.0         0.57
# 1 2025-05-15   106319       4011.0           BANANA LB  1.0         1.81
# 2 2025-05-10   102508          2.0            UNLEADED  1.0        54.65
# 3 2025-05-10   102505          2.0            UNLEADED  1.0        23.40
# 4 2025-05-10   102501          2.0            UNLEADED  1.0        20.10
#
#   sub_department_description sale_type item_ring_type
# 0          Hillman Fasteners      Sale           ITEM
# 1                Wic Produce      Sale           ITEM
# 2                   Unleaded      Sale           ITEM
# 3                   Unleaded      Sale           ITEM
# 4                   Unleaded      Sale           ITEM

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41030 entries, 0 to 41029
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   sale_date                   41030 non-null  datetime64[ns]
#  1   sale_id                     41030 non-null  int64
#  2   product_code                41030 non-null  object
#  3   product_description         41030 non-null  object
#  4   qty                         41030 non-null  float64
#  5   total_sales                 41030 non-null  float64
#  6   sub_department_description  41030 non-null  object
#  7   sale_type                   41030 non-null  object
#  8   item_ring_type              41030 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(5)
# memory usage: 2.8+ MB

# %% [markdown]
# ## Clean Data

# %%
# lets filter this down to just items
ds = ds[ds['item_ring_type'] == 'ITEM']

# %%
#now lets get rid of any empty products
ds.dropna(subset=['product_description', 'sale_id'], inplace=True)

# %%
# convert sale_id to string
ds['sale_id'] = ds['sale_id'].astype(str)

# %%
transactions = ds.groupby('sale_id')['product_description'].apply(list)

# %%
transactions.head()
# Out:
# sale_id
# 102481     [PREMIUM]
# 102482    [UNLEADED]
# 102483    [UNLEADED]
# 102484    [UNLEADED]
# 102486    [UNLEADED]
# Name: product_description, dtype: object

# %%
# filter out single item transactions as these wont apply
transactions_filtered = transactions[transactions.apply(lambda x: len(x) > 1)]
transaction_list = transactions_filtered.tolist()

# %%
len(transaction_list)
# Out:
# 4808

# %%
transaction_list[:-20]
# Out:
# [['KEB ZESTA SALTINES 16 OZ',
#   'BST CH GRD A LRG 18P EGG 1.5 DZ',
#   'DAISY 4% CTGE CHS/PINAPL 6 OZ',
#   'MC PURE VANILLA EXTRACT 1 OZ',
#   'VEL SHRP CHDR SNGLS 12 OZ',
#   'LEAN GROUND BEEF LB',
#   'LAYS LIGHTLY SALTED 7.75 OZ',
#   'LEAN GROUND BEEF LB',
#   'SUMMER SAUSAGE W/JALAPENO AND CHEESE',
#   'BANANA LB',
#   'APPLE WA HONEYCRISP LB',
#   'DAISY 4% CTGE CHS/PINAPL 6 OZ',
#   'DAISY PEACH COTT CHS 6 OZ',
#   'DAISY PEACH COTT CHS 6 OZ',
#   'CARD MDAY ANYONE',
#   'PRAIRIE FARM 2% MILK GL 128 OZ',
#   'BUNNY HONEY WHEAT 20 OZ'],
#  ['YOU ARE MY SUNSHINE BQT BQT', 'COUNTRY GIRL CHARM FLOWER BQT'],
#  ['BRKSTN RICOTTA CHEESE 15 OZ',
#   'BRKSTN RICOTTA CHEESE 15 OZ',
#   'SCOPE MW OUTLAST FRESH MINT 16.9 OZ',
#   'PRAIRIE FARM WHOLE MILK 128 OZ',
#   'MICK CHOC TRUFFLE MINT EACH',
#   'DARK CHOC TRUFFLE EACH',
#   'BORDEN HEAVY WHIPNG CREAM 16 OZ',
#   'BORDEN HEAVY WHIPNG CREAM 16 OZ'],
#  ['VARIETY DOZEN DONUT',
#   'MISC FLORAL GIFTWARE',
#   'MISC FLORAL GIFTWARE',
#   'CHOCOLATE CHIP COOKIE',
#   'MISC BALLOON ORDER'],
#  ['AIRBORNE GUMMIES 21 CT', 'SINGLE DONUT'],
#  ['FLORAL SEASONAL', 'FLORAL SEASONAL'],
#  ['DOMINO 10X POWDER SUGAR 32 OZ', 'DOMINO 10X POWDER SUGAR 32 OZ'],
#  ['BLUEBERRIES PINT',
#   'STRAWBERRIES   1 LB',
#   'KINGS HAWAIIAN ROLLS 20 OZ',
#   'MEOW MIX ORIGINAL 16 LB',
#   'MOUNTAIN DEW 24 PK',
#   'GAT ZERO GLACIER FREEZE 20OZ 8P 8 PK',
#   'KR STRING UMS CHEESE 12 OZ',
#   'LOF PREM DELI HNY HA 16 OZ',
#   'LOF PRM DELI TKY BRS 16 OZ'],
#  ['FP CENTER CUT RIB CHOPS LB',
#   'KY LEG HICKRY SMK SLICED BACON 1 LB',
#   'ANGUS CUBE STEAK LB',
#   'KL B BACON 16 OZ',
#   'KY LEG HICKRY SMK SLICED BACON 1 LB',
#   'ANGUS CUBE STEAK LB',
#   'SF 7 TRAY CF DRUMS LB',
#   'SF 7 TRAY CF DRUMS LB',
#   'FP WHOLE PNLS PORK LOIN LB',
#   'MOUNTAIN DEW 24 PK',
#   'KL DICED HAM 8 OZ',
#   'KL DICED HAM 8 OZ',
#   'BNLS PORK STEAK LB',
#   'PORK STEAK LB',
#   ' SMOKED PORK HOCKS LB',
#   'FP CENTER CUT RIB CHOPS LB'],
#  ['TOTINO 3 MEAT PIZZA 10.5 OZ',
#   'TOTINO PEPPERONI PIZZA 10.2 OZ',
#   'PEPPER GREEN EA',
#   'ONIONS GREEN 5.5 OZ',
#   'SEA BEST 30/40 E-Z PEEL SHRIMP 1 LB',
#   'SEA BEST 30/40 E-Z PEEL SHRIMP 1 LB',
#   'TOTINO PEPPERONI PIZZA 10.2 OZ',
#   'BEANS GREEN LB',
#   'GORTONS THR FISH FILLETS 24.5 Z',
#   'FP GROUND CHUCK LEAN LB',
#   'FP GROUND CHUCK LEAN LB',
#   'AM CH MILK WHOLE GAL 128 OZ',
#   'POTATO RUSSET 5 LB',
#   'BUNNY 4 PLAIN HAMBURGER 12 PK 12 PK',
#   'BUNNY 4 PLAIN HAMBURGER 12 PK 12 PK',
#   'BST CHCE ROUND TOP 20 OZ',
#   'BC HONEYWHEAT 20 OZ',
#   'LOL BUTTER QUARTERS 16 OZ',
#   'ONIONS SWEET 3 LB',
#   'CABBAGE GREEN LB',
#   'TRYME TIGER SAUCE THE ORIGINAL 10 OZ',
#   'JIFFY CORN MUFFIN MIX 8.5 OZ',
#   'JIFFY CORN MUFFIN MIX 8.5 OZ',
#   'JAR DIP TOSTITOS QUESO 15 OZ',
#   'CNTRY BOB AP SAUCE 13 OZ',
#   'CNTRY BOB AP SAUCE 13 OZ',
#   'CNTRY BOB AP SAUCE 13 OZ',
#   'CNTRY BOB AP SAUCE 13 OZ',
#   'SMUCKER SQUEEZE GRAPE JELLY 20 OZ',
#   'KR MIRACLE WHIP 30 OZ',
#   'CPN: $1 off (3) Totinos Pizzas or Rolls 5/7-5',
#   'TOTINO 3 MEAT PIZZA 10.5 OZ',
#   'TOTINO 3 MEAT PIZZA 10.5 OZ',
#   'TOTINO PEPPERONI PIZZA 10.2 OZ'],
#  ['RED BULL SUGAR FREE SUMMER EDITION WHITE',
#   'BROWNIE FACTORY EACH',
#   'KR FINE SHRD MEX TACO 8 OZ',
#   'BST CH TORTILLA BURRITO 8 CT',
#   'FRITO LAY SANTITAS WHITE 11 OZ'],
#  ['DIET MOUNTAIN DEW .5L 6 PK',
#   'TOMATOES HOT HOUSE LARGE LB',
#   'BANANA LB',
#   'SINGLE DONUT',
#   'PF SOFT WHITE HAMBURGER BUNS 14.5 OZ',
#   'LBS BUTTERMILK BREAD HALF LOAF 12 OZ',
#   'ASE HAWAIIAN HAM EACH'],
#  ['ROSE MIX BQT', 'SUNKIST ZERO ORANGE SODA 20 OZ'],
#  ['BST CH GRD A LRG 18P EGG 1.5 DZ',
#   'VEGETABLE BEDDING 4 CELL EA',
#   'VEGETABLE BEDDING 4 CELL EA',
#   'VEGETABLE BEDDING 4 CELL EA'],
#  ['JJ LEMON CREAM PIE 4 OZ',
#   'PRAIRIE FARMS WHOLE MILK 64 OZ',
#   'VARIETY DOZEN DONUT',
#   'VARIETY DOZEN DONUT',
#   'PRAIRIE FARMS WHOLE CHOC 64 OZ'],
#  ['KR FINE SHRD SHP CHD 8 OZ',
#   'COLEMAN PROPANE CYLINDER 16 OZ',
#   'POTATO IDAHO LOOSE BAKER LB',
#   'BST CH BACON PIECES REAL 2.8 OZ',
#   'PR NY STRP STK EA',
#   'PR NY STRP STK EA'],
#  ['PLUG I/M TYPE QC 1/4MPT',
#   'AIR CHUCK FEMALE 1/4NPT',
#   'PLUG I/M TYPE QC 1/4MPT',
#   'DIET COKE 20 OZ',
#   'GATORADE COOL BLUE 20 OZ',
#   'HOSTESS CHOCOLATE CUPCAKES 2 CT 3.17 OZ',
#   'THRD SL TAPE1/2X260'],
#  ['DOZEN ROSE BOUQUET BQT', 'MISC FLORAL GIFTWARE'],
#  ['CARD MDAY GRANDMOTHER',
#   'CARD MDAY ANYONE',
#   'DIET COKE 24 PK 12 OZ 288 OZ',
#   'KRETSCHMAR OVN RSTD TRKY BRST EACH',
#   'ROMAINE HEARTS 3 PK',
#   'APPLE WA HONEYCRISP LB'],
#  ['CAN DIP JALAPENO  CHEDDAR 9 OZ',
#   'DORITOS NACHO CHEESE 9.25 OZ',
#   'GROUND BEEF LB',
#   'HOMEMADE CHICKEN N NOODL LB',
#   'CAROLINA PRIDE BOLOGNA 6 OZ',
#   'MANWICH THICK CHUNKY SLOPPY JOE SCE 15.5',
#   'KR BBQ SCE ORIGINAL 18 OZ',
#   'CP CHOPPED HAM PEG 5 OZ',
#   'CAR PRD BLK FRST HAM 4 OZ',
#   'KR BBQ SCE SWT&SPICY 18 OZ',
#   'MILO SWEET TEA GAL',
#   'SPRINGER MNTN BONE IN THIGHS',
#   'S GATE CHILI W/BNS 15 OZ',
#   'S GATE CHILI W/BNS 15 OZ',
#   'JOHNS ORIG RECIPE SAUSGE 12 O'],
#  ['CUCUMBER MINI EA',
#   'MANDARINS 3  LB',
#   'LEWIS 1/2 LOAF 100% WHOLE WHEAT 12 OZ',
#   'PF LEMON RASPBERRY CHEESCAKE 48 OZ',
#   'LETTUCE  EA',
#   'MINI TRI COLOR PEPPERS RS 1 LB',
#   'TOMATOES NATURE  SWEET CHERUB 10 OZ'],
#  ['BNTY 8TR SAS WHITE',
#   'REAL VANILLA SYRP 16.9 OZ',
#   'SINGLE DONUT',
#   'SIMPLY LEMONADE RASP 52 OZ',
#   'STRWBRY/PINEPLE/BLUBRY MIX LB',
#   'PRAIRIE FARM WHOLE MILK 128 OZ',
#   'DOLE TROP FRUIT BOWL 4 PK',
#   'BORDN HALF AND HALF 32 OZ',
#   'MANDARINS 3  LB',
#   'POST MARSHMALLOW FRUITY PEBBLES 11 OZ',
#   'KEL PTART FROST BRWN SGR CIN 8 CT',
#   'PRAIRIE FARMS CHOCOLATE MILK 16 OZ',
#   'BST CH SHRED FANCY  COLBY JACK 8 OZ',
#   'JD APPLEWD SMKD BCN 12 OZ',
#   'SPRITE 12 PK 144 OZ',
#   'ICE MOUNTAIN 16.9 OZ 24 PK PET 405.6 OZ',
#   'TOSTITOS CANTINA THIN AN CRISPY 10 OZ',
#   'FIELD OL FASH FRNK 14 OZ',
#   'GUMMI NEON WORMS 15 OZ',
#   'PDQ GLOW NECKLACE PDQ'],
#  ['MONSTER ULTRA SUNRISE 16 OZ', 'SINGLE DONUT'],
#  ['SHEET CAKE FLORAL EACH', 'AS ICE CREAM NEAPOLITAN 128 OZ'],
#  ['ECKRICH BOLOGNA 12 OZ',
#   'ECKRICH BOLOGNA 12 OZ',
#   'BANANA LB',
#   'RUFFLES CHEDDAR SOUR CREAM 8 OZ'],
#  ['LIL DEBBIE NUTTY BARS 25.2 OZ',
#   'LIL DEBBIE NUTTY BARS 25.2 OZ',
#   'SINGLE DONUT'],
#  ['BST CH SHRED FANCY CHDR MLD RF 2% 8 OZ',
#   'KEL FF GLZ DNT HL 10 OZ',
#   'CORN POPS CEREAL 16.4 OZ',
#   'AM CH MILK 2% GALN 128 OZ',
#   'KR DLX MAC DINNER 3PK 42 OZ 42 OZ',
#   'OM REAL BACON RECIPE PIECES 2.8 OZ',
#   'OM REAL BACON RECIPE PIECES 2.8 OZ',
#   'BST CH SHRED FANCY CHDR MLD RF 2% 8 OZ'],
#  ['RAGU OWS TRAD RETRO SAUCE LE 24 OZ',
#   'RAGU OWS TRAD RETRO SAUCE LE 24 OZ',
#   'C WILLIE BTR EXPLOSION POPCORN 6 PK',
#   'CPN: C WILLIE BTR EXPLOSION POPCORN 6 PK'],
#  ['SINGLE DONUT', 'GENERAL TSO MEAL 19 OZ', 'SPRITE 20 OZ'],
#  ['FRESH ARRANGEMENT OR STEMS', 'CARD MDAY ANYONE', 'CARD MDAY ANYONE'],
#  ['CF A/N GROUND CHICKEN 16 OZ', 'CPN: CF A/N GROUND CHICKEN 16 OZ'],
#  ['PEPSI 24 PK',
#   'SUKARNE BF RIBEYE STK LB',
#   'SUKARNE BF RIBEYE STK LB',
#   'SUKARNE BF RIBEYE STK LB',
#   'MISC HOT FOODS EACH'],
#  ['KBLR CRKR CLUB CHEDDAR 8 CT',
#   'DR PEPPER .5L 6 PK',
#   'DT DR PEPPER 6 PK 101.4 OZ',
#   'KBLR CRKR TOAST N PB 10.9 OZ',
#   'SUNCHIPS GARDEN SALSA 7 OZ',
#   'SUNCHIPS HARVEST CHEDDAR 7 OZ',
#   'DR PEPPER .5L 6 PK',
#   'DT DR PEPPER 6 PK 101.4 OZ',
#   'WLCH FRT SNK MXD FRT 10 CT',
#   'COOKIE POP OREO PPCR 5.25 OZ',
#   'COOKIE POP OREO PPCR 5.25 OZ',
#   'BST CH FUDGE STRIPE COOKIE 13 OZ'],
#  ['  BUTTERFLY  PORK CHOPS LB',
#   'AM CH MILK 2% GALN 128 OZ',
#   'BUNNY HAMBURGER BUNS 8 CT',
#   'BUNNY HOT DOG BUNS 12 OZ 8 CT',
#   'BB NEAPOLITAN PREMIUM ICE CREAM 48 OZ',
#   'B BUNNY PEANUT BUTTER PARTY 46 OZ'],
#  ['ECKRICH ORIG SKNLS SAUSAGE 14 OZ.',
#   'ECKRICH ORIG SKNLS SAUSAGE 14 OZ.',
#   'AM CH MILK 2% GALN 128 OZ',
#   'NESTLE CRUNCH BARS 1.55 OZ'],
#  ['AS DRESSING ITALAIN 16 OZ', 'AS DRESSING ITALAIN 16 OZ'],
#  ['HARIBO SOUR GOLDBEAR 7 OZ',
#   'DOVE DRY SP CL ESSNS 3.8 OZ',
#   'APPLE WA HONEYCRISP LB',
#   'DELI BEVERAGE EACH'],
#  ['RB SUMMER EDITION JUNEBERRY 12 OZ', 'BROWNIES EACH', 'PECAN TARTS 9.2 OZ'],
#  ['DORITOS TANGY GLDN SRIR 9.25 OZ',
#   'SELECT ANGUS NY STRIP EA',
#   'FRSH DILL CHKN SALAD',
#   'KY LEG APPLWOD SMK SLCED BACON 1 LB',
#   'POTATO IDAHO MINUTE BAKER EA',
#   'POTATO IDAHO MINUTE BAKER EA',
#   'POTATO IDAHO MINUTE BAKER EA',
#   'MISC HOT FOODS EACH',
#   'DORITOS COOL RANCH 9.25 OZ',
#   'DORITOS COOL RANCH 9.25 OZ',
#   'SELECT ANGUS NY STRIP EA'],
#  ['SPRAYR HOUSEHOLD16OZ ACE',
#   'AS LS REG BLEACH 128 OZ',
#   'KITCHEN SCRUBBER EA',
#   'WRENCH SERVICE DISPOSER',
#   'AS PAPER PLATES 100 CT',
#   'BST CH PLASTIC CUTLERY 144 CT',
#   'DRANO MAX CLOG REMOVR 32 OZ',
#   'COMET REGULAR POWDER 21 OZ',
#   'COMET REGULAR POWDER 21 OZ'],
#  ['BST CH PRUNE JUICE 64 OZ',
#   'BST CH PRUNE JUICE 64 OZ',
#   'PRAIRIE FARMS SKIM MILK 128 OZ',
#   'BST CH BLK PEP CHIP 7.75 OZ',
#   'AS CULTURED SOUR CREAM 16 OZ',
#   'AS CULTURED SOUR CREAM 16 OZ',
#   'KR BLUE BX MAC & CHS 5 CT 36.25 OZ'],
#  ['KEB CLUB MULTI GRAIN 12.7 OZ', 'KEB CLUB ORIGINAL 13.7 OZ'],
#  ['PACE PICANTE SCE MEDIUM 24 OZ',
#   'AL SAVE WAVY POT CHP 13 OZ',
#   'JJ BERRY FRT SNK PIE 4 OZ',
#   'JJ BERRY FRT SNK PIE 4 OZ',
#   'JAR DIP TOSTITOS SLSA QUESO MED 23 OZ',
#   'DEAN RANCH DIP 16 OZ',
#   'DEAN FRNCH ONION DIP',
#   'LIL HUG ASST. FLAVOR 20PK 20 CT',
#   'LIL HUG BERRY BLEND 8 OZ',
#   'BST CH CHED SC CHIPS 7.75 OZ',
#   'AL SAVE BBQ POT CHPS 12.5Z',
#   'BST CH CHED SC CHIPS 7.75 OZ'],
#  ['PF SHERBET ORANGE 64 OZ',
#   'PF PREMIUM MOOSE TRACKS 48 OZ',
#   'COOL WHIP ORIGINAL TOPPING 8 OZ'],
#  ['KR CHNK NY SHARP CHDR 8 OZ',
#   'KR CHNK NY SHARP CHDR 8 OZ',
#   'KR PHIL CREAM CHSE BAR 8 OZ',
#   'KR PHIL CREAM CHSE BAR 8 OZ',
#   'BL HOG BBQ SQZE CHAMP 24 OZ',
#   'KR CHNK NY SHARP CHDR 8 OZ',
#   'DAISY SOUR CREAM 16 OZ',
#   'KR PHIL CREAM CHSE BAR 8 OZ',
#   'KR PHIL CREAM CHSE BAR 8 OZ',
#   'LOLLIPOP DSP REFIL 1.1OZ 1.1 OZ',
#   'ENJOY LIFE CHOC CHUNK SEMI 10 OZ',
#   'BST CH STHRN STYLE HASH BROWN 32 OZ',
#   'KR CHNK NY SHARP CHDR 8 OZ'],
#  ['SM APWD BCN PK LN FL 27.2 OZ',
#   'CRMT THIN SPAGHETTI 16 OZ',
#   'CRMT SM ELBOW MAC 16 OZ',
#   'ECKRICH BEEF SMOKED LINKS ERCH',
#   'HOST FROSTED DONETTES MINI DONUTS 10.75',
#   'KY LEG APPLWOD SMK SLCED BACON 1 LB',
#   'BST CH GR A JMBO EGG 1 DZ',
#   'BUNNY SOFT TWIST 16 OZ',
#   'BUNNY HAMBURGER BUNS 8 CT',
#   'BST CH SHRED FANCY ITALIAN CHEESE 8 OZ',
#   'AM CH MILK 2% HGAL 64 OZ',
#   'BDN SLC NAT SMK PROV 6 OZ',
#   'LIVERS EACH',
#   'LIVERS EACH',
#   'PRAIRIE FARMS ICED COFFE 64 OZ',
#   'FURLANI PARMESAN GARLIC TOAST 6 CT',
#   'POTATO RUSSET 5 LB',
#   'DIET PEPSI 16.9 OZ 6 PK',
#   'TIDE SMP HEC REFRESH BRZ 117 OZ',
#   'JNSNVL SWT ITALIAN JVILLEBRT'],
#  ['GRADUATION CARD',
#   'FLOWER BEDDING 4 CELL EA',
#   'STAND ANNUAL PLANTS 4 IN',
#   'KIMBERLY FERN BIN 10 IN'],
#  ['MANDARINS 3  LB',
#   'FLORAL HANGING BASKET',
#   'MISC BALLOON ORDER',
#   'VEGETABLE BEDDING 4 CELL EA',
#   'HEART SHAPED CAKE EACH'],
#  ['XTRA LQ MT RAIN 116L 139.2 OZ',
#   'AM CH MILK WHOLE GAL 128 OZ',
#   'SUNKIST  ORANGE 12 PK'],
#  ['WATERMELON  SEEDLESS',
#   'MONSTER ZERO ULTRA 16 OZ',
#   'BC TRIPLE BERRY MUFFIN MIX 6.5 OZ',
#   'NPL PURIFIED WATER 6 PK 101.4 OZ',
#   'VITA WATER DRAGONFRUIT 6 PK 101.4 OZ',
#   'MONSTER ZERO ULTRA 16 OZ'],
#  ['APPLE WA GRANNY SMITH LB',
#   'WEDGES BY COUNT EA',
#   'LIVERS EACH',
#   'HRML F/C BACON 10.5 OZ',
#   'BUBBLE BLASTER RED EACH',
#   'NUTTY BUDDY CREM PIES 6 CT 16.91 OZ',
#   'FUNYUNS 10CT 7.5 OZ',
#   'RED BULL REGULAR 12 PK 100.8 OZ',
#   'STANDARD SIDE LB',
#   'STANDARD SIDE LB',
#   'FRITO LAY CHESTERS CHEES 4.25 OZ',
#   'NUTTY BUDDY CREM PIES 6 CT 16.91 OZ',
#   'MISC FLORAL GIFTWARE',
#   'LIVERS EACH',
#   'BIG HUG PUNCH 16 OZ',
#   'BIG HUG PUNCH 16 OZ',
#   'TUM E YUMMIE APPLE 10.1 OZ',
#   'VN SALT WATER TAFFY 11 OZ'],
#  ['MOUNTAIN DEW .5L 6 PK',
#   'COKE ZERO SUGAR 24 PK 12 OZ 288 OZ',
#   'YEAST DONUTS 6 CT',
#   'FRAPPUCCINO VANIILA 13.7 OZ 13.7 OZ 13.7',
#   'MILO SWEET TEA GAL',
#   'PRAIRIE FARMS WHOLE CHOC 64 OZ'],
#  ['GOURMET COOKIE TRAY EA', 'BUTTER PECAN FUDGE LB'],
#  ['KL DICED HAM 8 OZ',
#   'STRAWBERRIES   1 LB',
#   'STRAWBERRIES   1 LB',
#   'BH PEACH PARFAIT 15.2 OZ',
#   'HINT WATER PEACH 16 OZ',
#   'BH PROTEIN PLUS STRAWBRY 450 ML',
#   'HINT WATER PINEAPPLE 16 OZ',
#   'HINT WATER CRISP APPLE 16 OZ',
#   'HINT WATER RASPBERRY 16 OZ',
#   'SI BLACK CHERRY 17 OZ',
#   'NAKED BLUE MACHINE  SMOOTHIE 15.2 OZ',
#   'SWT RAY BBQ HAWAIIAN 18 OZ',
#   'SWT RAY BBQ HAWAIIAN 18 OZ',
#   'BST CH SODA PEACH 67.6 OZ',
#   'NAKED  RED MACHINE 15.2 OZ',
#   'PICK 5 MISC 24.99 EA',
#   'MAYFIELD BUTTER PECAN 48 OZ',
#   'MAYFIELD EX MOOSE TRACKS 48 OZ',
#   'RST STEAK SIRLOIN GAR N HERB 12 OZ',
#   'RST STEAK SIRLOIN GAR N HERB 12 OZ'],
#  ['ACE TOP SOIL 40# EA',
#   'MG POTTING MIX SOIL 2 CF EA',
#   'MG POTTING MIX S',
#   'MG POTTING MIX S'],
#  ['SILK PURE ALMOND VAN 64 OZ',
#   'PK READY TO COOK FAST FOOD NUGGET 4#',
#   'CHOB STRW 4PK 4 PK',
#   'BST CH GRD A LRG 18P EGG 1.5 DZ',
#   'PARADISE RTC POPCORN CHICKEN 4#'],
#  ['FLWR VEG GARD SO',
#   'FLWR VEG GARD SO',
#   'FLWR VEG GARD SO',
#   'FLWR VEG GARD SO',
#   'FLWR VEG GARD SO',
#   'FLWR VEG GARD SO',
#   'FLWR VEG GARD SO',
#   'FLWR VEG GARD SO',
#   'FLWR VEG GARD SO',
#   'FLWR VEG GARD SOIL 1 CF',
#   'FLWR VEG GARD SO',
#   'FLWR VEG GARD SO',
#   'FLWR VEG GARD SO'],
#  ['NY TEX GARL TOAST 8 CT',
#   'RITZ FRESH STACKS PARTY SIZE 23.7 OZ',
#   'SMKR UNCRUSTABLES GRAPE 10 CT',
#   'SMKR UNCRUSTABLES GRAPE 10 CT',
#   'ACT II BUTTER LOVERS POPCORN 6 CT 16.5 O',
#   'ACT II BUTTER LOVERS POPCORN 6 CT 16.5 O',
#   'TOTINO COMBO PZ RLS 48.85 OZ',
#   'TOTINO COMBO PZ RLS 48.85 OZ',
#   'NAB OREO DS FAM SZ 18.71 OZ',
#   'NAB OREO DS FAM SZ 18.71 OZ',
#   'CNTRY CROCK ORIG SPRD 67.5 OZ',
#   'BUNNY SOFT TWIST 16 OZ',
#   'BUNNY SOFT TWIST 16 OZ',
#   'LD ZEBRA CAKE 13 OZ',
#   'LD ZEBRA CAKE 13 OZ',
#   'BIG PK HONEY BUNS 21 OZ',
#   'KA JAMMERS TROPICAL 10PK 60 OZ',
#   'MAR RAMEN 12 PK BEEF 36 OZ',
#   'BIG PK HONEY BUNS 21 OZ',
#   'CRMT THIN SPAG 32 OZ',
#   'PREGO PASTA SC TRADITIONAL 67 OZ',
#   'PREGO PASTA SC TRADITIONAL 67 OZ',
#   'FP GROUND CHUCK LEAN LB',
#   'FP GROUND CHUCK LEAN LB',
#   'FP GROUND CHUCK LEAN LB',
#   'ECKRICH SMKD SAUSAGE 14 OZ.',
#   'ECKRICH SMKD SAUSAGE 14 OZ.',
#   'LMKR PEP PIZZA 3.3 OZ.',
#   'LMKR PEP PIZZA 3.3 OZ.',
#   'LMKR PEP PIZZA 3.3 OZ.',
#   'LMKR PEP PIZZA 3.3 OZ.',
#   'FUDGE ROUNDS 30 OZ',
#   'FUDGE ROUNDS 30 OZ',
#   'COSMIC BROWNIES 30 OZ',
#   'BP PNB CREME PIES 18.39 OZ',
#   'NUTTY BUDDY CREM PIES 6 CT 16.91 OZ',
#   'LDS BP ZEBRA CAKES 6 CT 18.4 OZ',
#   'LD BIG SWISS ROLLS 20 OZ',
#   'LD BIG SWISS ROLLS 20 OZ',
#   'CAULIFLOWER EA',
#   'CAULIFLOWER EA',
#   'BROCCOLI  CROWNS LB',
#   'POTATO RUSSET 5 LB',
#   'POTATO RUSSET 5 LB',
#   'BST CH WHITE COOKIE 13 OZ',
#   'BST CH BLUE FRST COOKIE 13 OZ',
#   'SONIC FRIES 28 OZ',
#   'SONIC FRIES 28 OZ',
#   'SONIC FRIES 28 OZ',
#   'NY TEX GARL TOAST 8 CT'],
#  ['AL SAVE GRAN SUGAR 4 LB',
#   'PILLSBURY FLOUR ALL PURPOSE 5 LB',
#   'JF UTILITY PANS 2 CT',
#   'A&H BAKING SODA 16 OZ',
#   'FSHR WALNUT HALVES \xa0 10 OZ',
#   'FSHR CHOPPED WALNUTS\xa0 10 OZ',
#   'BST CH GR A LARGE EGG 1 DZ',
#   'PF BUTTERMILK HGL 64 OZ',
#   'GOT Markdown - Cold Deli',
#   'BST CH RSN WLNT OATS 8 CT',
#   'FLEIS MOVE OVER BTR SPREAD 10.05 OZ',
#   'PRAIRIE FARMS BUTTER QTR 16 OZ'],
#  ['MORT IODIZED SALT 26 OZ',
#   'PURE LEAF UNSWEET BLACK BREWED TEA 64 OZ',
#   'SWT N LOW COOKING & BAKING 8 OZ',
#   'PURE LEAF UNSWEET BLACK BREWED TEA 64 OZ'],
#  ['KR SHRD MOZZARELLA 24 OZ',
#   'BE ITAL ROLL FZ 1LB',
#   'GG MSHRM PIECES STEMS 4 OZ'],
#  ['FLOWER BEDDING 4 CELL EA',
#   'FLOWER BEDDING 4 CELL EA',
#   'FLOWER BEDDING 4 CELL EA',
#   'FLOWER BEDDING 4 CELL EA'],
#  ['V CAMP PORK N BEANS 15 OZ',
#   'V CAMP PORK N BEANS 15 OZ',
#   'PEPPER GREEN EA',
#   'GROUND BEEF LB',
#   'CHI CHI SALSA MILD 16 OZ',
#   'V CAMP PORK N BEANS 15 OZ',
#   'V CAMP PORK N BEANS 15 OZ'],
#  ['PIL GRANDS BISCUITS HOMESTYLE BTTRMK 16.',
#   'PRAIRIE FARMS CHOCOLATE MILK 16 OZ',
#   'COKE 1.25 LTR',
#   'PIL GRANDS BISCUITS HOMESTYLE BTTRMK 16.',
#   'CNTRY BOB MARINADE BBQ GRILL 18 OZ',
#   'POTATO IDAHO MINUTE BAKER EA',
#   'AM CH MILK 2% GALN 128 OZ',
#   'POTATO IDAHO MINUTE BAKER EA',
#   'POTATO IDAHO MINUTE BAKER EA',
#   'CUCUMBER EA',
#   'DOLE GREENER SELECT 11 OZ',
#   'KR VIRGINIA HAM EACH',
#   'HAM SALAD EACH',
#   'KF PLLD PORK W/BBQSC 16 OZ'],
#  ['PEPSI .5 LTR 6 PK',
#   'PEPSI .5 LTR 6 PK',
#   'PEPSI .5 LTR 6 PK',
#   'JUMBO CINNAMON EACH',
#   'L D CHOC CK Z 12 OZ',
#   'PEPSI .5 LTR 6 PK'],
#  ['ARGENTINE RAW 16 20 2 LB.',
#   'ARGENTINE RAW 16 20 2 LB.',
#   'ARGENTINE RAW 16 20 2 LB.',
#   'YOU ARE MY SUNSHINE BQT BQT',
#   'BST CH CUT GREEN BEANS 14.5 OZ',
#   'BST CH CUT GREEN BEANS 14.5 OZ',
#   'BST CH CUT GREEN BEANS 14.5 OZ'],
#  ['TONY CH MORE SPICE CREOLE SSNG 7 OZ',
#   'MC CRSE GRND PEPR 1.5 OZ',
#   'HAPPY EGG FREE RANGE 12 CT',
#   'BST CH GR A LARGE EGG 1 DZ',
#   'BUNNY HONEY WHEAT 20 OZ',
#   'BUNNY HONEY WHEAT 20 OZ',
#   'JD SAGE ROLL SAUSAGE 1L',
#   'CPN: $1 OFF (2) Pillsbury Participating  Item',
#   'PIL DELUXE CHOC CHIP CKY 16 OZ',
#   'PIL COOKIE DOUGH REESES PIECES 16 OZ',
#   'LOF PREM BRN SGR HAM 16 OZ',
#   'PLANET OAT UNSWT XTRA CREAMY 52 OZ',
#   'PRAIRIE FARM WHOLE MILK 128 OZ',
#   'KEB TOWNHOUSE ORIG 13.8 OZ',
#   'KEB TOWNHOUSE ORIG 13.8 OZ'],
#  ['HEART SHAPED CAKE EACH',
#   'PEPSI WILD CHERRY 16.9 OZ 6 PK',
#   'MOUNTAIN DEW .5L 6 PK',
#   'PEPSI .5 LTR 6 PK',
#   'MOUNTAIN DEW CODE RED 16.9 OZ 6 PK'],
#  ['S FLF STF WTRMLN PEG 2.1 OZ',
#   'S DOTS LEMONADE TBX 6.5 OZ',
#   'DR PEPPER 20 OZ'],
#  ['PIL FRSTNG CREAM CHEESE 16 OZ',
#   'COCA COLA SODA ZERO SUGAR 6 PK 101.4 OZ',
#   'COCA COLA SODA ZERO SUGAR 6 PK 101.4 OZ',
#   'PIL FRSTNG CREAM CHEESE 16 OZ',
#   'ORV RED CLSC BTR 3 CT',
#   'LAYS CLASSIC 8 OZ',
#   'MTLF MSHD POTATO EACH',
#   'COCA COLA SODA ZERO SUGAR 6 PK 101.4 OZ',
#   'DH MIX SIG SPICE CAKE 15.25 OZ',
#   'NSTL BABY RUTH FUNSZ LDB 10.2 OZ',
#   'NESTLE DRUMSTICK VARIETY 8 CT 36.8 OZ',
#   'KR PHIL CREAM CHEESE ORIG 8 OZ'],
#  ['VEL JALAPENO SINGLES 12 OZ',
#   'ONIONS SWEET LB',
#   'BC HOT DOG BUNS 8 CT 11 OZ',
#   'BC HOT DOG BUNS 8 CT 11 OZ',
#   'BUNNY 4 PLAIN HAMBURGER 12 PK 12 PK',
#   'AS HONEY GRAHAM 14.4 OZ',
#   'HRSH MILK CHOC XL BAR 4.4 OZ',
#   'AS MARSHMALLOWS 16 OZ',
#   'FRESH GROUND CHUCK 80/20 LB'],
#  ['KR NAT SLC SHRP CHDR 8 OZ',
#   'JNSNVL  ORIG BRATS 16 OZ',
#   'JNSNVL  ORIG BRATS 16 OZ',
#   'COKE ZERO 20 OZ',
#   'FP GROUND CHUCK LEAN LB',
#   'FP GROUND CHUCK LEAN LB',
#   'BUNNY 4 PLAIN HAMBURGER 12 PK 12 PK',
#   'UTZ HONEY BAR BQ CHIP 7.75 OZ',
#   'UTZ SOUR CREAM & ONION RILE CHIP 7.75 OZ',
#   'HOT DOG BUNS 8 PK'],
#  ['STRAWBERRIES   1 LB',
#   'CONCORD STRWBRY GLZ/PCH 16 OZ',
#   'KY LEG APPLWOD SMK SLCED BACON 1 LB',
#   'MARZ CHOC FRUIT DIP 13.5 OZ',
#   'PMC COMPLETE PANCAKE MIX 32 OZ',
#   'REDI WIP REAL CREAM TOP 6.5 OZ',
#   'KR PHIL CREAM CHSE BAR 8 OZ',
#   'MB ORIGINAL SYRUP 24 OZ',
#   'BST CH PIE SHELL 2PK 10 OZ',
#   'KL B BACON 16 OZ',
#   'KY LEG APPLWOD SMK SLCED BACON 1 LB',
#   'LEND CINN RAISIN SWIRL BAGELS 17.1 OZ',
#   'STRAWBERRIES   1 LB',
#   'STRAWBERRIES   1 LB'],
#  ['KNGFRD BRIQUETS ORIGINAL 8 LB',
#   'SELECT NY STRIP STEAKS LB',
#   'PREMIUM RESERVE RIBEYE STEAK LB',
#   'ASPARAGUS BNCH EA',
#   'PICK 5 BNLS COUNTRY RIBS LB',
#   'SM APWD BCN PK LN FL 27.2 OZ',
#   'CHOICE ANGUS BNLS SIRLOIN LB'],
#  ['TOMBSTONE 5 CHEESE 19.3 OZ',
#   'SF 7 TRAY CF TNDR LB',
#   '  BUTTERFLY  PORK CHOPS LB',
#   '  BUTTERFLY  PORK CHOPS LB',
#   'TB DIABLO SAUCE 7.5 OZ',
#   'BANANA LB',
#   'BST CH GR A MED EGGS 1 DZ',
#   'TOMBSTONE 5 CHEESE 19.3 OZ',
#   'TOMBSTONE 5 CHEESE 19.3 OZ',
#   'TOMBSTONE 5 CHEESE 19.3 OZ'],
#  ['NUTTY BUDDY CREM PIES 6 CT 16.91 OZ',
#   'ECK SMKD LINK SAUSAGE 14 OZ',
#   'ECK CHEDDAR SMK LINKS 14 OZ',
#   'BAR S BUNLENGTH  FRANKS 12 OZ.',
#   'OATMEAL CREME PIES 36 OZ',
#   'LD MUFFINS CHOCOLATE CHIP 5 CT 12.67 OZ',
#   'BAR S BUNLENGTH  FRANKS 12 OZ.',
#   'SELECT ANGUS NY STRIP EA',
#   'SELECT ANGUS NY STRIP EA',
#   'SELECT ANGUS NY STRIP EA',
#   'DOLE GREENER SELECT 11 OZ',
#   'GOT Markdown - Wic Produce',
#   'POTATO RUSSET 5 LB',
#   'A1 SAUCE ORIGINAL 10 OZ',
#   'HVR DRESSING SQZ ORIG 20 OZ',
#   'MC GRILL MATE BRAZIL STEAKHOUSE 2.12 OZ',
#   'Dt 7up 12pk 12oz  Can  Cs 12 PK',
#   'DIET BIG  RED 12 PK',
#   'ICEE BLUE RASPBERRY 6 OZ',
#   'LD BIG PACKS FROSTED DONUTS 16.91 OZ'],
#  ['ECKRICH CHEESE FRANKS 12 OZ',
#   'ECKRICH CHEESE FRANKS 12 OZ',
#   'AS CUT GREEN BEANS 14.5 OZ',
#   'SWTRTS MINI CHEWY 12 OZ',
#   'AS CUT GREEN BEANS 14.5 OZ',
#   'STANDARD SIDE LB',
#   'MISC HOT CHICKEN EACH'],
#  ['KR SHRD 2% MEX 4 CHS 7 OZ', 'LINDSAY OLIVE RIPE SLICED 2.25 OZ'],
#  ['KR SHRD MILD CHEDDAR 8 OZ',
#   'PRAIRIE FARMS ORANGE JUICE 128 OZ',
#   'BUDDIG HONEY HAM 2.0 OZ',
#   'BUDDIG HONEY HAM 2.0 OZ',
#   'FP GROUND CHUCK LEAN LB',
#   'BUDDIG HONEY HAM 2.0 OZ',
#   'BUDDIG SLICED HAM 2.0 OZ',
#   'ECKRICH CHEESE FRANKS 12 OZ',
#   'ECKRICH CHEESE FRANKS 12 OZ',
#   'ECK ORIG FRANKS 12 OZ',
#   'ECK ORIG FRANKS 12 OZ',
#   'BUDDIG SLICED HAM 2.0 OZ',
#   'BUDDIG SLICED HAM 2.0 OZ',
#   'BUDDIG HONEY HAM 2.0 OZ',
#   'KR SHRD MOZZARELLA 8 OZ',
#   'KR SHRD MOZZARELLA 8 OZ',
#   'KR SHRD MILD CHEDDAR 8 OZ'],
#  ['LOLLIPOP DSP REFIL 1.1OZ 1.1 OZ',
#   'JAMESTOWN BRND SLCD BCN 1 LB',
#   'KY LEG APPLWOD SMK SLCED BACON 1 LB',
#   'HOST MINI DONUT DBL CHOC 11.25 OZ',
#   'KY LEG APPLWOD SMK SLCED BACON 1 LB',
#   'ROSE CAKE 8 IN',
#   'HOST DONETTES OLD FASH 10.5 OZ',
#   'HEART SHAPED CAKE EACH',
#   'CHERRY STRUDEL BITES EACH',
#   'CREAM CHEESE CINN ROLL 4CT',
#   '8 CT ICED SUGAR COOKIES 8 CT',
#   '8 CT ICED SUGAR COOKIES 8 CT',
#   'KY LEG APPLWOD SMK SLCED BACON 1 LB',
#   'JAMESTOWN BRND SLCD BCN 1 LB',
#   'GRIPPOS SWEET MAUI ONION 8 OZ',
#   'GRIPPOS SWEET MAUI ONION 2.75 OZ'],
#  ['GARLIC LB',
#   'BST CH MOZZARELLA CHEESE STICKS 8 OZ',
#   'PETE GERRY PAST RAISED LG EGGS 1 DZ',
#   'ITALIAN CHS SUB ROLL 4 CT',
#   'CORN BI COLOR 4 PK',
#   'BEANS GREEN LB'],
#  ['M&M TWIX CARAMEL KING 3.02 OZ',
#   'COKE CLASSIC 20 OZ',
#   'DIET PEPSI 20 OZ',
#   'MILO UNSWEET TEA GAL',
#   'MILO SWEET TEA GAL',
#   'STRAWBERRIES   1 LB',
#   'CUPCAKE W PICK 6 CT',
#   'HEART SHAPED CAKE EACH'],
#  ['BAR/S MEAT FRANKS 12 OZ',
#   'HRSH COOKIE&CRM BAR 1.55 OZ',
#   'OEP ORIGINAL TACO SSNG MIX 6.25 OZ',
#   'FRESH GROUND CHUCK 80/20 LB',
#   'BST CHCE ROUND TOP 20 OZ',
#   'TOSTITOS SCOOPS 10 OZ'],
#  ['99% LN GR TKYBRST 1LB',
#   'THIN CUT PORK STEAK LB',
#   'ASPARAGUS BNCH EA',
#   '99% LN GR TKYBRST 1LB',
#   '99% LN GR TKYBRST 1LB',
#   '99% LN GR TKYBRST 1LB',
#   '99% LN GR TKYBRST 1LB'],
#  ['MG POTTING MIX SOIL 2 CF EA',
#   'MG POTTING MIX S',
#   'MG POTTING MIX SOIL 2 CF EA',
#   'MG POTTING MIX S'],
#  ['GOT Markdown - Cold Deli',
#   'OTB CHUNKY MILD 16 OZ',
#   'OTB CHUNKY MILD 16 OZ',
#   'ROTIS CHICKEN SALAD EACH',
#   'GOT Markdown - Cold Deli'],
#  ['BUBLY BLACKBERRY 12 OZ 8 PK 96 OZ',
#   'DIG STUFFED PEPPERONI 22.2 OZ',
#   'KEL HONEY SMACKS 15.3 OZ',
#   'AM CH MILK 2% HGAL 64 OZ'],
#  ['ONIONS SWEET LB',
#   'BDN CHNK COJACK 8 OZ',
#   'VEL SHREDS MEXICAN 8 OZ',
#   'LETTUCE  EA',
#   'LA PREF FAJITA SEAS 1.25 OZ',
#   'LA PREF FAJITA SEAS 1.25 OZ',
#   'TOMATOES NATURE  SWEET CHERUB 10 OZ',
#   'LA PREF FAJITA SEAS 1.25 OZ',
#   'LAWRY MARINADE MESQUITE 12 OZ',
#   'OPEN PIT BBQ SC HICKORY 18 OZ',
#   'TOMATOES NATURE  SWEET CHERUB 10 OZ',
#   'OPEN PIT BBQ SC HICKORY 18 OZ',
#   'OPEN PIT BBQ SC HICKORY 18 OZ',
#   'WISHBONE DRSNG RUSSIAN 15 OZ',
#   'BACKYARD ORIG SEASON 7 OZ',
#   'LAWRY MARINADE MESQUITE 12 OZ',
#   'VEL SHRP CHDR SNGLS 12 OZ',
#   'BDN CHNK XSHP CHDR 8 OZ',
#   'HVR DRESSING ORIG RANCH 36 OZ',
#   'PRAIRIE FARM COTTAGE CH 24 OZ',
#   'DEAN FRNCH ONION DIP',
#   'LOL BUTTER HALF STICKS 16 OZ',
#   'KR ROTISS CHKN BRST EACH',
#   'KRETSCHMAR SUN DRIED TOM TKY EACH',
#   'BST CH TORTILLA BURRITO 8 CT',
#   'PIL CRSNT SWT HAWAII 8 OZ',
#   'PIL CINNAMON ROLLS ORIGINAL 12.4 OZ',
#   'PIL CINNAMON ROLLS ORIGINAL 12.4 OZ',
#   'PIL CRSNT SWT HAWAII 8 OZ',
#   'BUNNY HONEY WHEAT 20 OZ',
#   'BUNNY SOFT TWIST 16 OZ',
#   'LAYS CLASSIC PRTY SZ 13 OZ',
#   'BST CH FRUIT COCKTAIL 15.25 OZ',
#   'BST CH FRUIT COCKTAIL 15.25 OZ',
#   'JARRITOS BTL MANDARIN 1.5 LTR',
#   'JARRITO LIME SODA 1.5 LT',
#   'AM CH MILK WHOLE GAL 128 OZ',
#   'BST CH CANOLA OIL 48 OZ',
#   'BST CH CANOLA OIL 48 OZ',
#   'POTATO RUSSET 5 LB',
#   'POTATO RUSSET 5 LB',
#   'POTATO BST CH GOLD 5 LB',
#   'CPN: $1 OFF (2) Pillsbury Participating  Item',
#   'PEPPER YELLOW EA',
#   'PEPPER  RED EA',
#   'PEPPER ORANGE EA',
#   'PEPPER GREEN EA'],
#  ['TOTINO HAMBURGER PIZZA 10.9 OZ',
#   'TOTINO PEPPERONI PIZZA 10.2 OZ',
#   'TOTINO COMBINATION PIZZA 10.7 OZ',
#   'TOTINO COMBINATION PIZZA 10.7 OZ',
#   'TOTINO SUPREME PIZZA 10.9 OZ',
#   'TOTINO PEPPERONI PIZZA 10.2 OZ',
#   'TOTINO 3 CHEESE PIZZA 9.8 OZ',
#   'TOTINO SUPREME PIZZA 10.9 OZ',
#   'TOTINO SUPREME PIZZA 10.9 OZ',
#   'SF 7 TRAY CF DRUMS LB',
#   'SF 7 TRAY CF DRUMS LB',
#   'SF 7 TRAY CF DRUMS LB',
#   'SF 7 TRAY CF THIGH LB',
#   'SF 7 TRAY CF THIGH LB',
#   'SF 7 TRAY CF THIGH LB',
#   'ECK ORIG FRANKS 12 OZ',
#   'ECK ORIG FRANKS 12 OZ',
#   'TOTINO 3 CHEESE PIZZA 9.8 OZ',
#   'TOTINO 3 CHEESE PIZZA 9.8 OZ',
#   'TOTINO COMBINATION PIZZA 10.7 OZ',
#   'ECK ORIG FRANKS 12 OZ',
#   'ECK ORIG FRANKS 12 OZ',
#   'ECKRICH BOLOGNA 12 OZ',
#   'ECKRICH BOLOGNA 12 OZ',
#   'ECKRICH BOLOGNA 12 OZ',
#   'ECKRICH BOLOGNA 12 OZ',
#   'IMPERIAL SPREAD 45 OZ',
#   'BC SANDWICH 20 OZ',
#   'BC SANDWICH 20 OZ',
#   'CPN: $1 off (3) Totinos Pizzas or Rolls 5/7-5',
#   'TOTINO HAMBURGER PIZZA 10.9 OZ',
#   'TOTINO HAMBURGER PIZZA 10.9 OZ',
#   'TOTINO PEPPERONI PIZZA 10.2 OZ'],
#  ['TENDERS 1 LB', 'KH DELI ROLLS 4 OZ'],
#  ['TENDERS 1 LB', 'STANDARD SIDE LB', 'COKE  CLASSIC  .5LT 6 PK'],
#  ['LD NUTTY BAR 12 OZ', 'AIR PURIFIER AIR POLICE'],
#  ['BST CH CHUNK MED CHEDDAR 8 OZ',
#   'BORDEN HEAVY WHIPNG CREAM 16 OZ',
#   'BUNNY HOT DOG BUNS 12 OZ 8 CT',
#   'KR SLICED AMER DELI CHSE 12 OZ',
#   'BST CH STEAM SWT W CRN 12 OZ',
#   'CRMT SM ELBOW MAC 16 OZ',
#   'CRMT MEDIUM SHELLS 16 OZ',
#   'BUNNY HAMBURGER BUNS 8 CT',
#   'BDN CHNK GOUDA 8 OZ',
#   'HZ KETCHUP SQUEEZE 38 OZ',
#   'GHOST LTO BLACK CHERRY WARHEADS 16OZ SIN'],
#  ['TYSN BNLS TENDERLOIN 2.5 LB',
#   'DIET PEPSI 20 OZ',
#   'OM SHAVED SMO  TURKEY 9 OZ',
#   'KC MSTRPC MARINADE CRBN JERK 16 OZ',
#   'KR CO/JACK BIG SLICE 8 OZ'],
#  ['NAB OREO PARTY SZ 24.16 OZ',
#   'AL SAVE POWDER SUGAR 2 LB',
#   'JELLO PUDDING PIE FILLING VANILLA 3.4 OZ',
#   'JELLO PUDDING PIE FILLING VANILLA 3.4 OZ',
#   'JF 13X9 CAKE WITH BLUE LID EACH',
#   'AM CH MILK 2% HGAL 64 OZ',
#   'COOL WHIP ORIGINAL TOPPING 8 OZ',
#   'BST CH CREAM CHEESE 2PK 16 OZ',
#   'PRAIRIE FARMS BUTTER QTR 16 OZ'],
#  ['TOMATOES NATURE  SWEET CHERUB 10 OZ',
#   'BC DECO ICING YELLOW 4.25 OZ',
#   'BC HAPPY BDAY CANDLE 13 CT',
#   'PEPPER  RED EA',
#   'BC CANDLE #6 1 CT',
#   'HRSH ZERO BAR 1.85 OZ',
#   'PEPPER YELLOW EA',
#   'HRSH ZERO BAR 1.85 OZ',
#   'CARD BRTHDAY HALLMARK',
#   'ASSORTED TWIRLS',
#   'JF COOKIE SHEETS 2 CT',
#   'PEPPER ORANGE EA',
#   'DIET MOUNTAIN DEW 20 OZ',
#   'CUCUMBER EA',
#   'BC DECO ICING BLUE 4.25 OZ',
#   'DORITOS COOL RANCH PRTY SZ 15 OZ',
#   'LAYS BBQ PRTY SZ 12.5 OZ',
#   'LETTUCE  EA',
#   'LETTUCE  EA'],
#  ['TENN PRIDE MILD SAUSAGE 1 LB',
#   'AM CH MILK 2% GALN 128 OZ',
#   'LH OATMEAL RSN CKIE 15 OZ',
#   '7UP  CAKE 26 OZ'],
#  ['KLG GRIPZ VRTY PCK 12CT 11 OZ',
#   'KLG GRIPZ VRTY PCK 12CT 11 OZ',
#   'IDAHO HAND CUT FRIES 16.1 OZ'],
#  ['SMK PORK CHOP CLD LB', 'MISC HOT CHICKEN EACH', 'CHERRY  RC COLA 12 PK'],
#  ['KR DRSNG CLASSIC RANCH 16 OZ',
#   'AL SAVE FLOUR ALL PURPOSE 5 LB',
#   'BDN SLC NAT CO/JACK 6 OZ',
#   'STRAWBERRIES   1 LB',
#   'JELLO STRAWBERRY GELATIN 6 OZ',
#   'BST CH PIE SHELL 2PK 10 OZ'],
#  ['PF VANILLA HOMEMADE 48 OZ',
#   'AM CH MILK WHOLE GAL 128 OZ',
#   'NSTL TOLLHOUSE CHOC CHIP LOVERS 16 OZ'],
#  ['ENTENMANNS BAG PWD DNT 12 CT',
#   'TABASCO SAUCE SRIRACHA 20 OZ',
#   'OL FOLKS ITALIAN SGE 1 LB',
#   'VLVTA SHELLS N CHEESE LIGHT 12 OZ',
#   'KR MAC N CHEESE SPIRALS 5.5 OZ',
#   'KR MAC N CHEESE THINK N CREAMY 7.25 OZ',
#   'MILO SWEET TEA GAL',
#   'MILO SWEET TEA GAL',
#   'BST CHCE ROUND TOP 20 OZ',
#   'FLAG BLOW POPS 9.1  OZ'],
#  ['ANGUS BEEF STEW MEAT',
#   'MISC BALLOON ORDER',
#   'YOU ARE MY SUNSHINE BQT BQT',
#   'BUNNY HAMBURGER BUNS 8 CT',
#   'CPN: $1 OFF (2) Pillsbury Participating  Item',
#   'SWEET SUE BROTH BEEF 14.5 OZ',
#   'POTATO IDAHO LOOSE BAKER LB',
#   'CELERY EA',
#   'CARROTS BABY PEEL 1 LB',
#   'PIL CRSNT SWT HAWAII 8 OZ',
#   'PIL CRSNT SWT HAWAII 8 OZ',
#   'ANGUS BEEF STEW MEAT',
#   'MC BEEF STEW SEASONING 1.5 OZ'],
#  ['DARK CHOC TRUFFLE EACH',
#   'IDAHO CRISPY POTATO PUFFS 13.8 OZ',
#   'IDAHO CRISPY POTATO PUFFS 13.8 OZ',
#   'BST CH LARGE GRADE EGGS 2.5 DZ'],
#  ['LUMP CHARCL SPRPRM 17.6#',
#   'ASPARAGUS BNCH EA',
#   'ASPARAGUS BNCH EA',
#   'BBQ SAUCE SW HNY 20.25OZ',
#   'EVERFRESH APPLE JCE FUJI 12 OZ'],
#  ['APPLE WA HONEYCRISP LB',
#   'BANANA LB',
#   'HC CHICKEN PESTO 9.9 OZ',
#   'BST CH SUNFLOWER KERNEL 5.85 OZ',
#   'HC STMR SPAG MEATBALL 9.5 OZ',
#   'DAISY 2% COTTAGE CHS 24 OZ'],
#  ['SKYR STRAWBERRIES CREAM EXTRA CRMY 4.4 O',
#   'SO REC SLT PPR RINDS 4 OZ',
#   'AM CH MILK WHOLE GAL 128 OZ',
#   'SKYR VANILLA EXTRA CREAMY 4.4 OZ',
#   'SKYR STRAWBERRIES CREAM EXTRA CRMY 4.4 O',
#   'SKYR STRAWBERRIES CREAM EXTRA CRMY 4.4 O'],
#  ['SINGLE ROSE EA', 'ROSE MIX BQT'],
#  ['CF A/N GROUND CHICKEN 16 OZ',
#   'LORETTA STEAK SEASONING 1.4 OZ',
#   'LOR CHKN SP GRINDER 1.5 OZ',
#   'BOB EVANS MASHED POT 24 OZ.'],
#  ['FLORAL HANGING BASKET', 'FLORAL HANGING BASKET'],
#  ['KID CUISINE POPCORN CHKN 7 OZ',
#   'BST CH SOUP CREAM CHICKEN 26 OZ',
#   'NAB RITZ CRACKERS 13.7 OZ',
#   'BANQ CHKN FRIED CHICKEN MEAL 10.1 OZ',
#   'GM CINN TOAST CRUNCH 2 OZ',
#   'PINEAPPLE CHUNKS LB',
#   'CAP N CRUNCH BERRIES    SNGL SRV 1.3 OZ',
#   'KR CLBY M/JACK CUBES 6.4 OZ',
#   'KR PHIL CREAM CHSE BAR 8 OZ',
#   'KR PHIL CREAM CHSE BAR 8 OZ',
#   'WATERMELON CHUNKS LB',
#   'FP WHOLE PNLS PORK LOIN LB',
#   'FP WHOLE PNLS PORK LOIN LB',
#   'AM CH MILK 2% GALN 128 OZ',
#   'BST CH SOUP CREAM CHICKEN 26 OZ',
#   'BANQ CHKN FRIED CHICKEN MEAL 10.1 OZ',
#   'BANQ CHKN FRIED CHICKEN MEAL 10.1 OZ',
#   'OM FP PIZZA TREATZA 10.5',
#   'OM UPLOADED DEEPDISH PEP PIZZ 14.7'],
#  ['BC ANGEL FOOD CAKE 16 OZ',
#   'REDI WIP REAL CREAM TOP 6.5 OZ',
#   'BBQ GINGHAM SMALL PLATE EACH',
#   'STRAWBERRIES   1 LB'],
#  ['B BUNNY SOFT CHOCOLATE 46 OZ',
#   'ACE RSTP SPRY GL BLK 15OZ',
#   '8 PC COLD CHICKEN 8 PC',
#   'RUP EXT CNTRL RFLL',
#   'ACE RSTP SPRY SATBLK15OZ',
#   'ACE RSTP SPRY GL',
#   'ACE RSTP SPRY SA',
#   'BST CH ROUND TOOTHPICK 250 CT',
#   'PEPSI ZERO SUGAR 12 PK',
#   'NAB OREO CHOC FAM SZ 18.71 OZ',
#   'NAB OREO MEGA STUFF FS 17.6 OZ',
#   'BB CHERRIFIC CHEESECAKE 46 OZ'],
#  ['KY LEGEND PILLOW PACK BLACK FOREST SLICE',
#   'KY LEGEND PILLOW PACK SMOKED SLICED TURK',
#   'OIKOS TRIPLE ZERO PEACH 5.3 OZ',
#   'DAN OIKOS ZERO BRY 5.3 OZ',
#   'OIKOS TRIPLE ZERO PEACH 5.3 OZ',
#   'OIKOS TRIPLE ZERO PEACH 5.3 OZ',
#   'KY LEGEND PILLOW PACK SMOKED SLICED TURK',
#   'DAN OIKOS ZERO BRY 5.3 OZ',
#   'DAN OIKOS ZERO BRY 5.3 OZ',
#   'DAN OIKOS ZERO BRY 5.3 OZ',
#   'DAN OIKOS ZERO BRY 5.3 OZ',
#   'DAN OIKOS ZERO BRY 5.3 OZ',
#   'DAN OIKOS ZERO BRY 5.3 OZ',
#   'OIKOS TRIPLE ZERO PEACH 5.3 OZ',
#   'DAN OIKOS ZERO BRY 5.3 OZ',
#   'DAN OIKOS ZERO STRAW 5.3 OZ',
#   'OIKOS TRIPLE ZERO PEACH 5.3 OZ',
#   'DAN OIKOS ZERO BRY 5.3 OZ',
#   'DAN OIKOS ZERO STRAW 5.3 OZ',
#   'DAN OIKOS ZERO BRY 5.3 OZ',
#   'DAN OIKOS ZERO BRY 5.3 OZ',
#   'DAN OIKOS ZERO BRY 5.3 OZ',
#   'DAN OIKOS ZERO STRAW 5.3 OZ',
#   'VLASIC SWT MIDGET PICKLE 16 OZ',
#   'CPN: Save $1.50 on  1 Kentucky Legend Lunchme',
#   'AS ICE CREAM NEAPOLITAN 128 OZ',
#   'BST CH GR A LARGE EGG 1 DZ',
#   'BST CH GR A LARGE EGG 1 DZ',
#   'BST CH GR A LARGE EGG 1 DZ'],
#  ['WHINK COFFEEMAK 10 OZ',
#   'RD FLYING INSECT 20% MORE 18 OZ',
#   'ZIPL SNDWCH BAG 50 CT',
#   'FEBREZE AIR HAWAIIAN ALOHA 8.8 OZ',
#   'SMK PORK CHOP CLD LB',
#   'POMP OLIVE OIL XV SMOOTH 16 OZ',
#   'BE BROCCOLI & CHSE 20 OZ',
#   'BUNNY 100% WHEAT 16 OZ'],
#  ['PF ENG TOFFEE 16.5 OZ',
#   'JL COCO MERINGUE PIE 27 OZ',
#   'MARIE C COCONUT CREAM PIE 30.3 OZ'],
#  ['SINGLE ROSE EA', 'SINGLE ROSE EA'],
#  ['ECK MAPLE LINK 8.30OZ',
#   'ECKRICH CHEESE FRANKS 12 OZ',
#   'BUNNY HOT DOG BUNS 12 OZ 8 CT',
#   'CHEETOS PUFFS JUMBO 8 OZ',
#   'PURNELLS OLD FOLK GRAVY BG 8 OZ',
#   'PURNELLS OLD FOLK GRAVY BG 8 OZ',
#   'PIL GRANDS BISCUITS STHRN STYLE 16.3 OZ',
#   'NAB CHIPS AHOY W REESES 9.5 OZ',
#   'OM READY/TO/SRV BACN 2.52 OZ'],
#  ['FRSK CHKN/GRAVY 5.5 OZ',
#   'FRSK SHRDDED SALMON 5.5 OZ',
#   'FRSK CHKN/GRAVY 5.5 OZ',
#   'FRSK PRM FILET TRKY 5.5 OZ',
#   'FRSK PRM FILET TRKY 5.5 OZ',
#   'FRSK TSTY CHKN CHS 5.5 OZ',
#   'FRSK TSTY CHKN CHS 5.5 OZ',
#   'FRSK PRM FILET TRKY 5.5 OZ',
#   'FRSK SHRDDED SALMON 5.5 OZ',
#   'BST CH HEAVY DUTY FORKS 48 CT',
#   'FRSK PRM FILET TRKY 5.5 OZ'],
#  ['KY LEG HICKRY SMK SLICED BACON 1 LB',
#   'MUCH LOVE MOM MIXED BOUQUET BQT',
#   'PIL GR BTR TST BISC 10.2 OZ',
#   'OL FOLKS SAUS.MILD 1/LB',
#   'AM CH MILK 2% HGAL 64 OZ'],
#  ['MUCH LOVE MOM MIXED BOUQUET BQT',
#   'MUCH LOVE MOM MIXED BOUQUET BQT',
#   'CARD MDAY ANYONE'],
#  ['KR MIRACLE WHIP 30 OZ', 'CARD MDAY MOTHER', 'COUNTRY BOB SEA SALT 8 OZ'],
#  ['RATIO YOG STRAWBERRY 5.3 OZ',
#   'RATIO YOG VANILLA 5.3 OZ',
#   'RATIO YOG STRAWBERRY 5.3 OZ',
#   'RATIO YOG VANILLA 5.3 OZ',
#   'RATIO YOG VANILLA 5.3 OZ',
#   'FAIRLIFE 2% CHOC MILK 52 OZ',
#   'BST CH GR A LARGE EGG 1 DZ',
#   'BONELESS PORK CHOPS LB',
#   'FRESH GROUND CHUCK 80/20 LB',
#   'SF BACON 12 OZ',
#   'SF BACON 12 OZ',
#   'DOZEN ROSE BOUQUET BQT',
#   'RATIO YOG BLUEBERRY 5.3 OZ',
#   'RATIO YOG BLUEBERRY 5.3 OZ'],
#  ['SHREDDED PULLED PORK LB',
#   'SWT RAY BBQ ORIG 28 OZ',
#   'TROP STRWBRY LMADE 46 OZ',
#   'SWT RAY BBQ VIDALIA 18 OZ',
#   'SIMPLY ORNGE LOW ACD 52 OZ',
#   'OS WILD BLUEBERRY MUFFIN 3 PK',
#   'SINGLE DONUT'],
#  ['ENTENMANNS BAGED CINN DONUTS 12 PK 12 PK',
#   'PIONEER GRAVY PEPPER 2.75 OZ',
#   'SINGLE DONUT',
#   'PIONEER GRAVY COUNTRY 2.75 OZ',
#   'MAR RAMEN NDL SOY SCE 3 OZ',
#   'MAR RAMEN NDL SOY SCE 3 OZ',
#   'AM CH MILK WHOLE GAL 128 OZ',
#   'KR SHRD SHARP CHDR 8 OZ',
#   'PIL GRANDS BISCUITS BTR 32.6 OZ',
#   'OL FOLKS SMKD SAUSAG 1 LB',
#   'BST CH GRD A LRG 18P EGG 1.5 DZ'],
#  ['CARD MDAY ANYONE',
#   'YOU ARE MY SUNSHINE BQT BQT',
#   'DOZEN ROSE BOUQUET BQT',
#   'CARD MDAY MOTHER',
#   '9 STEM BOUQUET BQT',
#   'RED BULL RED EDITION WATERMELON 12 OZ'],
#  ['STAND ANNUAL PLANTS 4 IN', 'FLOWER BEDDING 4 CELL EA'],
#  ['PEPPER  RED EA', 'FLORAL HANGING BASKET', 'PEPPER GREEN EA'],
#  ['UTZ KET CLASSIC RUSSET CHIPS 7.5 OZ',
#   'GRIPPOS BBQ CHIPS 24 OZ',
#   'FROZEN CAKE EA'],
#  ['DIET MOUNTAIN DEW 2 LTR',
#   'MUG ROOT BEER 2 LTR',
#   'COKE CLASSIC 24 PK 12 OZ 288 OZ'],
#  ['ALCON EYE DROPS 0.5 OZ', 'PEPTO BSML KIDS CHEWABLE BUBBLE GUM 24 C'],
#  ['BUNNY 4 PLAIN HAMBURGER 12 PK 12 PK',
#   'BUNNY 4 PLAIN HAMBURGER 12 PK 12 PK',
#   'BUNNY 4 PLAIN HAMBURGER 12 PK 12 PK'],
#  ['ACE BAG 39GAL 32CT DRAW',
#   'RED BARON FRENCH PEPPERONI 10.8 OZ',
#   'KING HAWAIIAN REG ROLLS 4 OZ',
#   'CHILI ROLL 16 OZ.',
#   'CHILI ROLL 16 OZ.',
#   'JACKS THIN SUPREME 15.8 OZ',
#   'JACKS THIN SAUSAGE N PEPPERONI 16.1 OZ',
#   'JACK`S CANADIAN BACON  PIZZA 15.7 OZ',
#   'RED BARON FRENCH 5 CHEESE N GARLIC 21.1',
#   'AM CH MILK WHOLE GAL 128 OZ',
#   'FLORAL HANGING BASKET'],
#  ['CRANBERRY SALAD EACH',
#   'KR PHIL CREAM CHSE CHIVE N ONION 7.5 OZ',
#   'BST CH SHRED MOZZARLA 8 OZ',
#   'PISTACHIO SALAD EACH'],
#  ['KL DICED HAM 8 OZ',
#   'BST CH GR A LARGE EGG 1 DZ',
#   'KR VELV SPRD SNGL 16 OZ'],
#  ['FRITO LAY CHESTERS CHEES 4.25 OZ',
#   'MOM BAG FROSTED FLAKES 30 OZ',
#   'PEPSI 24 PK',
#   'PF DUTCH CHOCOLATE MILK 32 OZ'],
#  ['MG POTTING MIX S',
#   'MG POTTING MIX SOIL 2 CF EA',
#   'MG POTTING MIX S',
#   'MG POTTING MIX S',
#   'MG POTTING MIX S',
#   'MG POTTING MIX S'],
#  ['POTATO IDAHO LOOSE BAKER LB',
#   'SELECT ANGUS NY STRIP EA',
#   'SF THIN BNLS BRST LB',
#   'DORITOS NACHO CHEESE 9.25 OZ',
#   'BUNNY SOFT TWIST 16 OZ',
#   'DOLE AMERICAN BLEND 12 OZ',
#   'ROXANE SPRING WTR 24 PK',
#   'DORITOS COOL RANCH 9.25 OZ',
#   'DORITOS NACHO CHEESE 9.25 OZ'],
#  ['SUPR SNACK PACK CHOC 6 PK',
#   'MORT IODIZED SALT 26 OZ',
#   'PF COTTAGE CHEESE 24 OZ',
#   'NOR STR LOTTA CREME 35 OZ',
#   'KEB CLUB ORIGINAL 13.7 OZ',
#   'MOTTS APPLESAUCE ORIGINAL 24 OZ',
#   'TOMATOES NATURE  SWEET CHERUB 10 OZ',
#   'MILO TEA SWEET W/SPLENDA GAL',
#   'AM CH MILK 2% GALN 128 OZ',
#   'MISC HOT FOODS EACH',
#   'BUNNY SOFT TWIST 16 OZ',
#   'KR DELI MLD CHD SLIC 8 OZ'],
#  ['MT DEW BAJA BLAST CABO CITRUS',
#   'FANTA ORANGE 20 OZ',
#   'MUNCHIES SW CK JALAPENO CHEDDAR 8PK 11.0',
#   'MONSTER ZERO ULTRA 16 OZ',
#   'SMARTWATER 20 OZ',
#   'CRACKERS GOLDEN TOAST 8PK 11.4 OZ'],
#  ['DH MIX CLASSIC WHITE 15.25 OZ',
#   'BST CH PECAN PIECES 10 OZ',
#   'AS VEGETABLE OIL 48 OZ',
#   'DH MIX DEVILS FOOD 15.25 OZ',
#   'DH MIX CLASSIC WHITE 15.25 OZ',
#   'MISC HOT FOODS EACH',
#   'MISC BAKERY CAKE EACH',
#   'DH MIX DEVILS FOOD 15.25 OZ'],
#  ['DAISY 4% COTTAGE CHEESE 16 OZ',
#   'PEPSI 2 LTR',
#   'SPRITE 2 LTR',
#   'BST CHCE ROUND TOP 20 OZ',
#   'MOUNTAIN DEW 2 LTR',
#   'PEPPER GREEN EA'],
#  ['SMOKED PORK CHOPS LB', 'SMOKED PORK CHOPS LB'],
#  ['ECK BUN SZ FRANKS 12 OZ', 'ECK BUN SZ FRANKS 12 OZ', 'TOMATO  ROMA LB'],
#  ['SELECT ANGUS NY STRIP EA',
#   'TYSON BRISKET PATTIES 1.33 LB',
#   'KR SLICED AMER DELI CHSE 12 OZ',
#   'SELECT ANGUS NY STRIP EA',
#   'BUNNY HAMBURGER BUNS 8 CT'],
#  ['KNORR PS TERIYAKI NOODLES 4.6 OZ',
#   'SB ICED ENERGY BLUEBERRY 12 OZ',
#   'KNORR PS TERIYAKI NOODLES 4.6 OZ'],
#  ['BUNNY SOFT TWIST 16 OZ',
#   'LEWIS 1/2 LOAF HONEY WHEAT 12 OZ',
#   'GB WAFER ROLL STRWBRY 5.68 OZ',
#   'MEAT CHRCH SEASNING',
#   'ECKRICH THICK BOLOGNA 12 OZ',
#   'ECKRICH BOLOGNA 12 OZ',
#   'GENERAL TSO BNLS CHKN LB',
#   'GOLD STRBRY CRM CHS DANIS 14 OZ',
#   'BST CH LARGE GRADE EGGS 2.5 DZ',
#   'SLICED WHLE PORK BUTT LB',
#   '8 PC COLD CHICKEN 8 PC',
#   'FRITO LAY CHESTERS CHEES 4.25 OZ',
#   'AM CH MILK 2% HGAL 64 OZ',
#   'MOUNTAIN DEW .5L 6 PK',
#   'MOUNTAIN DEW .5L 6 PK',
#   'TENDERS 1 LB',
#   'CRACKERS CHEESE PNUT BTR 8PK 11.36 OZ',
#   'DD MOON SLT CARMEL 3\xa0 3 CT'],
#  ['JOHNSONVILLE DOUBLE BEDDAR CHEDDAR BRAT', 'JVILLE SAUS W PEPPERJACK 14 OZ'],
#  ['NIAGARA DRNKG  WTR 24 PK',
#   'CARDINAL HOUSEHOLD TOWEL BIG ROLL 1 RL',
#   'CARDINAL HOUSEHOLD TOWEL BIG ROLL 1 RL',
#   'DORITOS COOL RANCH 9.25 OZ',
#   'NBTR CHKN LIVER FISH CAT 3 LB',
#   'PALM DISH OXY 8.4 OZ',
#   'DORITOS NACHO CHEESE 9.25 OZ',
#   'AS COMPARTMENT PLATES 20 CT',
#   'CARDINAL BATH TISS MEGA RL 4 RL',
#   'BST CH VARIETY POTATO CHIPS 20 CT',
#   'MISC HOT FOODS EACH',
#   'NIAGARA DRNKG  WTR 24 PK'],
#  ['HEINZ SWEET RELISH\xa0SQZ 12.7 OZ', 'COLE SLAW EACH'],
#  ['BANG ENERGY SOUR ROPES 15 OZ',
#   'BANG ENERGY BLUE RAZZ 16 OZ',
#   'BANG ENERGY SOUR ROPES 15 OZ',
#   'TOSTITOS SCOOPS PRTY SZ 17 OZ',
#   'TOSTITOS SCOOPS PRTY SZ 17 OZ'],
#  ['OM D/S MESQ  TKY 8 OZ',
#   'LEWIS 1/2 LOAF 100% WHOLE WHEAT 12 OZ',
#   'MISC CUST SMK COLD LB',
#   'AMERICAN CHEESE EACH',
#   'DORITOS COOL RANCH 9.25 OZ'],
#  ['LETTUCE  EA',
#   'BC HAMBURGER BUNS 8 CT 13 OZ',
#   'AS KETCHUP 38 OZ',
#   'BC HAMBURGER BUNS 8 CT 13 OZ',
#   'FP GROUND CHUCK LEAN LB'],
#  ['BST CH CUT GREEN BEANS 14.5 OZ',
#   'IDHN CHEESY SCALLOPED CASSEROLE 4 OZ',
#   'BST CH CUT GREEN BEANS 14.5 OZ',
#   'IDHN CHEESY SCALLOPED CASSEROLE 4 OZ',
#   'BST CH CUT GREEN BEANS 14.5 OZ',
#   'DIET PEPSI 20 OZ',
#   'FP WHOLE PNLS PORK LOIN LB'],
#  ['GRIPPOS BBQ CHIPS 12 OZ',
#   'ECKRICH OLIVE LOAF 7OZ',
#   'ECKRICH OLD FASHION 7OZ',
#   'EL MONT BF ENCHILADA MXDNR',
#   'LEAN GROUND BEEF LB',
#   'LACHOY CHOW MEIN NOODLES 5 OZ',
#   'LACHOY CHOW MEIN BEEF 42 OZ',
#   'FRENCH BREAD EACH'],
#  ['MOM CINN TSTR FAM SZ 24 OZ', 'AM CH MILK 2% GALN 128 OZ'],
#  ['HINGE PIN 3-1/2SB CD/3', 'BLACK OXIDE DRL BT 7/16', 'HINGE PIN 4SB CD/3'],
#  ['SUKARNE BF RIBEYE STK LB',
#   'SUKARNE BF RIBEYE STK LB',
#   'HL KETO HAMB BUN 7.5 OZ'],
#  ['5 INCH CAKE EACH', 'MISC HOT FOODS EACH'],
#  ['TOMATOES NATURE  SWEET CHERUB 10 OZ',
#   'BST CH PECAN PIECES 6 OZ',
#   'NSTL SEMI SWEET CHOCO MORSEL 12 OZ',
#   'FP GROUND CHUCK LEAN LB',
#   'CARROTS ORGANIC 1 LB'],
#  ['UTZ HONEY BAR BQ CHIP 7.75 OZ',
#   'APPLE WA HONEYCRISP LB',
#   'UTZ REG POTATO CHIP 8 OZ',
#   'UTZ HELUVA GOOD FRNCH ON WVY CHIP 7.75 O',
#   'BAKE BEANS EACH',
#   'STEAKHOUSE POTATO SALAD LB',
#   'BALLARDS 12OZ CHIKCEN SALAD 12 OZ',
#   'KR SLC COJK MLD CHDR 7.2 OZ',
#   'LOF DELI/SHVD HNY HAM 9 OZ',
#   'LOF OVN RSTD TRKY 9 OZ',
#   'STRAWBERRIES   1 LB',
#   'CUPCAKE W PICK 6 CT',
#   'LBS HAWAIIAN SLIDER BUNS 15 OZ',
#   'WONDER 8 PK HOT DOG BUN 13 OZ',
#   'BUNNY HONEY WHEAT 20 OZ',
#   'UTZ SOUR CREAM & ONION RILE CHIP 7.75 OZ'],
#  ['SELECT ANGUS NY STRIP EA',
#   'POTATO RUSSET 5 LB',
#   'KR MAYO REAL CREAMY & SMOOTH 30 OZ',
#   'ONIONS SWEET LB',
#   'KR PHIL CREAM CHSE BAR 8 OZ',
#   'KR PHIL CREAM CHSE BAR 8 OZ',
#   'CORN BICOLOR CT'],
#  ['MASONRY WHEEL4.5X1/8X7/8',
#   'RED BULL YELLOW SIN 12 OZ',
#   'BOLT EYE W/NUT5/16X5',
#   'RED BULL YELLOW SIN 12 OZ',
#   'MASONRY WHEEL4.5X1/8X7/8'],
#  ['PICKLED BEETS',
#   'AMERICAN POTATO SALAD PER LB',
#   'BAKE BEANS EACH',
#   'MISC HOT CHICKEN EACH',
#   'COLE SLAW EACH',
#   'CRANBERRY SALAD EACH'],
#  ['FLORAL SILK BUSH/ARRANGEMNT', 'FRESH ARRANGEMENT OR STEMS'],
#  ['PIL DELUXE CHOC CHIP CKY 16 OZ',
#   'CPN: $1 OFF (2) Pillsbury Participating  Item',
#   'PIL COOKIE DOUGH CHOC 16 OZ'],
#  ['PUTTY PLUMBERS 5#', 'CHARLOTTE PIPE FLOWGUARD 1/2'],
#  ['LOLLIPOP DSP REFIL 1.1OZ 1.1 OZ',
#   'DOZEN ROSE BOUQUET BQT',
#   'LOLLIPOP DSP REFIL 1.1OZ 1.1 OZ',
#   'CARD MDAY MOTHER',
#   'MISC FLORAL GIFTWARE'],
#  ['RC 24 PK',
#   'HUNGRYMAN FRD CKN DRK 16 OZ',
#   'HUNGRYMAN FRD CKN DRK 16 OZ',
#   'MEOW MIX TNDR BEEF SALMON 3 LB 3 LB',
#   'PF ICE CRM BAR 30 OZ',
#   'BC HMB HLP RANCH BGR 5.9 OZ',
#   'BC HMB HLP CHSY HASHBROWN 5.5 OZ',
#   'JAR DIP TOSTITOS MILD SALSA 15.5 OZ',
#   'CP PICKLE LOAF PEG 5 OZ',
#   'CAROLINA PRIDE HNY ROASTED TKY 4OZ',
#   'CAROLINA PRIDE HNY ROASTED TKY 4OZ',
#   'CAROLINA PRIDE COOKED SALAMI 6 OZ',
#   'CAROLINA PRIDE HNY ROASTED TKY 4OZ',
#   'BA SPORTS DRK BLUE RASPBERRY 8 PK 96 OZ',
#   'STIR FRY CHICKEN LB',
#   'PREMIUM RESERVE RIBEYE STEAK LB',
#   'SEAPAK JMB  BTRFLY SHRMP 9 OZ',
#   'ST. LOUIS RIBS LB',
#   'ST. LOUIS RIBS LB',
#   'SF 7 TRAY CF THIGH LB',
#   'TENDERIZED PORK CHOPS LB',
#   'TENDERIZED BUTTERFLY CHOPS LB',
#   'ROXANE SPRING WTR 24 PK'],
#  ['GP SWEET BLACK TEA 6 PK 101.4 OZ',
#   'IDHN ORIGINAL MASHED POTATOES 13.75 OZ',
#   'GM CINNAMON TOAST CRUNCH 12 OZ',
#   'DYNAMIC PLASTIC PARTY CUPS RED 18OZ 50 C',
#   'IDHN ORIGINAL MASHED POTATOES 13.75 OZ',
#   'GM CINNAMON TOAST CRUNCH 12 OZ',
#   'PIL MIX GERMAN CHOCOLATE 15.25 OZ',
#   'BST CH TEXAS TOAST 5 CHEESE 8 CT',
#   'KR FINE SHRD MOZZ 8 OZ',
#   'KR FINE SHRD PARMESAN 6 OZ',
#   'SNPK CHOCOLATE PUDDING 4 PK',
#   'SNPK CHOCOLATE PUDDING 4 PK',
#   'SNPK CHOCOLATE PUDDING 4 PK',
#   'SNPK CHOCOLATE PUDDING 4 PK',
#   'WATERMELON SLICES LB',
#   'BST CH LARGE EGGS 6 CT',
#   'TIDY CAT SCOOP PERFORMANCE 20 LB',
#   'MILO SWEET TEA GAL'],
#  ['IDHN AU GRTN POTATO CASROLE FS 4 OZ',
#   'RS PUNCHED  ENERGY 16 OZ',
#   'RS PUNCHED  ENERGY 16 OZ',
#   'BST CH TEXAS TOAST 5 CHEESE 8 CT',
#   'RS PUNCHED  ENERGY 16 OZ',
#   'RS PUNCHED  ENERGY 16 OZ',
#   'SUKARNE BF RIBEYE STK LB',
#   'SUKARNE BF RIBEYE STK LB',
#   'SNAPPLE FRUIT PUNCH PET 16 OZ',
#   'IDHN AU GRTN POTATO CASROLE FS 4 OZ'],
#  ['TRKY HILL MOOSE TRACKS 46 OZ',
#   'PF PREMIUM BUTTER PECAN 48 OZ',
#   'MAYFIELD BROWN COW 48 OZ'],
#  ['MOUNTAIN DEW 20 OZ',
#   'MOUNTAIN DEW 20 OZ',
#   'DIET PEPSI 20 OZ',
#   'MOUNTAIN DEW 20 OZ',
#   'DR PEPPER 20 OZ',
#   'DEVOUR BUFF CHKN MAC CHS 12 OZ',
#   'DEVOUR BCN BAC N CHS 12 OZ',
#   'PF NEOPOLITAN PAIL 128 OZ',
#   'HAAGEN DAZS BUTTER PECAN 14 OZ',
#   'CHOLULA HOT SCE CHILI GARLIC 5 OZ',
#   'KY LEG HICKRY SMK SLICED BACON 1 LB',
#   'KY LEG HICKRY SMK SLICED BACON 1 LB',
#   'KY LEG HICKRY SMK SLICED BACON 1 LB',
#   'KINGS HAWAIIAN ROLL 12 OZ',
#   'SWT RAY BBQ HONEY 28 OZ',
#   'RESER RED SKIN POTATO SALAD 3 LB',
#   'PICK 5 MISC 24.99 EA',
#   'MISC HOT FOODS EACH',
#   'MISC HOT FOODS EACH',
#   'RS PUNCHED  ENERGY 16 OZ'],
#  ['CARD MDAY ANYONE', 'SINGLE ROSE EA', 'LA COSTENA PEPPER CHIPOTLE 7 OZ'],
#  ['CHOC CHIP COOKIES EACH',
#   'CHOC CHIP COOKIES EACH',
#   'CHOC CHIP COOKIES EACH'],
#  ['MOUNTAIN DEW .5L 6 PK',
#   'ORANGE CRUSH 16.9OZ 6PK 6 PK',
#   'ORANGE CRUSH 16.9OZ 6PK 6 PK',
#   'COUPL BRS3/4MH-3/4FP ACE'],
#  ['MILOS SWEET TEA 20 OZ',
#   'TROP RFRSHR PNAP MGO 11OZ 12L 11 OZ',
#   'CANTALOUPE CHUNKS LB',
#   'TROP RFRSHR PNAP MGO 11OZ 12L 11 OZ',
#   'OM LC NACHOS FP 10.7',
#   'MINI TRI COLOR PEPPERS RS 1 LB',
#   'RST SIRLOIN STEAKHOUSE MARINADE 12 OZ',
#   'CUCUMBER MINI EA',
#   'MILOS SWEET TEA 20 OZ'],
#  ['T PRD SAGE   SAUSAGE 1L',
#   'COLE SLAW EACH',
#   'AM CH MILK SKIM GAL 128 OZ',
#   'SELECT ANGUS NY STRIP EA',
#   'POTATO GG GOLDEN 3 LB',
#   'SELECT ANGUS NY STRIP EA',
#   'OL FOLKS SAUS.MILD 1/LB'],
#  ['PEPSI .5 LTR 6 PK',
#   'BST CH CHUNK MED CHEDDAR 8 OZ',
#   'KRAB SPINACH DIP SOSDIP',
#   'BST CH CHUNK MONT JACK 8 OZ',
#   'PEPSI .5 LTR 6 PK'],
#  ['SELECT ANGUS NY STRIP EA',
#   'POTATO SWEET LB',
#   'PR NY STRP STK EA',
#   'PR NY STRP STK EA',
#   'MC HIMALAYAN PINK SALD GRINDER 2.5 OZ'],
#  ['CV LEMON BUNDT CAKE 16 OZ', 'AS ICE CREAM VANILLA 128 OZ'],
#  ['AN 85/15 ROUND PATTI 1.33LB',
#   'FNCY FST W/SHRIMP 3 OZ',
#   'FNCY FST FLAKE TUNA 3 OZ',
#   'FNCY FST FLAKE TUNA 3 OZ',
#   'FNCY FST FLAKE TROUT 3 OZ',
#   'FNCY FST W/SHRIMP 3 OZ',
#   'FNCY FST FLAKE TROUT 3 OZ',
#   'IDAHO HAND CUT FRIES 16.1 OZ'],
#  ['BC HMB HLP CHSY ITAL 6.1 OZ',
#   'EGGO BUTTERMILK WAFFLE 10 CT',
#   'ECK S/CHS SMO ROPE 13 OZ',
#   'EGGO HOMESTYLE WAFFLE 10 CT',
#   'ECK S/CHS SMO ROPE 13 OZ',
#   'IMPERIAL MARG STICK 16 OZ',
#   'IMPERIAL MARG STICK 16 OZ',
#   'BST CH NAT BNL SKNL BRST 2.5 LB',
#   'BST CH CK 3140 SHMP 16 OZ',
#   'LMKR CHICKEN SM 2.6 OZ',
#   'LUNCHMAKER HONEY HAM 2.44 OZ',
#   'LMAKER BOLO 2.6 OZ',
#   'LMAKER TURKEY 2.6 OZ',
#   'FIELD THK SLICE  BOLO 12 OZ',
#   'BST CH NO BAKE CHSECAKE 11.2 OZ',
#   'BC HMB HLP CHSY ITAL 6.1 OZ',
#   'BC HMB HLP STROGANOF 6.4 OZ',
#   'BC HMB HLP STROGANOF 6.4 OZ',
#   'KR BLUE BOX MAC N CHEESE 7.25 OZ',
#   'KR BLUE BOX MAC N CHEESE 7.25 OZ',
#   'BC SUD SAL RANCH/BAC 7.5 OZ',
#   'BC TNA HLP TETRAZIN 7.3 OZ',
#   'BC TNA HLP TETRAZIN 7.3 OZ',
#   'CRMT FETTUCINE 16 OZ',
#   'CRMT FETTUCINE 16 OZ',
#   'CRMT ANGEL HAIR SPAG 16 OZ',
#   'CRMT ANGEL HAIR SPAG 16 OZ',
#   'CRMT ROTINI 16 OZ',
#   'KNORR PS TERIYAKI NOODLES 4.6 OZ',
#   'KNORR PS CRMY GARLIC SHELL 4.4 OZ',
#   'KNORR PS PARMESAN 4.3 OZ',
#   'KNORR PS TERIYAKI NOODLES 4.6 OZ',
#   'RAGU PASTA SC GRLC PARM 16 OZ',
#   'RAGU PASTA SC GRLC PARM 16 OZ',
#   'RAGU PASTA SC 4 CHEESE 16 OZ',
#   'AS SLICED CARROT 14.5 OZ',
#   'BST CH WHOLE KERNAL CORN 15.25 OZ',
#   'AS SLICED POTATO 15 OZ',
#   'BST CH WHOLE KERNAL CORN 15.25 OZ',
#   'BST CH WHOLE KERNAL CORN 15.25 OZ',
#   'BST CH WHOLE KERNAL CORN 15.25 OZ',
#   'JJ LEMON CREAM PIE 4 OZ',
#   'JJ BSTN CR DUO PIE 4 OZ',
#   'FP GROUND BEEF LEAN LB',
#   'FP WHOLE PNLS PORK LOIN LB',
#   'AM CH MILK WHOLE GAL 128 OZ',
#   'POTATO RUSSET 5 LB',
#   'STRAWBERRIES   1 LB',
#   'AL SAVE GRAN SUGAR 4 LB',
#   'CORN BICOLOR CT',
#   'NIAGARA DRNKG  WTR 24 PK',
#   'NIAGARA DRNKG  WTR 24 PK',
#   'CHERRY COKE 20 OZ'],
#  ['SQUIRT 12 OZ 8 PK',
#   'KR MW CUPS MAC N CHS ORIG 4 CT',
#   'KR MW CUPS MAC N CHS ORIG 4 CT',
#   'KR MW CUPS MAC N CHS ORIG 4 CT',
#   'BABYBEL WHITE CHD 8.5 OZ',
#   'DEAN FRNCH ONION DIP',
#   'PRAIRIE FARM WHOLE MILK 128 OZ',
#   'PURE LEAF SWEET TEA 6 PK 101.4 OZ',
#   'SNAPPLE KIWI STRAWBERRY JCE  6 PK 96 OZ',
#   'AL SAVE WAVY POT CHP 13 OZ'],
#  ['CH DIP STRWBRY 6 CT',
#   'HRSH REESE PBTR CUPS 1.5 OZ',
#   'COW TALES CHOC EA',
#   'CH DIP STRWBRY 6 CT'],
#  ['LOLLIPOP DSP REFIL 1.1OZ 1.1 OZ',
#   'BODY ARMOR ZERO FRUIT PUNCH 16 OZ',
#   'OM BASIC LUNCH CHKN DUNKS 4.2 OZ'],
#  ['CONTRACTOR BAG 42G 25PK', 'CONTRACTOR BAG 42G 25PK'],
#  ['PIL ORANGE ROLLS W/CINN 13.9 OZ',
#   'BST CHCE ROUND TOP 20 OZ',
#   'QUICK CONNECT3/8 F PLUG'],
#  ['MUSTARD POTATO SALAD PER LB',
#   'RESERS PARFAIT STRAWBERRY 20 OZ',
#   'DILL DIP EACH',
#   'AMISH MACARONI SALAD EACH',
#   'BREAD HAWAIIAN ORIGINAL 16 OZ',
#   'LG CHOC CHIP COOKIE EACH',
#   'KNG HAWAIIAN PRETZL BITES 10.2'],
#  ['PF BLACK RASPBERRY CHOC CHIP 48 OZ',
#   'COKE DE MEXICO 355ML 4PK 4 PK',
#   'TRKY HILL CHOCOLATE MINT CHIP 46 OZ'],
#  ['GOT Markdown - Cold Deli',
#   'SMOKED PORK STEAK EACH',
#   'FRITOS CHILI CHEESE 9.25 OZ'],
#  ['KRETSCHMAR BEEF PASTRAMI EACH',
#   'GOT Markdown - Cold Deli',
#   'SWEET N SOUR SLAW EACH',
#   'BOWTIE PASTA EACH'],
#  ['MOUNTAIN DEW 20 OZ', 'PRNGL BBQ GRAB N GO \xa0\xa0\xa0\xa0 2.5 OZ'],
#  ['CBAD ABC &  WITH MEATBALLS 15 OZ',
#   'CLSC PASTA SC SWEET BASIL 24 OZ',
#   'CBAD BEEF RAVIOLI 15 OZ',
#   'CBAD BEEF RAVIOLI 15 OZ',
#   'CBAD BEEFARONI 15 OZ',
#   'PEPRDG GARLIC BREAD 10 OZ',
#   'LEWIS STEAK ROLL 14 OZ',
#   'KNORR RICE CRMY CHKN 5.7 OZ',
#   'KY LEG HICKRY SMK SLICED BACON 1 LB',
#   'GROUND BEEF GROUND ROUND LB',
#   'JVL FIRECRACKER BRAT LINKS 19 OZ',
#   'BARILLA THICK SPAGHETTI 16 OZ',
#   'CRACKERS TSTED PNUT BTR 8PK 11.36 OZ',
#   'CLSC PASTA SC SWEET BASIL 24 OZ'],
#  ['SNICKERS ICE CREAM BARS 6 PK 12 OZ', 'PF ICE CRM SAND 42 OZ'],
#  ['ORE IDA WAFFLE FRIES 22 OZ',
#   'BST CH SHRED MOZZARLA 32 OZ',
#   'MAR RAMEN NDL CHKN 3 OZ',
#   'SKITTLES SOUR SINGLE 1.8 OZ',
#   'FP GROUND CHUCK LEAN LB',
#   'SF 7 TRAY CF B/S BRST LB',
#   'GROUND BEEF GROUND ROUND LB',
#   'GROUND BEEF GROUND ROUND LB',
#   'GROUND BEEF GROUND ROUND LB',
#   'LD OATMEAL CREAM PIE 16 OZ',
#   'MAR RAMEN NDL CHKN 3 OZ'],
#  ['PCTSWT STM BROC FLORET 10 OZ',
#   'BL RIBBON C NEOPOLITAN R FAT 48 OZ',
#   'PCTSWT BROCCOLI CUTS 12 OZ'],
#  ['TRAP BLKEYE PEA BACN 15.5 OZ',
#   'MRS CUB CROUTONS SEASONED 5 OZ',
#   'FRITO LAY POPCORNERS   SEASALT 7 OZ',
#   'LA PREF FAJITA SEAS 1.25 OZ',
#   'ANGUS STIR FRY BEEF LB',
# ...
#   'AS FRIED APPLES CINNAMON 15 OZ',
#   'ARGO CORN STARCH 16 OZ',
#   'HAM SALAD EACH'],
#  ['DELI BEVERAGE EACH',
#   'PF STR JT DP VAN CN 27.6 OZ',
#   'TYSON STHRN STYLE CHICKEN SAN 6 OZ',
#   'PF CHOC ECLAIR 16.5 OZ',
#   'PF ICE CRM SAND 24 OZ',
#   'KR SHRD TRIPLE CHDR 8 OZ',
#   'PROG SP RH CHKN NDL HMSTYL 19 OZ',
#   'AMISH MACARONI SALAD EACH',
#   'AMISH POTATO SALAD EACH',
#   'BST CH GRD A LRG 18P EGG 1.5 DZ',
#   'YOP PEACH YOG 6 OZ',
#   'YOP PEACH YOG 6 OZ',
#   'SARA LEE WHL GRAIN BREAD 20 OZ',
#   'PUFF ULTRA SOFT FACIAL FS 124 CT',
#   'LD MUFFINS CHOCOLATE CHIP 5 CT 12.67 OZ',
#   'RF CHO DNT 8Ct 8 CT',
#   'LD BIG PACKS FROSTED DONUTS 16.91 OZ',
#   'SFTSP LHS SOOTHING ALOE VERA 7.5 OZ',
#   'DELSYM ADLT GRP 12HR 5 OZ',
#   'PROG SP RH CHKN NDL HMSTYL 19 OZ',
#   'SFTSP LHS MILK GOLDEN HONEY 7.5 OZ',
#   'STANDARD SIDE LB',
#   'TENDERS 1 LB',
#   'MISC HOT CHICKEN EACH',
#   'MISC HOT FOODS EACH',
#   'PRAIRIE FARM 2 % MILK H 64 OZ',
#   'TRES ANTI BRKG DEFNS COND 28 OZ',
#   'ENSURE NUTRTIONAL SHAKE VANILLA 6 PK',
#   'PEPSI .5 LTR 6 PK',
#   'SUNKIST ORANGE 6 PK 101.4 OZ'],
#  ['BAG ICE 7 LB',
#   'CHEETOS PUFFS CHEDDAR 1 OZ',
#   'CHEETOS PUFFS CHEDDAR 1 OZ',
#   'CHEETOS PUFFS CHEDDAR 1 OZ',
#   'CHEETOS PUFFS CHEDDAR 1 OZ',
#   'CHEETOS PUFFS CHEDDAR 1 OZ',
#   'PLNT CHIPOLTE PNUTS 6 OZ',
#   'CHEETOS PUFFS CHEDDAR 1 OZ',
#   'CHEETOS PUFFS CHEDDAR 1 OZ',
#   'PLNT CHIPOLTE PNUTS 6 OZ',
#   'CHEETOS PUFFS CHEDDAR 1 OZ',
#   'CHEETOS CRUNCHY CHEDDAR 1 OZ',
#   'APPLE MI GOLD DELICIOUS 3 LB',
#   'CHEETOS CRUNCHY CHEDDAR 1 OZ',
#   'CHEETOS CRUNCHY CHEDDAR 1 OZ',
#   'CARROTS 1 LB',
#   'CHEETOS CRUNCHY CHEDDAR 1 OZ',
#   'NAB WHEAT THINS ORIGINAL 8.5 OZ',
#   'FR MUSTARD CLASSIC YELLOW 14 OZ',
#   'PLNT CHIPOLTE PNUTS 6 OZ',
#   'BISTRO APPLWD SMOKE HM 8 OZ',
#   'SABRA HUMMUS CLASSIC 10 OZ',
#   'STRWBRY/PINEPLE/BLUBRY MIX LB',
#   'BLUEBERRIES PINT',
#   'GRAPE AND CHEESE SNACKER',
#   'WATERMELON SLICES LB',
#   'CHICKEN LEG QUARTERS LB',
#   'CHICKEN LEG QUARTERS LB',
#   'SMOKED CHICKEN WING EACH',
#   'SMOKED CHICKEN WING EACH'],
#  ['BB SUPER FUDGE BROWNIE 46 OZ',
#   'AM CH MILK 2% GALN 128 OZ',
#   'BB SUPER FUDGE BROWNIE 46 OZ',
#   '9 IN CHOC CHIP COOKIE EACH'],
#  ['RAISED BED SOIL 1.5CU FT',
#   'RAISED BED SOIL 1.5CU FT',
#   'RAISED BED SOIL',
#   'RAISED BED SOIL'],
#  ['KY LEG APPLWOD SMK SLCED BACON 1 LB',
#   'DUKES MAYONNAISE REAL 30 OZ',
#   'DAISY SOUR CREAM 8 OZ',
#   'BUNNY SOFT TWIST 16 OZ'],
#  ['SPRYPNT 2X GLS WHITE',
#   'DCK SCREW 10X3 GRN 1#',
#   'MONSTER ZERO ULTRA 16 OZ',
#   'BIT DRILL 7/16 SPEEDBOR',
#   'TORX BIT T25 2 SW',
#   'GLUE TITEBOND8OZ FRANKLN',
#   'DOWEL FSC 7/16X48 GREEN',
#   'DOWEL FSC 7/16X48 GREEN'],
#  ['PEPSI .5 LTR 6 PK', 'PEPSI .5 LTR 6 PK'],
#  ['SANDWICH CUSTOM MADE EACH',
#   'RUFFLES CHDRANDSOUR CREAM 1 OZ',
#   'RUFFLES CHDRANDSOUR CREAM 1 OZ',
#   'DELI BEVERAGE EACH'],
#  ['CRACKERS CHEESE PNUT BTR 8PK 11.36 OZ',
#   'LIBBY REG FS GREEN BNS 14.5 OZ',
#   'CRMT VERMICELLI 16 OZ',
#   'LIBBY REG FS GREEN BNS 14.5 OZ',
#   'PIL GR BTR TST BISC 10.2 OZ',
#   'RAGU PASTA SC CHNKY ONION GARLIC 24 OZ',
#   'BDN AMER IW SINGLES 12 OZ',
#   'TENDERIZED THIN BONLES PORK CHOPS LB',
#   'FP GROUND CHUCK LEAN LB',
#   'FRESH PORK SAUSAGE LB',
#   'BONELESS COUNTRY STYLE RIBS LB',
#   'SF THIN BNLS BRST LB',
#   'AS WATER SPRING 128 OZ',
#   'AS WATER SPRING 128 OZ',
#   'NPL FILTERED WATER 24 PK 405.6 OZ'],
#  ['B BUNNY VANILLA 48 OZ',
#   'FRESH GROUND CHUCK 80/20 LB',
#   'B BUNNY VANILLA 48 OZ',
#   'MUSTARD POTATO SALAD PER LB',
#   'CORN BICOLOR CT',
#   'TOMATO ON THE VINE  1 LB'],
#  ['LETTUCE  EA',
#   'BLUEBERRIES PINT',
#   'TOMATOES NATURE  SWEET CHERUB 10 OZ',
#   'GRAPES RED SEEDLESS LB',
#   'PF GOLDFISH BULK CHEDDAR BULK 27.3 OZ',
#   'BUNNY HONEY WHEAT 20 OZ',
#   'STRAWBERRIES   1 LB',
#   'BLUEBERRIES PINT'],
#  ['MISC HOT FOODS EACH', 'DELI BEVERAGE EACH'],
#  ['NPL PURIFIED WATER 6 PK 101.4 OZ',
#   'AM CH MILK 2% HGAL 64 OZ',
#   'STANDARD SIDE LB',
#   'AS WATER DISTILLED 128 OZ',
#   'BANANA LB',
#   'ORANGE NAVEL  EA'],
#  ['POWERADE ZERO GRAPE 28 OZ',
#   'POWERADE ZERO GRAPE 28 OZ',
#   'POWERADE ZERO GRAPE 28 OZ',
#   'POWERADE ZERO GRAPE 28 OZ',
#   'POWERADE ZERO GRAPE 28 OZ'],
#  ['THRD SL TAPE1/2X260', 'THRD SL TAPE1/2X260'],
#  ['READING GLASSES', 'READING GLASSES', 'READING GLASSES'],
#  ['SI KIWI STRAWBERRY 17 OZ',
#   'BODY ARMOR LYTE SPORTS DK TROP COCNT 16',
#   'SI BLACK RASPBERRY 17 OZ',
#   'BA LYTE BLUEBERRY POM 16 OZ',
#   'BA LYTE PEACH MANGO 16 OZ'],
#  ['BST CH LAWN REFS 30GL 5 CT',
#   'BROCCOLI  CROWNS LB',
#   'SIMPLY 100% GRPFT JC 52 OZ',
#   'FLOWER BEDDING 4 CELL EA',
#   'FLOWER BEDDING 4 CELL EA',
#   'FLOWER BEDDING 4 CELL EA'],
#  ['GRIPPOS BBQ CHIPS 8 OZ', 'BST CH CHED SC CHIPS 7.75 OZ'],
#  ['ICED OATMEAL COOKIES EACH',
#   'AS FROZEN WHIP TOPPING 8 OZ',
#   '8 CT ICED SUGAR COOKIES 8 CT',
#   'STRAWBERRIES   1 LB',
#   'BST CH SS CHEESE RAVOLI 20 OZ',
#   'DESSERT SHELLS 6 CT',
#   'TASTY CHOICE SESAME CHIC 24 OZ',
#   'SEABEST 50/60 CT CKD SHRMP 10 OZ',
#   'SMOKED CHICKEN HOT EACH',
#   'FLOWER BEDDING 4 CELL EA'],
#  ['CHERRY COKE 20 OZ', 'QKR CPN CRN BRRY BAR 8 CT'],
#  ['DIET MOUNTAIN DEW .5L 6 PK',
#   'DIET MOUNTAIN DEW .5L 6 PK',
#   'FLORAL HANGING BASKET',
#   'FLORAL HANGING BASKET',
#   'FLORAL SEASONAL',
#   'STAND ANNUAL PLANTS 4 IN'],
#  ['B BUNNY MINI SWIRL VANILLA 8 CT 18 OZ',
#   'HAM SALAD EACH',
#   'PIMENTO SPREAD EACH',
#   'CRANBERRY SALAD EACH'],
#  ['PF ORNG DRM BAR 30 OZ',
#   'PF PREMIUM STRAWBERRY SHORTCAKE 16 OZ',
#   'BRKSTN RICOTTA CHEESE 15 OZ',
#   'PF PREMIUM BUTTER PECAN IC 16 OZ',
#   'BST CH PINK FRIST COOKIE 13 OZ',
#   'BST CH PINK FRIST COOKIE 13 OZ'],
#  ['PRAIRIE FARMS BUTTER MIL 32 OZ',
#   'YUMMY LOLLI REFILLS 1 OZ',
#   'BC FRSTNG DLX WHP STRW 12 OZ',
#   'G2G PARADISE PUNCH BIGGE 10 OZ'],
#  ['HILLMAN FASTENERS', 'ROUND UP W&G CONC 36.8OZ', 'BOLT EYE W/NUT 1/4X2'],
#  ['DASANI PET 16.9 OZ 24 PK', 'KLNX US FLAT 4 PK 480 CT', 'BANANA LB'],
#  ['ROXANE SPRING WTR 24 PK', 'ROXANE SPRING WTR 24 PK'],
#  ['CHEEZ IT PEPPER JACK 12.42 OZ',
#   'CHEEZ IT PEPPER JACK 12.42 OZ',
#   'PF WHOLE GRAIN 100% WHOLE WHEAT BRD 24 O',
#   'BST CH GR A LARGE EGG 1 DZ',
#   'FRESH GROUND CHUCK 80/20 LB',
#   'FRESH GROUND CHUCK 80/20 LB',
#   'DILL DIP EACH',
#   'CRISCO CANOLA OIL 40 OZ',
#   'POTATO RUSSET 5 LB'],
#  ['BUNNY SOFT TWIST 16 OZ',
#   'CAMP SOUP CREAM CHICKEN HR 10.5 OZ',
#   'LEWIS TEXAS TOAST 24 OZ',
#   'SWANSON BROTH CHICKEN BOX 32 OZ',
#   'RAGU OWS TRAD RETRO SAUCE LE 24 OZ',
#   'RAGU OWS TRAD RETRO SAUCE LE 24 OZ',
#   'SUNKIST ORANGE ZERO SUAGR 6 PK',
#   'HOST DONETTES OLD FASH 10.5 OZ',
#   'GRIPPOS BBQ CHIPS 12 OZ',
#   'COFMAT IC COF CARML 50 OZ',
#   'PF SHERBET ORANGE 32 OZ',
#   'BLUE BON SPREAD BOWL 15 OZ',
#   'BANQ TURKEY MEAL 10 OZ',
#   'BANQ SWEDISH MEATBALLS 10.25 OZ',
#   'CRMT SPAGHETTI 16 OZ',
#   'MOUNTAIN DEW CODE RED 16.9 OZ 6 PK',
#   'MOUNTAIN DEW CODE RED 16.9 OZ 6 PK'],
#  ['DESSERT FOR 2 EACH',
#   'BST CH HEAVY DUTY  SPOONS 24 CT',
#   'PARFAIT EACH',
#   'PDGR CHOICE CUT BEEF 13.2 OZ',
#   'GG SF BROC CAR CAUL CHS 22 OZ',
#   'MILOS SWEET TEA 20 OZ',
#   'VLVTA BOWL SHELLS N CHEESE 5 OZ',
#   'SMOKED CHICKEN HOT EACH',
#   'BST CH NAT BONE 5IN EA',
#   'MILO TEA SWEET W/SPLENDA GAL'],
#  ['CNTRY TIME OTG LMD 10CT 10 CT',
#   'JOHN M BRAUNSCHWEIGER 16 OZ',
#   'BC FRSTNG RC CREAM CHSE 16 OZ',
#   'CARROTS GR MATCHSTIX 10 OZ',
#   'V8 ORIG 100% VEG JCE 46 OZ',
#   'V8 SPICY HOT VEG JCE 46 OZ',
#   'DANISH ROLLS 3 CT',
#   'BROWNIE FACTORY EACH',
#   'NIAGARA DRNKG  WTR 24 PK',
#   'NIAGARA DRNKG  WTR 24 PK'],
#  ['BST CH GR A LARGE EGG 1 DZ',
#   'CRST LT SWT TEA 12 QT',
#   'AS SAUERKRAUT 15 OZ',
#   'AS SAUERKRAUT 15 OZ',
#   'HZ KETCHUP SQUEEZE 38 OZ',
#   'HZ KETCHUP SQUEEZE 38 OZ',
#   'JF MUFFIN PANS 2 CT',
#   'CHI CHI SALSA MED 16 OZ',
#   'CELERY EA',
#   'CABBAGE GREEN LB',
#   'LETTUCE  EA',
#   'ONIONS SWEET LB',
#   'LPT GREEN TEA 12 PK 202.8 OZ'],
#  ['COKE CAFFEINE FREE 12 PK 144 OZ',
#   'ROTISSERIE CHICKEN HOT EACH',
#   'COKE CAFFEINE FREE 12 PK 144 OZ',
#   'APPLE WA RED DELICIOUS LB',
#   'HRSH MILK CHOC BAR 1.55 OZ',
#   'SMALL DIE CAST CARS EACH',
#   'DORITOS NACHO CHEESE 9.25 OZ',
#   'POTATO RUSSET 5 LB',
#   'DASANI WATER 20 OZ'],
#  ['FL LAYS DUAF FLAVOR 7.75 OZ',
#   'GOURMET DBL CHOC CHIP EACH',
#   'OREO MEGA STUFF PARTY SIZE 25.35 OZ',
#   'ROBIN BBQ SC WHISKEY RIVER 14 OZ'],
#  ['RED BULL SUMMER EDITION STRA 12 OZ',
#   'MOUNTAIN DEW 20 OZ',
#   'HRSH REESE PBTR CUPS 1.5 OZ'],
#  ['PF PREMIUM ROCKY ROAD 48 OZ',
#   'KR MAC CH SPONGEBOB 5.5 OZ',
#   'KR MAC CH SPONGEBOB 5.5 OZ',
#   'KR MAC CH SPONGEBOB 5.5 OZ',
#   'KR MAC CH SPONGEBOB 5.5 OZ',
#   'CPN: SAVE $2.00 off (4) Kraft Mac Cheese 5/7-'],
#  ['SINGLE DONUT',
#   'FROSTIE CREAM SODA 32 OZ',
#   'DOVE MILK CHOC BAR 1.44 OZ',
#   'BST-CH BBQ PRK SKINS 5 OZ'],
#  ['BST CH SODA CHERRY COLA 12PK 144 OZ',
#   'BST CH SODA DR CHOICE 12PK 144 OZ',
#   'DORITOS COOL RANCH 9.25 OZ',
#   'DORITOS NACHO CHEESE 9.25 OZ',
#   'BST CH SHRED TACO 8 OZ',
#   'BST CH SHRED PEPPER JACK 8 OZ',
#   'WAMP A/N MLD TACO MT 16 OZ',
#   'AS CULTURED SOUR CREAM 16 OZ',
#   'MC STREET TACO CHICKEN .87 OZ',
#   'MC STREET TACO CHICKEN .87 OZ',
#   'MC STREET TACO CHICKEN .87 OZ',
#   'AS ORANGE 67.6 OZ',
#   'CUPCAKE W PICK 10 CT',
#   'MOUNTAIN DEW 20 OZ',
#   'DOLE SHREDDED LETTUCE 8 OZ',
#   'TOMATOES HOT HOUSE LARGE LB',
#   'PACE PICANTE SAUCE MILD 16 OZ',
#   'ONIONS SWEET LB',
#   'GROUND BEEF LB',
#   'GROUND CHUCK LB',
#   'DR PEPPER 20 OZ',
#   'MONSTER ENERGY PUNCH 16 OZ'],
#  ['BE LOADD BAKED PTO BAKE 25 OZ',
#   'TENDERIZED THIN BONLES PORK CHOPS LB',
#   'FP BONLES CNTRY RIBS',
#   'TENDERIZED PORK CHOPS LB',
#   'FP BONLES CNTRY RIBS',
#   'BST CH GR A LARGE EGG 1 DZ',
#   'SWT RAY BBQ HONEY 40 OZ',
#   'BUNNY SOFT TWIST 16 OZ',
#   'LOF DELI/SHAVED HAM 9 OZ',
#   'MINI CHOC CUPCK WP 3 OZ',
#   'KY LEG HICKRY SMK SLICED BACON 1 LB',
#   'KY LEG HICKRY SMK SLICED BACON 1 LB',
#   'COKE CLASSIC 24 PK 12 OZ 288 OZ',
#   'COKE CLASSIC 24 PK 12 OZ 288 OZ',
#   'CPN: $1 OFF (2) Coke Participating Items 24 p'],
#  ['OCN SPR CRANBERRY JUICE COCKTAIL 64 OZ',
#   'OCN SPR CRAN APPLE JUICE 64 OZ',
#   'BC RAINBOW MIX SPRINKLES 1.75 OZ'],
#  ['KR GRTED PARM PP4.99 8 OZ',
#   'RED GOLD TOMATO PUREE 15 OZ',
#   'RED GOLD TOMATO PUREE 15 OZ',
#   'CRMT THIN SPAGHETTI 16 OZ',
#   'CRMT THIN SPAGHETTI 16 OZ',
#   'FP GROUND CHUCK LEAN LB'],
#  ['NY GARLIC BREADSTICK 6 CT',
#   'RONCO SPAGHETTI 16 OZ',
#   'ICE MOUNTAIN 16.9 OZ 24 PK PET 405.6 OZ',
#   'BUNNY HAMBURGER BUNS 8 CT'],
#  ['CLR LIME RUST REMOVER 28 OZ',
#   'DRANO MX GEL CLOG RMVR 80 OZ',
#   'CLR LIME RUST REMOVER 28 OZ'],
#  ['KR BLK ANGUS RST BEEF EACH', 'DORITOS COOL RANCH 9.25 OZ'],
#  ['I DLT CRML MACCH CLD FOAM CREAMER 14 OZ',
#   'COFMAT VAN CARM CRM 32 OZ',
#   'REDI WIP REAL CREAM TOP 6.5 OZ',
#   'FL LAYS DUAF FLAVOR 3 7.5 OZ',
#   'LAYS DILL PICKLE 7.75 OZ',
#   'ANGEL FOOD CAKE',
#   'ANGEL FOOD CAKE',
#   'STRAWBERRIES   1 LB',
#   'STRAWBERRIES   1 LB'],
#  ['MECH TIMER INDR 24HR', 'MECH TIMER INDR 24HR'],
#  ['BC PENCIL CANDLES 24 CT', '1/2 SLAB RIB COLD EACH'],
#  ['DORITOS NACHO CHEESE 9.25 OZ',
#   'DORITOS NACHO CHEESE 9.25 OZ',
#   'DORITOS COOL RANCH 9.25 OZ',
#   'KY LEG APPLWOD SMK SLCED BACON 1 LB',
#   'ECKRICH THICK BOLOGNA 12 OZ',
#   'K9 CARRYOUTS BEEF 4.5 OZ',
#   'V CAMP PORK N BEANS 15 OZ'],
#  ['HRSH ROLO BARS 1.7 OZ', 'BB BUTTER PECAN PREMIUM ICE CREAM 48 OZ'],
#  ['ROLD GOLD STICKS 16 OZ',
#   'IDHN BTR HERB MSH POTATO 4 OZ',
#   'KR DRSNG CUCUMBER RANCH 16 OZ',
#   'IDHN BTR HERB MSH POTATO 4 OZ',
#   'IDHN BTR HERB MSH POTATO 4 OZ',
#   'IDHN BTR HERB MSH POTATO 4 OZ'],
#  ['BLACKBERRIES 6 OZ',
#   'RASPBERRIES 6 OZ',
#   'BLUEBERRIES PINT',
#   'HOST MINI DONUT GLAZED 10.5 OZ',
#   'HAMBURGER BUNS EACH',
#   'STOK COLD BREW UNSWE 48 OZ',
#   'AM CH MILK 2% GALN 128 OZ'],
#  ['BARILLA RIGATONI 16 OZ',
#   'BROCCOLI  CROWNS LB',
#   'BARILLA RIGATONI 16 OZ',
#   'HNT FIRE RSTD TOM 14.5 OZ',
#   'HNT FIRE RSTD TOM 14.5 OZ',
#   'HNT TOMATO SAUCE 29 OZ',
#   'HNT TOMATO SAUCE 29 OZ'],
#  ['LBS HAWAIIAN DINNER ROLL 12 CT', 'DIET MOUNTAIN DEW 20 OZ'],
#  ['CELERY EA', 'BROCCOLI  CROWNS LB'],
#  ['CAMP SOUP CREAM POTATO 10.5 OZ', 'PIL PIE CRUSTS 14.1 OZ'],
#  ['CALI PK UNCURED PEPPERONI THIN 13.6 OZ',
#   'RED BARON CL SAUS PEPP 21.95 OZ',
#   'RED BARON CLASSIC SUPREME 23.45 OZ',
#   'KR CHNK NY SHARP CHDR 8 OZ',
#   'GC PIZZA CUTTER 1 CT',
#   'BASKIN ROBBINS JAMOCA ALMOND FUDGE 14 OZ',
#   'RADISHES 1 LB',
#   'ATHENOS FETA CRM EACH'],
#  ['LEWIS TEXAS TOAST 12 OZ',
#   'LAYS SOUR CREAM AND ONION 7.75 OZ',
#   'LEWIS SOURDOUGH 12 OZ',
#   'I DLT CRML MACCH CLD FOAM CREAMER 14 OZ'],
#  ['BL RIBBON C HOMEMADE VANILLA R FAT 48 OZ',
#   'TERRO LIQUID ANT KILLER BAITS 6 CT',
#   'BST CH PIE CRUST REFRIGRTD 15 OZ'],
#  ['AZTECA SSZ FLOUR TORTILLA 10 CT',
#   'FLORAL SEASONAL',
#   'SL ART HAW BN 8P 19Z',
#   'NSTL TOLLHOUSE CHOC CHIP LOVERS 16 OZ',
#   'DORITOS SPICY NACHO PRTY SZ 15 OZ',
#   'JAR DIP TOSTITOS QUESO 15 OZ',
#   'FRITO LAY TOSTITOS SPICY QUESO DIP 15 OZ',
#   'RED CACTUS SALSA SWT HOT 16 OZ',
#   'FP GROUND CHUCK LEAN LB',
#   'STAND ANNUAL PLANTS 4 IN',
#   'STAND ANNUAL PLANTS 4 IN',
#   'STAND ANNUAL PLANTS 4 IN',
#   'FLOWER BEDDING 4 CELL EA',
#   'FLOWER BEDDING 4 CELL EA',
#   'FLOWER BEDDING 4 CELL EA'],
#  ['AM CH MILK 2% GALN 128 OZ',
#   'STRAWBERRIES   1 LB',
#   'HOST TWINKIES 10 CT 13.58 OZ',
#   'STRAWBERRIES   1 LB'],
#  ['COOL WHIP SF TOPPING 8 OZ', 'COOL WHIP ORIGINAL TOPPING 8 OZ'],
#  ['B BUNNY HOMEMADE VANILA 48 OZ',
#   'BST CH SP CREAM MSHRM FF 10.75 OZ',
#   'BST CH SP CREAM MSHRM FF 10.75 OZ',
#   'GROUND CHUCK LB'],
#  ['MAYFIELD PT MOOSE TRACKS 1 EACH',
#   'HOT PKT SMKY GRN CHILI CHS STEAK 9 OZ',
#   'IDHN BTR HMSTYLE MSH POTATO 4 OZ',
#   'BST CH BLACK BEANS 15 OZ',
#   'GROUND CHUCK LB',
#   'FP GROUND CHUCK LEAN LB'],
#  ['BANANA LB', 'PORK STEAK LB'],
#  ['SB CK SALAD SHRIMP 16 OZ',
#   'MILO SWEET TEA GAL',
#   'BORDEN HEAVY WHIPNG CREAM 16 OZ',
#   'SIMPLY LT LEMONADE 52 OZ',
#   'LEWIS SOURDOUGH 12 OZ'],
#  ['NIAGARA DRNKG  WTR 24 PK',
#   'NIAGARA DRNKG  WTR 24 PK',
#   'NIAGARA DRNKG  WTR 24 PK',
#   'NIAGARA DRNKG  WTR 24 PK'],
#  ['MC SEASONING TACO MILD 1 OZ',
#   'MULLENS DRSNG IMITATION FRENCH 16 OZ',
#   'MC SEASONING TACO MILD 1 OZ',
#   'STRAWBERRIES   1 LB',
#   'BLUEBERRIES PINT',
#   'COOL WHIP ORIGINAL TOPPING 8 OZ',
#   'RAGU OWS TRAD RETRO SAUCE LE 24 OZ',
#   'RAGU OWS TRAD RETRO SAUCE LE 24 OZ',
#   'CHOB 0% PLAIN YOG 32 OZ',
#   'ALMOND BRZ VAN MILK 64 OZ',
#   'BANANA LB'],
#  ['7 UP 2 LTR', 'TERRO LIQUID ANT KILLER BAITS 6 CT'],
#  ['GOT Markdown - Cold Deli',
#   'MISC HOT CHICKEN EACH',
#   'MISC HOT CHICKEN EACH'],
#  ['A&H BAKING SODA 16 OZ',
#   'HEARTH CLUB BAKING POWDER 8.1 OZ',
#   'JAR DIP TOSTITOS QUESO 15 OZ',
#   'COOL WHIP SF TOPPING 8 OZ',
#   'COOL WHIP SF TOPPING 8 OZ'],
#  ['FRESH TORTILLA CHIPS LB',
#   'TB SALSA CON QUESO MILD 15 OZ',
#   'TB SALSA CON QUESO MILD 15 OZ',
#   'BODY ARMOR LYTE SPORTS DK TROP COCNT 16',
#   'BODY ARMOR LYTE SPORTS DK TROP COCNT 16',
#   'POWERADE ZERO MIXED BERRY 28 OZ',
#   'PADE ZERO STRAWBERRY 28 OZ'],
#  ['KR FINE SHRD 4 CHS MEX 8 OZ',
#   'CHI CHI BURRITO TORTILLA 8 CT 17 OZ',
#   'KR FINE SHRD 4 CHS MEX 8 OZ',
#   'GROUND BEEF LB',
#   'LACHOY BEAN SPROUT 14 OZ',
#   'OEP ENCHILADA SCE RED MILD 19 OZ',
#   'OEP ENCHILADA SCE RED MILD 19 OZ'],
#  ['MARIE C SHEP PIE BEEF 11.5 OZ',
#   'MARIE C SHEP PIE BEEF 11.5 OZ',
#   'DIET MOUNTAIN DEW .5L 6 PK',
#   'DIET MOUNTAIN DEW .5L 6 PK',
#   'DIET MOUNTAIN DEW .5L 6 PK',
#   'DIET MOUNTAIN DEW .5L 6 PK'],
#  ['RAGU PASTA SC 4 CHEESE 16 OZ', 'RAGU PASTA SC 4 CHEESE 16 OZ'],
#  ['H/ESS B/ENVY AERO SPRY   003 8 OZ',
#   'COAQUA SUPER PREM COCONUT WATER 8.4 OZ',
#   'EMJ DEO CEDARWOOD 3 OZ'],
#  ['MISC HOT CHICKEN EACH',
#   'HILLSHIRE FARM UT O/R TRK 9 OZ',
#   'TENDERS 1 LB',
#   'GARDETTO GARLIC RYE CHIPS 8 OZ',
#   'COKE CLASSIC 20 OZ'],
#  ['AS WATER DISTILLED 128 OZ',
#   'ONIONS SWEET LB',
#   'ROTEL HOT TOM HAB 10 OZ',
#   'LETTUCE  EA'],
#  ['POST GOLDEN CRISP 14.75 OZ',
#   'SILK PURE ALMOND VAN 64 OZ',
#   'POST HONEYCOMB 12.5 OZ',
#   'MILO SWEET TEA GAL',
#   'STRAWBERRIES   1 LB',
#   'STRAWBERRIES   1 LB',
#   'SL CL HNY WHE 20 OZ',
#   'SL CL HNY WHE 20 OZ',
#   'ARM CHEESE PIZZA PEG 2.45 OZ',
#   'MARZETTI RANCH VEGGIE DIP 12 OZ',
#   'MARZETTI RANCH VEGGIE DIP 12 OZ',
#   'ARM CHEESE PIZZA PEG 2.45 OZ',
#   'OM LC CHEESE PIZZA FP 10.6 OZ',
#   'OM LC CHEESE PIZZA FP 10.6 OZ',
#   'PILLS R/B CHOC CHK/CHIP 16 OZ',
#   'STRAWBERRY CHUNKS LB',
#   'CARROTS BABY PEEL 1 LB',
#   'MISC FLORAL GIFTWARE',
#   'CARROTS BABY PEEL 1 LB',
#   'MANDARINS 3  LB'],
#  ['MULLENS DRSNG IMITATION FRENCH 16 OZ',
#   'MULLENS DRSNG IMITATION FRENCH 16 OZ'],
#  ['ADHS CONST PL PREM 10 OZ', '1LB-TAN STR DECK PLUS 10X3'],
#  ...]

# %% [markdown]
# ## Preprocessing

# %%
# one-hot encode the transactions
te = TransactionEncoder()
te_array = te.fit(transaction_list).transform(transaction_list)
ds_encoded = pd.DataFrame(te_array, columns=te.columns_)

# %%
ds_encoded.head()
# Out:
#      BUTTERFLY  PORK CHOPS LB   FRYER  LIVERS LB   FRYER THIGHS LB  \
# 0                       False              False             False
# 1                       False              False             False
# 2                       False              False             False
# 3                       False              False             False
# 4                       False              False             False
#
#     FRYER WHOLE LB   FRYER WINGS LB   SMOKED PORK HOCKS LB  1/16 CAKE EACH  \
# 0            False            False                  False           False
# 1            False            False                  False           False
# 2            False            False                  False           False
# 3            False            False                  False           False
# 4            False            False                  False           False
#
#    1/2 FRESH APPLE PIE  1/2 SLAB RIB COLD EACH  1/4 WATERMELON LB  ...  \
# 0                False                   False              False  ...
# 1                False                   False              False  ...
# 2                False                   False              False  ...
# 3                False                   False              False  ...
# 4                False                   False              False  ...
#
#    ZIP FREEZER BAG GALLON 28 CT  ZIP FREEZER BAG GL 14 CT  \
# 0                         False                     False
# 1                         False                     False
# 2                         False                     False
# 3                         False                     False
# 4                         False                     False
#
#    ZIP FRZ BAG GAL 16 CT  ZIP SNDWICH BAG 40 CT  ZIP STORAGE BAG QT 24 CT  \
# 0                  False                  False                     False
# 1                  False                  False                     False
# 2                  False                  False                     False
# 3                  False                  False                     False
# 4                  False                  False                     False
#
#    ZIPL SNDWCH BAG 50 CT  ZOOM LIZARD 6 IN BLACK BLUE 9 PK  \
# 0                  False                             False
# 1                  False                             False
# 2                  False                             False
# 3                  False                             False
# 4                  False                             False
#
#    ZSGR RC COLA 2LTR 67.62 OZ  ZYRTEC 10MG TABLETS 5 CT  \
# 0                       False                     False
# 1                       False                     False
# 2                       False                     False
# 3                       False                     False
# 4                       False                     False
#
#    ZZZQUIL ULTR DOX TAB 12 CT
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False
#
# [5 rows x 8173 columns]

# %% [markdown]
# ## Create Itemsets

# %%
frequent_itemsets = fpgrowth(ds_encoded, min_support=0.002, use_colnames=True)

# %%
frequent_itemsets.tail()
# Out:
#       support                                           itemsets
# 668  0.002080                      (GALA APPLES 3 LB, BANANA LB)
# 669  0.002080         (STRAWBERRIES   1 LB, DESSERT SHELLS 6 CT)
# 670  0.002496             (SQUASH YELLOW LB, SQUASH ZUCCHINI LB)
# 671  0.002288  (JJ BERRY FRT SNK PIE 4 OZ, JJ PEACH SNACK PIE...
# 672  0.002080        (BANANA LB, LEWIS 1/2 LOAF NUTTY OAT 12 OZ)

# %%
fi = frequent_itemsets.sort_values(by='support', ascending=False)
fi.tail(20)
# Out:
#      support                                           itemsets
# 368  0.00208                                      (CILANTRO LB)
# 206  0.00208                     (TENN PRIDE MILD SAUSAGE 1 LB)
# 205  0.00208                         (LAYS BBQ PRTY SZ 12.5 OZ)
# 71   0.00208                        (BORDN HALF AND HALF 32 OZ)
# 156  0.00208                            (MTLF MSHD POTATO EACH)
# 604  0.00208                (DAISY SOUR CREAM 16 OZ, BANANA LB)
# 341  0.00208                         (BOB EVANS SAUS ROLLS 1LB)
# 350  0.00208                      (BST CH BACON BITS REAL 3 OZ)
# 333  0.00208          (BST CH TORTILLA SOFT TACO 6 IN 10 CT 10)
# 642  0.00208                (MISC HOT FOODS EACH, TENDERS 1 LB)
# 602  0.00208  (KY LEG APPLWOD SMK SLCED BACON 1 LB, STRAWBER...
# 343  0.00208                         (SWT HAW DINNER ROLL EACH)
# 172  0.00208                      (ECK SMKD LINK SAUSAGE 14 OZ)
# 609  0.00208        (STAND ANNUAL PLANTS 4 IN, FLORAL SEASONAL)
# 173  0.00208                       (GOT Markdown - Wic Produce)
# 181  0.00208                       (CREAM CHEESE CINN ROLL 4CT)
# 652  0.00208  (GRAPES GREEN SUGAR DROP LB, STRAWBERRIES   1 LB)
# 659  0.00208         (PRAIRIE FARM 2 % MILK H 64 OZ, BANANA LB)
# 654  0.00208        (TOMATO ON THE VINE  1 LB, CORN BICOLOR CT)
# 672  0.00208        (BANANA LB, LEWIS 1/2 LOAF NUTTY OAT 12 OZ)

# %% [markdown]
# ## Create rules

# %%
rules = association_rules(frequent_itemsets,metric="lift", min_threshold=0.5)
print(rules.sort_values(by='lift', ascending=False).head(10))
# Out:
#                                       antecedents  \
# 125                            (MG POTTING MIX S)
# 124                 (MG POTTING MIX SOIL 2 CF EA)
# 224               (GM HONEY NUT CHEERIOS 10.8 OZ)
# 225  (CPN: Buy 2 Save $2 on GM Cereals 5/14-5/20)
# 238                   (JJ BERRY FRT SNK PIE 4 OZ)
# 239                     (JJ PEACH SNACK PIE 4 OZ)
# 236                            (SQUASH YELLOW LB)
# 237                          (SQUASH ZUCCHINI LB)
# 175                            (PEPPER YELLOW EA)
# 174                            (PEPPER ORANGE EA)
#
#                                       consequents  antecedent support  \
# 125                 (MG POTTING MIX SOIL 2 CF EA)            0.002288
# 124                            (MG POTTING MIX S)            0.002288
# 224  (CPN: Buy 2 Save $2 on GM Cereals 5/14-5/20)            0.004576
# 225               (GM HONEY NUT CHEERIOS 10.8 OZ)            0.002496
# 238                     (JJ PEACH SNACK PIE 4 OZ)            0.005408
# 239                   (JJ BERRY FRT SNK PIE 4 OZ)            0.003120
# 236                          (SQUASH ZUCCHINI LB)            0.004992
# 237                            (SQUASH YELLOW LB)            0.006656
# 175                            (PEPPER ORANGE EA)            0.005616
# 174                            (PEPPER YELLOW EA)            0.007072
#
#      consequent support   support  confidence        lift  representativity  \
# 125            0.002288  0.002288    1.000000  437.090909               1.0
# 124            0.002288  0.002288    1.000000  437.090909               1.0
# 224            0.002496  0.002080    0.454545  182.121212               1.0
# 225            0.004576  0.002080    0.833333  182.121212               1.0
# 238            0.003120  0.002288    0.423077  135.610256               1.0
# 239            0.005408  0.002288    0.733333  135.610256               1.0
# 236            0.006656  0.002496    0.500000   75.125000               1.0
# 237            0.004992  0.002496    0.375000   75.125000               1.0
# 175            0.007072  0.002288    0.407407   57.612200               1.0
# 174            0.005616  0.002288    0.323529   57.612200               1.0
#
#      leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 125  0.002283         inf       1.000000  1.000000   1.000000    1.000000
# 124  0.002283         inf       1.000000  1.000000   1.000000    1.000000
# 224  0.002068    1.828758       0.999081  0.416667   0.453181    0.643939
# 225  0.002068    5.972546       0.996997  0.416667   0.832567    0.643939
# 238  0.002271    1.727926       0.998023  0.366667   0.421271    0.578205
# 239  0.002271    3.729721       0.995732  0.366667   0.731883    0.578205
# 236  0.002463    1.986689       0.991639  0.272727   0.496650    0.437500
# 237  0.002463    1.592013       0.993300  0.272727   0.371865    0.437500
# 175  0.002248    1.675567       0.988192  0.220000   0.403187    0.365468
# 174  0.002248    1.469959       0.989641  0.220000   0.319709    0.365468

# %%
def format_rule(row):
    antecedent = ' + '.join(sorted(row['antecedents']))
    consequent = ', '.join(sorted(row['consequents']))
    return f"If a customer buys {antecedent}, they also buy {consequent} (Lift: {row['lift']:.2f}, Confidence: {row['confidence']:.0%})"

# %%
rules['rule_summary'] = rules.apply(format_rule, axis=1)

# %%
rules.head()
# Out:
#                     antecedents                   consequents  \
# 0     (BUNNY HONEY WHEAT 20 OZ)                   (BANANA LB)
# 1                   (BANANA LB)     (BUNNY HONEY WHEAT 20 OZ)
# 2            (CARD MDAY ANYONE)  (FRESH ARRANGEMENT OR STEMS)
# 3  (FRESH ARRANGEMENT OR STEMS)            (CARD MDAY ANYONE)
# 4      (APPLE WA HONEYCRISP LB)                   (BANANA LB)
#
#    antecedent support  consequent support   support  confidence       lift  \
# 0            0.015391            0.085067  0.002496    0.162162   1.906297
# 1            0.085067            0.015391  0.002496    0.029340   1.906297
# 2            0.010815            0.018303  0.002080    0.192308  10.506993
# 3            0.018303            0.010815  0.002080    0.113636  10.506993
# 4            0.006864            0.085067  0.002288    0.333333   3.918500
#
#    representativity  leverage  conviction  zhangs_metric   jaccard  certainty  \
# 0               1.0  0.001187    1.092017       0.482855  0.025478   0.084264
# 1               1.0  0.001187    1.014370       0.519626  0.025478   0.014167
# 2               1.0  0.001882    1.215435       0.914718  0.076923   0.177249
# 3               1.0  0.001882    1.116003       0.921695  0.076923   0.103945
# 4               1.0  0.001704    1.372400       0.749948  0.025522   0.271350
#
#    kulczynski                                       rule_summary
# 0    0.095751  If a customer buys BUNNY HONEY WHEAT 20 OZ, th...
# 1    0.095751  If a customer buys BANANA LB, they also buy BU...
# 2    0.152972  If a customer buys CARD MDAY ANYONE, they also...
# 3    0.152972  If a customer buys FRESH ARRANGEMENT OR STEMS,...
# 4    0.180114  If a customer buys APPLE WA HONEYCRISP LB, the...

# %%
rules.to_csv('../data/association_rules.csv', index=False)

# %%
print(rules[['rule_summary', 'lift']].sort_values(by='lift', ascending=False).head(20))
# Out:
#                                           rule_summary        lift
# 125  If a customer buys MG POTTING MIX S, they also...  437.090909
# 124  If a customer buys MG POTTING MIX SOIL 2 CF EA...  437.090909
# 224  If a customer buys GM HONEY NUT CHEERIOS 10.8 ...  182.121212
# 225  If a customer buys CPN: Buy 2 Save $2 on GM Ce...  182.121212
# 238  If a customer buys JJ BERRY FRT SNK PIE 4 OZ, ...  135.610256
# 239  If a customer buys JJ PEACH SNACK PIE 4 OZ, th...  135.610256
# 236  If a customer buys SQUASH YELLOW LB, they also...   75.125000
# 237  If a customer buys SQUASH ZUCCHINI LB, they al...   75.125000
# 175  If a customer buys PEPPER YELLOW EA, they also...   57.612200
# 174  If a customer buys PEPPER ORANGE EA, they also...   57.612200
# 102  If a customer buys DORITOS COOL RANCH 9.25 OZ,...   45.695868
# 103  If a customer buys DORITOS NACHO CHEESE 9.25 O...   45.695868
# 173  If a customer buys PEPPER YELLOW EA, they also...   42.737778
# 172  If a customer buys PEPPER  RED EA, they also b...   42.737778
# 169  If a customer buys PEPPER  RED EA, they also b...   42.423529
# 168  If a customer buys PEPPER ORANGE EA, they also...   42.423529
# 112  If a customer buys STAND ANNUAL PLANTS 4 IN, t...   30.526984
# 113  If a customer buys FLOWER BEDDING 4 CELL EA, t...   30.526984
# 221  If a customer buys RASPBERRIES 6 OZ, they also...   30.125313
# 220  If a customer buys BLUEBERRIES PINT, they also...   30.125313

# %%
sorted_rules = rules[['rule_summary', 'lift', 'confidence']].sort_values(by='lift', ascending=False)

# %%
sorted_rules.to_csv('../data/sorted_association_rules.csv', index=False)
